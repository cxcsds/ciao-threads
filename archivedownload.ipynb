# %% [markdown]
# # Archive Download

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 1843
download_chandra_obsid 1843
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       35 Mb  ####################          < 1 s  47800.1 kb/s
#   vvref    pdf        19 Mb  ####################          < 1 s  58652.3 kb/s
#   evt2     fits       17 Mb  ####################          < 1 s  57313.8 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  43313.7 kb/s
#   cntr_img jpg       833 Kb  ####################          < 1 s  27071.9 kb/s
#   bias     fits      496 Kb  ####################          < 1 s  21131.9 kb/s
#   bias     fits      430 Kb  ####################          < 1 s  18413.4 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  21025.6 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  16026.2 kb/s
#   bias     fits      426 Kb  ####################          < 1 s  17628.1 kb/s
# ...

# %%
download_chandra_obsid 1842,1843,459
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       36 Mb    already downloaded
#   evt2     fits       19 Mb    already downloaded
#   vvref    pdf        17 Mb    already downloaded
#   asol     fits        2 Mb    already downloaded
#   cntr_img jpg       798 Kb    already downloaded
#   bias     fits      496 Kb    already downloaded
#   bias     fits      430 Kb    already downloaded
#   bias     fits      427 Kb    already downloaded
#   bias     fits      427 Kb    already downloaded
#   bias     fits      426 Kb    already downloaded
#   bias     fits      424 Kb    already downloaded
#   osol     fits      356 Kb    already downloaded
#   osol     fits      353 Kb    already downloaded
#   mtl      fits      332 Kb    already downloaded
#   eph1     fits      281 Kb    already downloaded
#   stat     fits      277 Kb    already downloaded
# ...

# %%
download_chandra_obsid 1842,1843 evt2,asol
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       19 Mb    already downloaded
#   asol     fits        2 Mb    already downloaded
#
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       17 Mb    already downloaded
#   asol     fits        2 Mb    already downloaded

# %% [markdown]
# ## Find Chandra Obsid

# %%
find_chandra_obsid G215-09 || echo
# Out:
# # find_chandra_obsid (02 November 2020): ERROR No position found matching the name 'G215-09'.

# %%
find_chandra_obsid "18h 33m 33.50s" "-10d 34' 06.70"'"'
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname          target
# 142       0.0  HRC-I NONE   30.3 2000-02-16 Calibration "SNR G21.5-0.9"
# 143       0.0  HRC-I NONE   13.8 1999-09-04 Calibration "SNR G21.5-0.9"
# 144       0.0  HRC-I NONE   30.0 2000-09-01 Calibration "SNR G21.5-0.9"
# 146       0.0  HRC-S NONE   10.4 2000-02-16 Calibration "SNR G21.5-0.9"
# 147       0.0  HRC-S NONE    9.7 1999-09-05 Calibration "SNR G21.5-0.9"
# 148       0.0  HRC-S NONE   10.0 2000-08-31 Calibration "SNR G21.5-0.9"
# 150       0.0  HRC-S NONE   10.3 2000-02-16 Calibration "SNR G21.5-0.9"
# 151       0.0  HRC-S NONE    9.7 1999-09-05 Calibration "SNR G21.5-0.9"
# 152       0.0  HRC-S NONE   10.4 2000-08-31 Calibration "SNR G21.5-0.9"
# 154       0.0  HRC-S NONE   10.0 2000-02-16 Calibration "SNR G21.5-0.9"
# 155       0.0  HRC-S NONE   10.4 2000-08-31 Calibration "SNR G21.5-0.9"
# 158       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration "SNR G21.5-0.9"
# ...

# %%
find_chandra_obsid 278.390 -10.57 instrument=hrci
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname          target
# 142       0.1  HRC-I NONE   30.3 2000-02-16 Calibration "SNR G21.5-0.9"
# 143       0.1  HRC-I NONE   13.8 1999-09-04 Calibration "SNR G21.5-0.9"
# 144       0.1  HRC-I NONE   30.0 2000-09-01 Calibration "SNR G21.5-0.9"
# 1242      0.1  HRC-I NONE   14.6 1999-09-04 Calibration "SNR G21.5-0.9"
# 1298      0.1  HRC-I NONE    7.2 1999-09-04 Calibration "SNR G21.5-0.9"
# 1406      0.1  HRC-I NONE   30.0 1999-10-25 Calibration "SNR G21.5-0.9"
# 1555      0.1  HRC-I NONE    8.9 2001-03-09 Calibration "SNR G21.5-0.9"
# 1556      0.1  HRC-I NONE   10.1 2001-07-13 Calibration "SNR G21.5-0.9"
# 2867      0.1  HRC-I NONE   19.1 2002-03-12 Calibration "SNR G21.5-0.9"
# 2874      0.1  HRC-I NONE   19.8 2002-07-15 Calibration "SNR G21.5-0.9"
# 3694      0.1  HRC-I NONE   18.3 2003-05-15 Calibration "SNR G21.5-0.9"
# 3701      0.1  HRC-I NONE   18.6 2003-11-09 Calibration "SNR G21.5-0.9"
# ...

# %%
find_chandra_obsid 18:33:33.5 -10:34:7 > matches.txt
dmlist matches.txt counts
# Out:
# 137

# %%
dmlist matches.txt"[sepn<1,inst=ACIS-I]" counts
# Out:
# 42

# %%
dmlist matches.txt"[sepn<1,inst=ACIS-I,time>10][cols obsid,time]" data,clean
# Out:
# #  obsid                time
#                 162.0                13.10
#                1233.0                 14.0

# %%
find_chandra_obsid '18 33 34' '-10 34' inst=hrci download=n
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname          target
# 142       0.2  HRC-I NONE   30.3 2000-02-16 Calibration "SNR G21.5-0.9"
# 143       0.2  HRC-I NONE   13.8 1999-09-04 Calibration "SNR G21.5-0.9"
# 144       0.2  HRC-I NONE   30.0 2000-09-01 Calibration "SNR G21.5-0.9"
# 1242      0.2  HRC-I NONE   14.6 1999-09-04 Calibration "SNR G21.5-0.9"
# 1298      0.2  HRC-I NONE    7.2 1999-09-04 Calibration "SNR G21.5-0.9"
# 1406      0.2  HRC-I NONE   30.0 1999-10-25 Calibration "SNR G21.5-0.9"
# 1555      0.2  HRC-I NONE    8.9 2001-03-09 Calibration "SNR G21.5-0.9"
# 1556      0.2  HRC-I NONE   10.1 2001-07-13 Calibration "SNR G21.5-0.9"
# 2867      0.2  HRC-I NONE   19.1 2002-03-12 Calibration "SNR G21.5-0.9"
# 2874      0.2  HRC-I NONE   19.8 2002-07-15 Calibration "SNR G21.5-0.9"
# 3694      0.2  HRC-I NONE   18.3 2003-05-15 Calibration "SNR G21.5-0.9"
# 3701      0.2  HRC-I NONE   18.6 2003-11-09 Calibration "SNR G21.5-0.9"
# ...

# %%
find_chandra_obsid 1843
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname          target
# 142       0.0  HRC-I NONE   30.3 2000-02-16 Calibration "SNR G21.5-0.9"
# 143       0.0  HRC-I NONE   13.8 1999-09-04 Calibration "SNR G21.5-0.9"
# 144       0.0  HRC-I NONE   30.0 2000-09-01 Calibration "SNR G21.5-0.9"
# 146       0.0  HRC-S NONE   10.4 2000-02-16 Calibration "SNR G21.5-0.9"
# 147       0.0  HRC-S NONE    9.7 1999-09-05 Calibration "SNR G21.5-0.9"
# 148       0.0  HRC-S NONE   10.0 2000-08-31 Calibration "SNR G21.5-0.9"
# 150       0.0  HRC-S NONE   10.3 2000-02-16 Calibration "SNR G21.5-0.9"
# 151       0.0  HRC-S NONE    9.7 1999-09-05 Calibration "SNR G21.5-0.9"
# 152       0.0  HRC-S NONE   10.4 2000-08-31 Calibration "SNR G21.5-0.9"
# 154       0.0  HRC-S NONE   10.0 2000-02-16 Calibration "SNR G21.5-0.9"
# 155       0.0  HRC-S NONE   10.4 2000-08-31 Calibration "SNR G21.5-0.9"
# 158       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration "SNR G21.5-0.9"
# ...

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 1842 1843 459
