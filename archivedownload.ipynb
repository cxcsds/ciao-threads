# %% [markdown]
# # Archive Download

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 1843
download_chandra_obsid 1843
# Out:
# Downloading files for ObsId 1843, total size is 81 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb  ####################          < 1 s  1896.0 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  3245.4 kb/s
#   vv       pdf        40 Kb  ####################          < 1 s  5391.3 kb/s
#   cntr_img fits      237 Kb  ####################          < 1 s  16647.8 kb/s
#   cntr_img jpg       925 Kb  ####################          < 1 s  30432.6 kb/s
#   evt2     fits       17 Mb  ####################          < 1 s  73104.6 kb/s
#   full_img fits       80 Kb  ####################          < 1 s  9163.9 kb/s
#   full_img jpg        82 Kb  ####################          < 1 s  9525.0 kb/s
#   bpix     fits       13 Kb  ####################          < 1 s  2374.4 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  582.9 kb/s
#   eph1     fits      281 Kb  ####################          < 1 s  20264.1 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  50433.5 kb/s
#   evt1     fits       35 Mb  ####################          < 1 s  83757.0 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  1113.5 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  901.5 kb/s
#   mtl      fits      344 Kb  ####################          < 1 s  23161.7 kb/s
#   stat     fits      290 Kb  ####################          < 1 s  21229.0 kb/s
#   bias     fits      426 Kb  ####################          < 1 s  22299.2 kb/s
#   bias     fits      494 Kb  ####################          < 1 s  22690.9 kb/s
#   bias     fits      430 Kb  ####################          < 1 s  20060.7 kb/s
#   bias     fits      423 Kb  ####################          < 1 s  22307.4 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  20423.3 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  20688.1 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  624.2 kb/s
#   vv       pdf        19 Mb  ####################          < 1 s  72816.1 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  1042.9 kb/s
#   eph1     fits      274 Kb  ####################          < 1 s  16927.1 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  16248.7 kb/s
#   osol     fits      353 Kb  ####################          < 1 s  19130.8 kb/s
#   aqual    fits      148 Kb  ####################          < 1 s  13036.9 kb/s
#   osol     fits      343 Kb  ####################          < 1 s  18179.5 kb/s
#   osol     fits      354 Kb  ####################          < 1 s  20451.4 kb/s
#
#       Total download size for ObsId 1843 = 81 Mb
#       Total download time for ObsId 1843 = 1 s

# %%
download_chandra_obsid 1842,1843,459
# Out:
# Downloading files for ObsId 1842, total size is 81 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb    already downloaded
#   oif      fits       23 Kb    already downloaded
#   vv       pdf        44 Kb    already downloaded
#   cntr_img fits      230 Kb    already downloaded
#   cntr_img jpg       910 Kb    already downloaded
#   evt2     fits       19 Mb    already downloaded
#   full_img fits       91 Kb    already downloaded
#   full_img jpg        74 Kb    already downloaded
#   bpix     fits       12 Kb    already downloaded
#   fov      fits        6 Kb    already downloaded
#   eph1     fits      281 Kb    already downloaded
#   asol     fits        2 Mb    already downloaded
#   evt1     fits       36 Mb    already downloaded
#   flt      fits       16 Kb    already downloaded
#   msk      fits        5 Kb    already downloaded
#   mtl      fits      334 Kb    already downloaded
#   stat     fits      276 Kb    already downloaded
#   bias     fits      426 Kb    already downloaded
#   bias     fits      494 Kb    already downloaded
#   bias     fits      430 Kb    already downloaded
#   bias     fits      423 Kb    already downloaded
#   bias     fits      427 Kb    already downloaded
#   bias     fits      427 Kb    already downloaded
#   pbk      fits        4 Kb    already downloaded
#   vv       pdf        18 Mb    already downloaded
#   eph1     fits        6 Kb    already downloaded
#   eph1     fits      274 Kb    already downloaded
#   eph1     fits      258 Kb    already downloaded
#   osol     fits      354 Kb    already downloaded
#   aqual    fits      133 Kb    already downloaded
#   osol     fits      357 Kb    already downloaded
#
# Downloading files for ObsId 1843, total size is 81 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb    already downloaded
#   oif      fits       23 Kb    already downloaded
#   vv       pdf        40 Kb    already downloaded
#   cntr_img fits      237 Kb    already downloaded
#   cntr_img jpg       925 Kb    already downloaded
#   evt2     fits       17 Mb    already downloaded
#   full_img fits       80 Kb    already downloaded
#   full_img jpg        82 Kb    already downloaded
#   bpix     fits       13 Kb    already downloaded
#   fov      fits        6 Kb    already downloaded
#   eph1     fits      281 Kb    already downloaded
#   asol     fits        2 Mb    already downloaded
#   evt1     fits       35 Mb    already downloaded
#   flt      fits        7 Kb    already downloaded
#   msk      fits        5 Kb    already downloaded
#   mtl      fits      344 Kb    already downloaded
#   stat     fits      290 Kb    already downloaded
#   bias     fits      426 Kb    already downloaded
#   bias     fits      494 Kb    already downloaded
#   bias     fits      430 Kb    already downloaded
#   bias     fits      423 Kb    already downloaded
#   bias     fits      427 Kb    already downloaded
#   bias     fits      427 Kb    already downloaded
#   pbk      fits        4 Kb    already downloaded
#   vv       pdf        19 Mb    already downloaded
#   eph1     fits        6 Kb    already downloaded
#   eph1     fits      274 Kb    already downloaded
#   eph1     fits      258 Kb    already downloaded
#   osol     fits      353 Kb    already downloaded
#   aqual    fits      148 Kb    already downloaded
#   osol     fits      343 Kb    already downloaded
#   osol     fits      354 Kb    already downloaded
#
# Downloading files for ObsId 459, total size is 298 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      10 Kb    already downloaded
#   oif      fits       25 Kb    already downloaded
#   vv       pdf        39 Kb    already downloaded
#   cntr_img jpg       625 Kb    already downloaded
#   evt2     fits       22 Mb    already downloaded
#   full_img jpg        74 Kb    already downloaded
#   pha2     fits        1 Mb    already downloaded
#   bpix     fits       11 Kb    already downloaded
#   fov      fits        6 Kb    already downloaded
#   eph1     fits      301 Kb    already downloaded
#   asol     fits       10 Mb    already downloaded
#   aoff     fits        4 Mb    already downloaded
#   evt1     fits       97 Mb    already downloaded
#   evt1a    fits       75 Mb    already downloaded
#   flt      fits        7 Kb    already downloaded
#   msk      fits        5 Kb    already downloaded
#   mtl      fits        2 Mb    already downloaded
#   soff     fits        5 Kb    already downloaded
#   stat     fits        1 Mb    already downloaded
#   bias     fits      501 Kb    already downloaded
#   bias     fits      444 Kb    already downloaded
#   bias     fits      437 Kb    already downloaded
#   bias     fits      446 Kb    already downloaded
#   bias     fits      435 Kb    already downloaded
#   pbk      fits        4 Kb    already downloaded
#   vv       pdf        79 Mb    already downloaded
#   eph1     fits       16 Kb    already downloaded
#   eph1     fits      293 Kb    already downloaded
#   eph1     fits      271 Kb    already downloaded
#   osol     fits      115 Kb    already downloaded
#   aqual    fits      611 Kb    already downloaded
#   osol     fits      357 Kb    already downloaded
#   osol     fits      356 Kb    already downloaded
#   osol     fits      266 Kb    already downloaded
#   osol     fits      355 Kb    already downloaded
#   osol     fits      355 Kb    already downloaded
#   osol     fits      355 Kb    already downloaded
#   osol     fits      364 Kb    already downloaded

# %%
download_chandra_obsid 1842,1843 evt2,asol
# Out:
# Downloading files for ObsId 1842, total size is 21 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       19 Mb    already downloaded
#   asol     fits        2 Mb    already downloaded
#
# Downloading files for ObsId 1843, total size is 20 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       17 Mb    already downloaded
#   asol     fits        2 Mb    already downloaded

# %% [markdown]
# ## Find Chandra Obsid

# %%
find_chandra_obsid G215-09
# Out:
# # find_chandra_obsid (18 October 2016): ERROR No position found matching the name 'G215-09'.

# %%
find_chandra_obsid "18h 33m 33.50s" "-10d 34' 06.70"'"'
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname                                               target
# 142       0.0  HRC-I NONE   30.3 2000-02-16 Calibration                                            G21.5-0.9
# 143       0.0  HRC-I NONE   13.8 1999-09-04 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 144       0.0  HRC-I NONE   30.0 2000-09-01 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 146       0.0  HRC-S NONE   10.4 2000-02-16 Calibration        "G21.5-0.9 [HRC-S, Offsets=0,0,0 CENTER MCP]"
# 147       0.0  HRC-S NONE    9.7 1999-09-05 Calibration        "G21.5-0.9 [HRC-S, Offsets=0,0,0 CENTER MCP]"
# 148       0.0  HRC-S NONE   10.0 2000-08-31 Calibration        "G21.5-0.9 [HRC-S, Offsets=0,0,0 CENTER MCP]"
# 150       0.0  HRC-S NONE   10.3 2000-02-16 Calibration          "G21.5-0.9 [HRC-S, Offsets=-30,0,0 +Y MCP]"
# 151       0.0  HRC-S NONE    9.7 1999-09-05 Calibration          "G21.5-0.9 [HRC-S, Offsets=-20,0,0 +Y MCP]"
# 152       0.0  HRC-S NONE   10.4 2000-08-31 Calibration          "G21.5-0.9 [HRC-S, Offsets=-30,0,0 +Y MCP]"
# 154       0.0  HRC-S NONE   10.0 2000-02-16 Calibration           "G21.5-0.9 [HRC-S, Offsets=30,0,0 -Y MPC]"
# 155       0.0  HRC-S NONE   10.4 2000-08-31 Calibration           "G21.5-0.9 [HRC-S, Offsets=30,0,0 -Y MPC]"
# 158       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration "G21.5-0.9 [Chip I1, T=100, Offsets=-3,-5,0 Off-ax]"
# 159       0.0 ACIS-S NONE   14.8 1999-08-23 Calibration "G21.5-0.9 [Chip S3, T=100, Offsets=0,0,0 Std Cand]"
# 160       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration  "G21.5-0.9 [Chip I0, T=100, Offsets=5,-5,0 Off-ax]"
# 161       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration   "G21.5-0.9 [Chip I2, T=100, Offsets=5,3,0 Off-ax]"
# 162       0.0 ACIS-I NONE   13.1 1999-08-27 Calibration "G21.5-0.9 [Chip I3, T=100, Offsets=-1,1,0 Std Can]"
# 163      23.5 ACIS-S NONE    9.9 1999-08-15 Calibration         "G21.5-0.9 [Chip S0, T=100, Offsets=23,0,0]"
# 164      15.0 ACIS-S NONE    9.6 1999-08-15 Calibration         "G21.5-0.9 [Chip S1, T=100, Offsets=15,0,0]"
# 165       0.0 ACIS-S NONE    9.6 1999-08-23 Calibration          "G21.5-0.9 [Chip S2, T=100, Offsets=6,0,0]"
# 166      10.5 ACIS-S NONE    9.9 1999-08-15 Calibration        "G21.5-0.9 [Chip S4, T=100, Offsets=-10,0,0]"
# 167      19.0 ACIS-S NONE    9.6 1999-08-15 Calibration        "G21.5-0.9 [Chip S5, T=100, Offsets=-19,0,0]"
# 1230      0.0 ACIS-S NONE   14.6 1999-08-23 Calibration "G21.5-0.9 [Chip S3, T=100, Offsets=0,0,0 Std Cand]"
# 1233      0.0 ACIS-I NONE   14.0 1999-11-05 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-1,1,0]"
# 1242      0.0  HRC-I NONE   14.6 1999-09-04 Calibration                                            G21.5-0.9
# 1267     19.0 ACIS-S NONE   12.8 1999-08-16 Calibration        "G21.5-0.9 [Chip S5, T=100, Offsets=-19,0,0]"
# 1298      0.0  HRC-I NONE    7.2 1999-09-04 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1406      0.0  HRC-I NONE   30.0 1999-10-25 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1432      0.0 ACIS-S NONE    9.9 2000-03-01 Calibration         "G21.5-0.9 [Chip S0, T=120, Offsets=22,0,0]"
# 1433      0.0 ACIS-S NONE   15.0 1999-11-15 Calibration         "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,0]"
# 1434      0.0 ACIS-S NONE    9.7 1999-11-16 Calibration          "G21.5-0.9 [Chip S2, T=110, Offsets=6,0,0]"
# 1441      0.0 ACIS-I NONE    9.1 1999-11-15 Calibration         "G21.5-0.9 [Chip I0, T=110, Offsets=7,-6,0]"
# 1442      0.0 ACIS-I NONE    9.7 1999-11-15 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-3,-5,0]"
# 1443      0.0 ACIS-I NONE    9.7 1999-11-15 Calibration          "G21.5-0.9 [Chip I2, T=110, Offsets=5,3,0]"
# 1551      0.0 ACIS-I NONE    8.7 2001-03-08 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,0,2]"
# 1552      0.0 ACIS-I NONE    9.9 2001-07-13 Calibration     "G21.5-0.9[Chip I3, T=120, Offsets=-2.25,0,3.5]"
# 1553      0.0 ACIS-S NONE    9.7 2001-03-18 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 1554      0.0 ACIS-S NONE    9.1 2001-07-21 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 1555      0.0  HRC-I NONE    8.9 2001-03-09 Calibration      "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2A]"
# 1556      0.0  HRC-I NONE   10.1 2001-07-13 Calibration      "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2B]"
# 1557      0.0  HRC-S NONE    8.5 2001-03-09 Calibration      "G21.5-0.9 [HRC-S, Offsets=0,0,0 Offsets=AO2A]"
# 1558      0.0  HRC-S NONE    8.9 2001-07-27 Calibration      "G21.5-0.9 [HRC-S, Offsets=0,0,0 Offsets=AO2B]"
# 1716      0.0 ACIS-S NONE    7.7 2000-05-23 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,3]"
# 1717      0.0 ACIS-S NONE    7.5 2000-05-23 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 1718      0.0 ACIS-S NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,-3]"
# 1719      0.0 ACIS-I NONE    7.7 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-7,0,-1]"
# 1720      0.0 ACIS-I NONE    7.5 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-5,0,-1]"
# 1721      0.0 ACIS-I NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-4,0,-1]"
# 1722      0.0 ACIS-I NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-2,0,-1]"
# 1723      0.0 ACIS-I NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-0,0,-1]"
# 1724      0.0 ACIS-I NONE    7.6 2000-05-24 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-5,0,2]"
# 1725      0.0 ACIS-I NONE    7.6 2000-05-24 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-4,0,2]"
# 1726      0.0 ACIS-I NONE    7.6 2000-05-24 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,0,2]"
# 1727      0.0 ACIS-S NONE    7.7 2000-05-24 Calibration          "G21.5-0.9 [Chip S2, T=120, Offsets=5,0,1]"
# 1728      0.0 ACIS-S NONE    7.5 2000-05-24 Calibration          "G21.5-0.9 [Chip S2, T=120, Offsets=5,0,0]"
# 1729      0.0 ACIS-S NONE    7.6 2000-05-24 Calibration          "G21.5-0.9 [Chip S2, T=120, Offsets=5,0,3]"
# 1769      0.0 ACIS-S NONE    7.4 2000-07-05 Calibration         "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,3]"
# 1770      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration         "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,0]"
# 1771      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,-3]"
# 1772      0.0 ACIS-I NONE    7.4 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-7,0,-1]"
# 1773      0.0 ACIS-I NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-5,0,-1]"
# 1774      0.0 ACIS-I NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-4,0,-1]"
# 1775      0.0 ACIS-I NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-2,0,-1]"
# 1776      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-0,0,-1]"
# 1777      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-5,0,2]"
# 1778      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-4,0,2]"
# 1779      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-2,0,2]"
# 1780      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration          "G21.5-0.9 [Chip S2, T=110, Offsets=5,0,1]"
# 1781      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration          "G21.5-0.9 [Chip S2, T=110, Offsets=5,0,0]"
# 1782      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration         "G21.5-0.9 [Chip S2, T=110, Offsets=5,0,-3]"
# 1838      0.0 ACIS-S NONE    7.8 2000-09-02 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,1]"
# 1839      0.0 ACIS-S NONE    7.7 2000-09-02 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,2,-1]"
# 1840      0.0 ACIS-S NONE    7.7 2000-09-02 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,5,-4]"
# 1841      0.0 ACIS-I NONE    8.0 2000-09-01 Calibration        "G21.5-0.9 [Chip I3, T=120, Offsets=-1,10,5]"
# 1842      0.0 ACIS-I NONE    7.4 2000-09-02 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,15,0]"
# 1843      0.0 ACIS-I NONE    7.8 2000-09-02 Calibration       "G21.5-0.9 [Chip S3, T=120, Offsets=-1,20,-4]"
# 2755      0.1  HRC-S NONE   29.2 2002-11-12      Murray                                            G21.5-0.9
# 2867      0.0  HRC-I NONE   19.1 2002-03-12 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 2868      0.0  HRC-S NONE   18.9 2002-03-13 Calibration                   "G21.5-0.9 [HRC-S, Offsets=0,0,0]"
# 2872      0.0 ACIS-I NONE    9.8 2002-09-13 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,2,0]"
# 2873      0.0 ACIS-S NONE    9.8 2002-09-14 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 2874      0.0  HRC-I NONE   19.8 2002-07-15 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 2875      0.0  HRC-S NONE   19.7 2002-09-13 Calibration                   "G21.5-0.9 [HRC-S, Offsets=0,0,0]"
# 3473      0.0 ACIS-I NONE    9.3 2002-05-16 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,2,0]"
# 3474      0.0 ACIS-S NONE    9.3 2002-05-16 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 3692      0.0 ACIS-I NONE    9.2 2003-05-16 Calibration      "G21.5-0.9[Chip I3, T=120, Offsets=-2.5,2.5,0]"
# 3693      0.0 ACIS-S NONE    9.8 2003-05-16 Calibration        "G21.5-0.9[Chip S3, T=120, Offsets=-1.0,0,0]"
# 3694      0.0  HRC-I NONE   18.3 2003-05-15 Calibration                                            G21.5-0.9
# 3695      0.0  HRC-S NONE   18.9 2003-05-12 Calibration                                            G21.5-0.9
# 3699      0.0 ACIS-I NONE    9.7 2003-11-09 Calibration      "G21.5-0.9[Chip I3, T=120, Offsets=-2.5,2.5,0]"
# 3700      0.0 ACIS-S NONE    9.5 2003-11-09 Calibration        "G21.5-0.9[Chip S3, T=120, Offsets=-1.0,0,0]"
# 3701      0.0  HRC-I NONE   18.6 2003-11-09 Calibration                                            G21.5-0.9
# 3702      0.0  HRC-S NONE   19.2 2003-11-09 Calibration                                            G21.5-0.9
# 4353      0.0 ACIS-S NONE    9.4 2003-05-15 Calibration       "G21.5-0.9[Chip S3, T=120, Offsets=-1,5,11.7]"
# 4354      0.0 ACIS-I NONE    9.8 2003-05-20 Calibration       "G21.5-0.9[Chip S3, T=120, Offsets=-1,10,-17]"
# 4355      0.0 ACIS-I NONE    9.4 2003-05-20 Calibration        "G21.5-0.9[Chip S3, T=120, Offsets=-1,15,-2]"
# 5158      0.0 ACIS-I NONE   10.0 2005-02-26 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 5159      0.0 ACIS-S NONE    9.8 2004-10-27 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 5165      0.0 ACIS-I NONE    9.6 2004-03-26 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 5166      0.0 ACIS-S NONE   10.0 2004-03-14 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 5167      0.0  HRC-I NONE   19.1 2004-03-25 Calibration                                             G21.5-09
# 5168      0.0  HRC-S NONE    0.0 2004-03-26 Calibration                                             G21.5-09
# 6070      0.0 ACIS-I NONE    9.4 2005-02-26 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 6071      0.0 ACIS-S NONE    9.6 2005-02-26 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 6072      0.0  HRC-I NONE   19.0 2005-02-26 Calibration                                             G21.5-09
# 6073      0.0  HRC-S NONE   20.0 2005-03-18 Calibration                                             G21.5-09
# 6740      0.0 ACIS-I NONE    9.8 2006-02-21 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 6741      0.0 ACIS-S NONE    9.8 2006-02-22 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 6742      0.0  HRC-I NONE   20.0 2006-02-21 Calibration                                             G21.5-09
# 6743      0.0  HRC-S NONE   19.9 2006-02-21 Calibration                                             G21.5-09
# 8371      0.0 ACIS-I NONE    9.9 2007-05-28 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 8372      0.0 ACIS-S NONE   10.0 2007-05-25 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 8373      0.0  HRC-I NONE   20.0 2007-05-25 Calibration                                             G21.5-09
# 8374      0.0  HRC-S NONE   21.4 2007-05-25 Calibration                                             G21.5-09
# 9701      0.0 ACIS-S NONE   10.1 2008-05-26 Calibration                        G21.5-09[S2,-120,5.15,0,10.0]
# 9702      0.0 ACIS-S NONE   10.1 2008-05-27 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 10644     0.0 ACIS-S NONE    9.6 2009-05-29 Calibration                           G21.5-09[S2,-120,5.15,0,8]
# 10645     0.0 ACIS-S NONE    9.5 2009-05-29 Calibration                       G21.5-09[S2,-120,5.15,0,-2.61]
# 10646     0.0 ACIS-S NONE    9.5 2009-05-29 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 10647     0.0 ACIS-S NONE   10.1 2009-05-30 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 10648     0.0  HRC-I NONE   10.1 2009-02-17 Calibration                                             G21.5-09
# 13091     0.0  HRC-I NONE   10.1 2011-05-30 Calibration                                             G21.5-09
# 14262     0.0  HRC-I NONE   10.0 2012-08-10 Calibration                                             G21.5-09
# 14263     0.0 ACIS-S NONE    9.6 2012-08-08 Calibration                                             G21.5-09
# 14264     0.0 ACIS-I NONE    9.6 2012-08-10 Calibration                                             G21.5-09
# 16419     0.0  HRC-I NONE   10.1 2014-05-06 Calibration                                             G21.5-09
# 16420     0.0 ACIS-S NONE    9.6 2014-05-07 Calibration                                             G21.5-09
# 16421     0.0 ACIS-I NONE    9.6 2014-05-09 Calibration                                             G21.5-09
# 16570     0.0  HRC-S NONE   10.1 2014-04-25 Calibration                                             G21.5-09

# %%
find_chandra_obsid 278.390 -10.57 instrument=hrci
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname                                          target
# 142       0.1  HRC-I NONE   30.3 2000-02-16 Calibration                                       G21.5-0.9
# 143       0.1  HRC-I NONE   13.8 1999-09-04 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 144       0.1  HRC-I NONE   30.0 2000-09-01 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1242      0.1  HRC-I NONE   14.6 1999-09-04 Calibration                                       G21.5-0.9
# 1298      0.1  HRC-I NONE    7.2 1999-09-04 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1406      0.1  HRC-I NONE   30.0 1999-10-25 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1555      0.1  HRC-I NONE    8.9 2001-03-09 Calibration "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2A]"
# 1556      0.1  HRC-I NONE   10.1 2001-07-13 Calibration "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2B]"
# 2867      0.1  HRC-I NONE   19.1 2002-03-12 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 2874      0.1  HRC-I NONE   19.8 2002-07-15 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 3694      0.1  HRC-I NONE   18.3 2003-05-15 Calibration                                       G21.5-0.9
# 3701      0.1  HRC-I NONE   18.6 2003-11-09 Calibration                                       G21.5-0.9
# 5167      0.1  HRC-I NONE   19.1 2004-03-25 Calibration                                        G21.5-09
# 6072      0.1  HRC-I NONE   19.0 2005-02-26 Calibration                                        G21.5-09
# 6742      0.1  HRC-I NONE   20.0 2006-02-21 Calibration                                        G21.5-09
# 8373      0.1  HRC-I NONE   20.0 2007-05-25 Calibration                                        G21.5-09
# 10648     0.1  HRC-I NONE   10.1 2009-02-17 Calibration                                        G21.5-09
# 13091     0.1  HRC-I NONE   10.1 2011-05-30 Calibration                                        G21.5-09
# 14262     0.1  HRC-I NONE   10.0 2012-08-10 Calibration                                        G21.5-09
# 16419     0.1  HRC-I NONE   10.1 2014-05-06 Calibration                                        G21.5-09

# %%
find_chandra_obsid 18:33:33.5 -10:34:7 > matches.txt
dmlist matches.txt counts
# Out:
# 128

# %%
dmlist matches.txt"[sepn<1,inst=ACIS-I]" counts
# Out:
# 42

# %%
dmlist matches.txt"[sepn<1,inst=ACIS-I,time>10][cols obsid,time]" data,clean
# Out:
# #  obsid                time
#                 162.0                13.10
#                1233.0                 14.0

# %%
find_chandra_obsid '18 33 34' '-10 34' inst=hrci download=n
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname                                          target
# 142       0.2  HRC-I NONE   30.3 2000-02-16 Calibration                                       G21.5-0.9
# 143       0.2  HRC-I NONE   13.8 1999-09-04 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 144       0.2  HRC-I NONE   30.0 2000-09-01 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1242      0.2  HRC-I NONE   14.6 1999-09-04 Calibration                                       G21.5-0.9
# 1298      0.2  HRC-I NONE    7.2 1999-09-04 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1406      0.2  HRC-I NONE   30.0 1999-10-25 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1555      0.2  HRC-I NONE    8.9 2001-03-09 Calibration "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2A]"
# 1556      0.2  HRC-I NONE   10.1 2001-07-13 Calibration "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2B]"
# 2867      0.2  HRC-I NONE   19.1 2002-03-12 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 2874      0.2  HRC-I NONE   19.8 2002-07-15 Calibration              "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 3694      0.2  HRC-I NONE   18.3 2003-05-15 Calibration                                       G21.5-0.9
# 3701      0.2  HRC-I NONE   18.6 2003-11-09 Calibration                                       G21.5-0.9
# 5167      0.2  HRC-I NONE   19.1 2004-03-25 Calibration                                        G21.5-09
# 6072      0.2  HRC-I NONE   19.0 2005-02-26 Calibration                                        G21.5-09
# 6742      0.2  HRC-I NONE   20.0 2006-02-21 Calibration                                        G21.5-09
# 8373      0.2  HRC-I NONE   20.0 2007-05-25 Calibration                                        G21.5-09
# 10648     0.2  HRC-I NONE   10.1 2009-02-17 Calibration                                        G21.5-09
# 13091     0.2  HRC-I NONE   10.1 2011-05-30 Calibration                                        G21.5-09
# 14262     0.2  HRC-I NONE   10.0 2012-08-10 Calibration                                        G21.5-09
# 16419     0.2  HRC-I NONE   10.1 2014-05-06 Calibration                                        G21.5-09

# %%
find_chandra_obsid 1843
# Out:
# # obsid  sepn   inst grat   time    obsdate      piname                                               target
# 142       0.0  HRC-I NONE   30.3 2000-02-16 Calibration                                            G21.5-0.9
# 143       0.0  HRC-I NONE   13.8 1999-09-04 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 144       0.0  HRC-I NONE   30.0 2000-09-01 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 146       0.0  HRC-S NONE   10.4 2000-02-16 Calibration        "G21.5-0.9 [HRC-S, Offsets=0,0,0 CENTER MCP]"
# 147       0.0  HRC-S NONE    9.7 1999-09-05 Calibration        "G21.5-0.9 [HRC-S, Offsets=0,0,0 CENTER MCP]"
# 148       0.0  HRC-S NONE   10.0 2000-08-31 Calibration        "G21.5-0.9 [HRC-S, Offsets=0,0,0 CENTER MCP]"
# 150       0.0  HRC-S NONE   10.3 2000-02-16 Calibration          "G21.5-0.9 [HRC-S, Offsets=-30,0,0 +Y MCP]"
# 151       0.0  HRC-S NONE    9.7 1999-09-05 Calibration          "G21.5-0.9 [HRC-S, Offsets=-20,0,0 +Y MCP]"
# 152       0.0  HRC-S NONE   10.4 2000-08-31 Calibration          "G21.5-0.9 [HRC-S, Offsets=-30,0,0 +Y MCP]"
# 154       0.0  HRC-S NONE   10.0 2000-02-16 Calibration           "G21.5-0.9 [HRC-S, Offsets=30,0,0 -Y MPC]"
# 155       0.0  HRC-S NONE   10.4 2000-08-31 Calibration           "G21.5-0.9 [HRC-S, Offsets=30,0,0 -Y MPC]"
# 158       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration "G21.5-0.9 [Chip I1, T=100, Offsets=-3,-5,0 Off-ax]"
# 159       0.0 ACIS-S NONE   14.8 1999-08-23 Calibration "G21.5-0.9 [Chip S3, T=100, Offsets=0,0,0 Std Cand]"
# 160       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration  "G21.5-0.9 [Chip I0, T=100, Offsets=5,-5,0 Off-ax]"
# 161       0.0 ACIS-I NONE    9.6 1999-08-25 Calibration   "G21.5-0.9 [Chip I2, T=100, Offsets=5,3,0 Off-ax]"
# 162       0.0 ACIS-I NONE   13.1 1999-08-27 Calibration "G21.5-0.9 [Chip I3, T=100, Offsets=-1,1,0 Std Can]"
# 163      23.5 ACIS-S NONE    9.9 1999-08-15 Calibration         "G21.5-0.9 [Chip S0, T=100, Offsets=23,0,0]"
# 164      15.0 ACIS-S NONE    9.6 1999-08-15 Calibration         "G21.5-0.9 [Chip S1, T=100, Offsets=15,0,0]"
# 165       0.0 ACIS-S NONE    9.6 1999-08-23 Calibration          "G21.5-0.9 [Chip S2, T=100, Offsets=6,0,0]"
# 166      10.5 ACIS-S NONE    9.9 1999-08-15 Calibration        "G21.5-0.9 [Chip S4, T=100, Offsets=-10,0,0]"
# 167      19.0 ACIS-S NONE    9.6 1999-08-15 Calibration        "G21.5-0.9 [Chip S5, T=100, Offsets=-19,0,0]"
# 1230      0.0 ACIS-S NONE   14.6 1999-08-23 Calibration "G21.5-0.9 [Chip S3, T=100, Offsets=0,0,0 Std Cand]"
# 1233      0.0 ACIS-I NONE   14.0 1999-11-05 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-1,1,0]"
# 1242      0.0  HRC-I NONE   14.6 1999-09-04 Calibration                                            G21.5-0.9
# 1267     19.0 ACIS-S NONE   12.8 1999-08-16 Calibration        "G21.5-0.9 [Chip S5, T=100, Offsets=-19,0,0]"
# 1298      0.0  HRC-I NONE    7.2 1999-09-04 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1406      0.0  HRC-I NONE   30.0 1999-10-25 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 1432      0.0 ACIS-S NONE    9.9 2000-03-01 Calibration         "G21.5-0.9 [Chip S0, T=120, Offsets=22,0,0]"
# 1433      0.0 ACIS-S NONE   15.0 1999-11-15 Calibration         "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,0]"
# 1434      0.0 ACIS-S NONE    9.7 1999-11-16 Calibration          "G21.5-0.9 [Chip S2, T=110, Offsets=6,0,0]"
# 1441      0.0 ACIS-I NONE    9.1 1999-11-15 Calibration         "G21.5-0.9 [Chip I0, T=110, Offsets=7,-6,0]"
# 1442      0.0 ACIS-I NONE    9.7 1999-11-15 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-3,-5,0]"
# 1443      0.0 ACIS-I NONE    9.7 1999-11-15 Calibration          "G21.5-0.9 [Chip I2, T=110, Offsets=5,3,0]"
# 1551      0.0 ACIS-I NONE    8.7 2001-03-08 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,0,2]"
# 1552      0.0 ACIS-I NONE    9.9 2001-07-13 Calibration     "G21.5-0.9[Chip I3, T=120, Offsets=-2.25,0,3.5]"
# 1553      0.0 ACIS-S NONE    9.7 2001-03-18 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 1554      0.0 ACIS-S NONE    9.1 2001-07-21 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 1555      0.0  HRC-I NONE    8.9 2001-03-09 Calibration      "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2A]"
# 1556      0.0  HRC-I NONE   10.1 2001-07-13 Calibration      "G21.5-0.9 [HRC-I, Offsets=0,0,0 Offsets=AO2B]"
# 1557      0.0  HRC-S NONE    8.5 2001-03-09 Calibration      "G21.5-0.9 [HRC-S, Offsets=0,0,0 Offsets=AO2A]"
# 1558      0.0  HRC-S NONE    8.9 2001-07-27 Calibration      "G21.5-0.9 [HRC-S, Offsets=0,0,0 Offsets=AO2B]"
# 1716      0.0 ACIS-S NONE    7.7 2000-05-23 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,3]"
# 1717      0.0 ACIS-S NONE    7.5 2000-05-23 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 1718      0.0 ACIS-S NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,-3]"
# 1719      0.0 ACIS-I NONE    7.7 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-7,0,-1]"
# 1720      0.0 ACIS-I NONE    7.5 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-5,0,-1]"
# 1721      0.0 ACIS-I NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-4,0,-1]"
# 1722      0.0 ACIS-I NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-2,0,-1]"
# 1723      0.0 ACIS-I NONE    7.6 2000-05-23 Calibration        "G21.5-0.9 [Chip I1, T=120, Offsets=-0,0,-1]"
# 1724      0.0 ACIS-I NONE    7.6 2000-05-24 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-5,0,2]"
# 1725      0.0 ACIS-I NONE    7.6 2000-05-24 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-4,0,2]"
# 1726      0.0 ACIS-I NONE    7.6 2000-05-24 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,0,2]"
# 1727      0.0 ACIS-S NONE    7.7 2000-05-24 Calibration          "G21.5-0.9 [Chip S2, T=120, Offsets=5,0,1]"
# 1728      0.0 ACIS-S NONE    7.5 2000-05-24 Calibration          "G21.5-0.9 [Chip S2, T=120, Offsets=5,0,0]"
# 1729      0.0 ACIS-S NONE    7.6 2000-05-24 Calibration          "G21.5-0.9 [Chip S2, T=120, Offsets=5,0,3]"
# 1769      0.0 ACIS-S NONE    7.4 2000-07-05 Calibration         "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,3]"
# 1770      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration         "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,0]"
# 1771      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip S3, T=110, Offsets=-1,0,-3]"
# 1772      0.0 ACIS-I NONE    7.4 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-7,0,-1]"
# 1773      0.0 ACIS-I NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-5,0,-1]"
# 1774      0.0 ACIS-I NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-4,0,-1]"
# 1775      0.0 ACIS-I NONE    7.2 2000-07-05 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-2,0,-1]"
# 1776      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration        "G21.5-0.9 [Chip I1, T=110, Offsets=-0,0,-1]"
# 1777      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-5,0,2]"
# 1778      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-4,0,2]"
# 1779      0.0 ACIS-I NONE    7.2 2000-07-06 Calibration         "G21.5-0.9 [Chip I3, T=110, Offsets=-2,0,2]"
# 1780      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration          "G21.5-0.9 [Chip S2, T=110, Offsets=5,0,1]"
# 1781      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration          "G21.5-0.9 [Chip S2, T=110, Offsets=5,0,0]"
# 1782      0.0 ACIS-S NONE    7.2 2000-07-05 Calibration         "G21.5-0.9 [Chip S2, T=110, Offsets=5,0,-3]"
# 1838      0.0 ACIS-S NONE    7.8 2000-09-02 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,1]"
# 1839      0.0 ACIS-S NONE    7.7 2000-09-02 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,2,-1]"
# 1840      0.0 ACIS-S NONE    7.7 2000-09-02 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,5,-4]"
# 1841      0.0 ACIS-I NONE    8.0 2000-09-01 Calibration        "G21.5-0.9 [Chip I3, T=120, Offsets=-1,10,5]"
# 1842      0.0 ACIS-I NONE    7.4 2000-09-02 Calibration        "G21.5-0.9 [Chip S3, T=120, Offsets=-1,15,0]"
# 1843      0.0 ACIS-I NONE    7.8 2000-09-02 Calibration       "G21.5-0.9 [Chip S3, T=120, Offsets=-1,20,-4]"
# 2755      0.1  HRC-S NONE   29.2 2002-11-12      Murray                                            G21.5-0.9
# 2867      0.0  HRC-I NONE   19.1 2002-03-12 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 2868      0.0  HRC-S NONE   18.9 2002-03-13 Calibration                   "G21.5-0.9 [HRC-S, Offsets=0,0,0]"
# 2872      0.0 ACIS-I NONE    9.8 2002-09-13 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,2,0]"
# 2873      0.0 ACIS-S NONE    9.8 2002-09-14 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 2874      0.0  HRC-I NONE   19.8 2002-07-15 Calibration                   "G21.5-0.9 [HRC-I, Offsets=0,0,0]"
# 2875      0.0  HRC-S NONE   19.7 2002-09-13 Calibration                   "G21.5-0.9 [HRC-S, Offsets=0,0,0]"
# 3473      0.0 ACIS-I NONE    9.3 2002-05-16 Calibration         "G21.5-0.9 [Chip I3, T=120, Offsets=-2,2,0]"
# 3474      0.0 ACIS-S NONE    9.3 2002-05-16 Calibration         "G21.5-0.9 [Chip S3, T=120, Offsets=-1,0,0]"
# 3692      0.0 ACIS-I NONE    9.2 2003-05-16 Calibration      "G21.5-0.9[Chip I3, T=120, Offsets=-2.5,2.5,0]"
# 3693      0.0 ACIS-S NONE    9.8 2003-05-16 Calibration        "G21.5-0.9[Chip S3, T=120, Offsets=-1.0,0,0]"
# 3694      0.0  HRC-I NONE   18.3 2003-05-15 Calibration                                            G21.5-0.9
# 3695      0.0  HRC-S NONE   18.9 2003-05-12 Calibration                                            G21.5-0.9
# 3699      0.0 ACIS-I NONE    9.7 2003-11-09 Calibration      "G21.5-0.9[Chip I3, T=120, Offsets=-2.5,2.5,0]"
# 3700      0.0 ACIS-S NONE    9.5 2003-11-09 Calibration        "G21.5-0.9[Chip S3, T=120, Offsets=-1.0,0,0]"
# 3701      0.0  HRC-I NONE   18.6 2003-11-09 Calibration                                            G21.5-0.9
# 3702      0.0  HRC-S NONE   19.2 2003-11-09 Calibration                                            G21.5-0.9
# 4353      0.0 ACIS-S NONE    9.4 2003-05-15 Calibration       "G21.5-0.9[Chip S3, T=120, Offsets=-1,5,11.7]"
# 4354      0.0 ACIS-I NONE    9.8 2003-05-20 Calibration       "G21.5-0.9[Chip S3, T=120, Offsets=-1,10,-17]"
# 4355      0.0 ACIS-I NONE    9.4 2003-05-20 Calibration        "G21.5-0.9[Chip S3, T=120, Offsets=-1,15,-2]"
# 5158      0.0 ACIS-I NONE   10.0 2005-02-26 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 5159      0.0 ACIS-S NONE    9.8 2004-10-27 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 5165      0.0 ACIS-I NONE    9.6 2004-03-26 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 5166      0.0 ACIS-S NONE   10.0 2004-03-14 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 5167      0.0  HRC-I NONE   19.1 2004-03-25 Calibration                                             G21.5-09
# 5168      0.0  HRC-S NONE    0.0 2004-03-26 Calibration                                             G21.5-09
# 6070      0.0 ACIS-I NONE    9.4 2005-02-26 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 6071      0.0 ACIS-S NONE    9.6 2005-02-26 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 6072      0.0  HRC-I NONE   19.0 2005-02-26 Calibration                                             G21.5-09
# 6073      0.0  HRC-S NONE   20.0 2005-03-18 Calibration                                             G21.5-09
# 6740      0.0 ACIS-I NONE    9.8 2006-02-21 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 6741      0.0 ACIS-S NONE    9.8 2006-02-22 Calibration                           G21.5-09[S3,-120,-1.0,0,0]
# 6742      0.0  HRC-I NONE   20.0 2006-02-21 Calibration                                             G21.5-09
# 6743      0.0  HRC-S NONE   19.9 2006-02-21 Calibration                                             G21.5-09
# 8371      0.0 ACIS-I NONE    9.9 2007-05-28 Calibration                         G21.5-09[I3,-120,-2.5,2.5,0]
# 8372      0.0 ACIS-S NONE   10.0 2007-05-25 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 8373      0.0  HRC-I NONE   20.0 2007-05-25 Calibration                                             G21.5-09
# 8374      0.0  HRC-S NONE   21.4 2007-05-25 Calibration                                             G21.5-09
# 9701      0.0 ACIS-S NONE   10.1 2008-05-26 Calibration                        G21.5-09[S2,-120,5.15,0,10.0]
# 9702      0.0 ACIS-S NONE   10.1 2008-05-27 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 10644     0.0 ACIS-S NONE    9.6 2009-05-29 Calibration                           G21.5-09[S2,-120,5.15,0,8]
# 10645     0.0 ACIS-S NONE    9.5 2009-05-29 Calibration                       G21.5-09[S2,-120,5.15,0,-2.61]
# 10646     0.0 ACIS-S NONE    9.5 2009-05-29 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 10647     0.0 ACIS-S NONE   10.1 2009-05-30 Calibration                            G21.5-09[S3,-120,1.0,0,0]
# 10648     0.0  HRC-I NONE   10.1 2009-02-17 Calibration                                             G21.5-09
# 13091     0.0  HRC-I NONE   10.1 2011-05-30 Calibration                                             G21.5-09
# 14262     0.0  HRC-I NONE   10.0 2012-08-10 Calibration                                             G21.5-09
# 14263     0.0 ACIS-S NONE    9.6 2012-08-08 Calibration                                             G21.5-09
# 14264     0.0 ACIS-I NONE    9.6 2012-08-10 Calibration                                             G21.5-09
# 16419     0.0  HRC-I NONE   10.1 2014-05-06 Calibration                                             G21.5-09
# 16420     0.0 ACIS-S NONE    9.6 2014-05-07 Calibration                                             G21.5-09
# 16421     0.0 ACIS-I NONE    9.6 2014-05-09 Calibration                                             G21.5-09
# 16570     0.0  HRC-S NONE   10.1 2014-04-25 Calibration                                             G21.5-09

# %% [markdown]
# # Cleanup

# %%
/bin/rm -f 1842 1843 459
