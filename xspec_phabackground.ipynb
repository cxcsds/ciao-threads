# %% [markdown]
# # xspec_phabackground

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 459

download_chandra_obsid 459 pha2
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   pha2     fits        1 Mb  ####################          < 1 s  27538.4 kb/s

# %%
cp -fv 459/primary/*pha2.fits.gz .
gunzip -f *pha2.fits.gz
chmod +w *pha2.fits
# Out:
# '459/primary/acisf00459N004_pha2.fits.gz' -> './acisf00459N004_pha2.fits.gz'

# %% [markdown]
# ## Run script

# %%
tg_bkg acisf00459N004_pha2.fits
# Out:
# Input file has been changed, BACKFILE keyword has been added

# %%
dmlist acisf00459N004_pha2.fits_bkg cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block SPECTRUM
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   SPEC_NUM                          Int2           1:32767              Spectrum Number
#    2   TG_M                              Int2           -62:62               Diffraction order (m)
#    3   TG_PART                           Int2           0:99                 Spectral component (HEG, MEG, LEG, HESF parts)
#    4   TG_SRCID                          Int2           1:32767              Source ID, output by detect
#    5   X                    pixel        Real4          0.50:    65534.50    X sky coord of source
#    6   Y                    pixel        Real4          0.50:    65534.50    Y sky coord of source
# ...

# %%
/bin/ls -1 *pha2*
# Out:
# acisf00459N004_pha2.fits
# acisf00459N004_pha2.fits_bkg

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 459 
/bin/rm -f acisf00459N004_pha2.fits
