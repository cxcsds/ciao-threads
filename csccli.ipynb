# %% [markdown]
# # csccli

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 5794 *.tsv CXOJ*

# %% [markdown]
# ## search_csc

# %%
search_csc "SDSS J1004+4112" radius=1 outfile=none
# Out:
# search_csc
#              pos = SDSS J1004+4112
#           radius = 1
#          outfile = none
#          radunit = arcmin
#          columns = INDEF
#      sensitivity = no
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 8 rows returned by query
# 8 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	sepn	obsid
# CXO J100433.6+411307	151.14038   	 41.21862   	0.47'	 5794
# CXO J100433.8+411234	151.14101   	 41.20962   	0.25'	 5794
# CXO J100434.0+411248	151.14199   	 41.21356   	0.19'	 5794
# CXO J100434.2+411220	151.14285   	 41.20560   	0.39'	 5794
# CXO J100434.2+411243	151.14249   	 41.21205   	0.14'	 5794
# CXO J100434.8+411239	151.14509   	 41.21087   	0.063'	 5794
# CXO J100434.9+411242	151.14557   	 41.21185   	0.00018'	 5794
# ...

# %%
search_csc "SDSS J1004+4112" radius=1 outfile=none verbose=2
# Out:
# search_csc
#              pos = SDSS J1004+4112
#           radius = 1
#          outfile = none
#          radunit = arcmin
#          columns = INDEF
#      sensitivity = no
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 2
#          clobber = no
#             mode = ql
#
# Resolved SDSS J1004+4112 to ra=151.14557 dec=41.21185
#
# 8 rows returned by query
# 8 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	sepn	obsid
# CXO J100433.6+411307	151.14038   	 41.21862   	0.47'	 5794
# CXO J100433.8+411234	151.14101   	 41.20962   	0.25'	 5794
# CXO J100434.0+411248	151.14199   	 41.21356   	0.19'	 5794
# CXO J100434.2+411220	151.14285   	 41.20560   	0.39'	 5794
# CXO J100434.2+411243	151.14249   	 41.21205   	0.14'	 5794
# CXO J100434.8+411239	151.14509   	 41.21087   	0.063'	 5794
# ...

# %%
search_csc "SDSS J1004+4112" radius=1 outfile= \
  columns=m.significance,m.flux_aper_b,o.theta,o.cnts_aper_b
# Out:
# search_csc
#              pos = SDSS J1004+4112
#           radius = 1
#          outfile =
#          radunit = arcmin
#          columns = m.significance,m.flux_aper_b,o.theta,o.cnts_aper_b
#      sensitivity = no
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 8 rows returned by query
# 8 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	sepn	obsid	significance	flux_aper_b	theta	cnts_aper_b
# CXO J100433.6+411307	151.14038   	 41.21862   	0.47'	 5794	   5.11	3.577e-15	    0.842	         32
# CXO J100433.8+411234	151.14101   	 41.20962   	0.25'	 5794	  35.73	9.788e-14	    1.382	       1314
# CXO J100434.0+411248	151.14199   	 41.21356   	0.19'	 5794	  26.72	6.189e-14	    1.149	        762
# ...

# %%
search_csc "SDSS J1004+4112" radius=10 radunit=arcsec out=
# Out:
# search_csc
#              pos = SDSS J1004+4112
#           radius = 10
#          outfile =
#          radunit = arcsec
#          columns = INDEF
#      sensitivity = no
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 3 rows returned by query
# 3 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	sepn	obsid
# CXO J100434.2+411243	151.14249   	 41.21205   	8.4"	 5794
# CXO J100434.8+411239	151.14509   	 41.21087   	3.8"	 5794
# CXO J100434.9+411242	151.14557   	 41.21185   	0.011"	 5794
#
# If you use this data, please cite Evans et al 2010, ApJS 189, 37

# %%
search_csc "SDSS J1004+4112" radius=1 outfile=sdss_j1004+4112.tsv  columns=m.significance,m.flux_aper_b,o.theta,o.cnts_aper_b verbose=0

# %%
cat sdss_j1004+4112.tsv
# Out:
# #Column	sepn	(E9.6)		(.sepn)	[""]	[]
# #Column	name	(A20)	Source name in the format 'CXO Jhhmmss.s +/- ddmmss'	(master_source.name)	[""]	[meta.id;meta.main]
# #Column	ra	(F9.5)	Source position, ICRS right ascension	(master_source.ra)	["deg"]	[pos.eq.ra;meta.main]
# #Column	dec	(F9.5)	Source position, ICRS declination	(master_source.dec)	["deg"]	[pos.eq.dec;meta.main]
# #Column	instrument	(A4)	Instrument used for the observation; 'ACIS' or 'HRC'	(obi_source.instrument)	[""]	[meta.id;instr]
# #Column	obsid	(I5)	Observation identifier	(obi_source.obsid)	[""]	[meta.id;obs.param]
# #Column	obi	(I3)	Observation interval number	(obi_source.obi)	[""]	[meta.id;obs.param]
# #Column	region_id	(I4)	Source region identifier	(obi_source.region_id)	[""]	[meta.id;instr.fov]
# #Column	match_type	(A1)	A Source Observation association with a single Master Source is unique ('u'), with more than one is ambiguous ('a').	(master_obi_assoc.match_type)	[""]	[meta.code]
# ...

# %%
dmlist "sdss_j1004+4112.tsv[opt kernel=text/tsv]" cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block sdss_j1004+4112.tsv
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   sepn                              Real4          -Inf:+Inf
#    2   name                              String[20]                          Source name in the format 'CXO Jhhmmss.s +/- ddmmss'
#    3   ra                   deg          Real4          -Inf:+Inf            Source position, ICRS right ascension
#    4   dec                  deg          Real4          -Inf:+Inf            Source position, ICRS declination
#    5   instrument                        String[4]                           Instrument used for the observation; 'ACIS' or 'HRC'
#    6   obsid                             Int4           -                    Observation identifier
# ...

# %% [markdown]
# ## obsid_search_csc

# %%
obsid_search_csc 5794 out="" column=o.theta,o.cnts_aper_b,o.ks_prob_b,o.flux_significance_b
# Out:
# obsid_search_csc
#            obsid = 5794
#          outfile =
#          columns = o.theta,o.cnts_aper_b,o.ks_prob_b,o.flux_significance_b
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 35 rows returned by query
# 35 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	obsid	theta	cnts_aper_b	ks_prob_b	flux_significance_b
# CXO J100414.3+411259	151.05970   	 41.21640   	 5794	    3.734	         94	    0.706	     9.07
# CXO J100415.2+411155	151.06340   	 41.19878   	 5794	    3.994	        155	    0.891	    11.94
# CXO J100416.7+410813	151.06969   	 41.13700   	 5794	    6.549	         54	    0.985	     5.92
# CXO J100416.8+411203	151.07000   	 41.20109   	 5794	    3.667	         27	    0.172	     3.27
# ...

# %%
find_chandra_obsid "SDSS J1004+4112"
# Out:
# # obsid  sepn   inst grat   time    obsdate   piname            target
# 5794      0.2 ACIS-S NONE   80.1 2005-01-01    Inada "SDSS J1004+4112"
# 11546     0.1 ACIS-S NONE    6.0 2010-03-08 Kochanek     SDSS1004+4112
# 11547     0.1 ACIS-S NONE    6.0 2010-06-19 Kochanek     SDSS1004+4112
# 11548     0.1 ACIS-S NONE    6.0 2010-09-23 Kochanek     SDSS1004+4112
# 11549     0.1 ACIS-S NONE    6.0 2011-01-30 Kochanek     SDSS1004+4112
# 14495     0.1 ACIS-S NONE   24.7 2013-01-27 Kochanek     SDSS1004+4112
# 14496     0.1 ACIS-S NONE   24.7 2013-03-01 Kochanek     SDSS1004+4112
# 14497     0.1 ACIS-S NONE   24.1 2013-10-05 Kochanek     SDSS1004+4112
# 14498     0.1 ACIS-S NONE   23.8 2013-11-16 Kochanek     SDSS1004+4112
# 14499     0.1 ACIS-S NONE   23.3 2014-04-29 Kochanek     SDSS1004+4112
# 14500     0.1 ACIS-S NONE   24.7 2014-06-02 Kochanek     SDSS1004+4112

# %% [markdown]
# ## Retrieve data

# %%
search_csc "SDSS J1004+4112" radius=10 radunit=arcsec outfile= download=all verbose=1
# Out:
# search_csc
#              pos = SDSS J1004+4112
#           radius = 10
#          outfile =
#          radunit = arcsec
#          columns = INDEF
#      sensitivity = no
#         download = all
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 3 rows returned by query
# 3 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	sepn	obsid
# CXO J100434.2+411243	151.14249   	 41.21205   	8.4"	 5794
# CXO J100434.8+411239	151.14509   	 41.21087   	3.8"	 5794
# CXO J100434.9+411242	151.14557   	 41.21185   	0.011"	 5794
#
# If you use this data, please cite Evans et al 2010, ApJS 189, 37
#
# Retrieving files for obsid_obi 05794_000
# Retrieved file .//CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016_pha3.fits
# ...

# %%
find CXOJ100434.* -type f -print
# Out:
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016_pha3.fits.gz
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016b_psf3.fits.gz
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016_regevt3.fits.gz
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016_rmf3.fits.gz
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016b_regexp3.fits.gz
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016_arf3.fits.gz
# CXOJ100434.2+411243/05794_000/r0016/acisf05794_000N001_r0016b_lc3.fits.gz
# CXOJ100434.8+411239/05794_000/r0014/acisf05794_000N001_r0014_pha3.fits.gz
# CXOJ100434.8+411239/05794_000/r0014/acisf05794_000N001_r0014b_psf3.fits.gz
# CXOJ100434.8+411239/05794_000/r0014/acisf05794_000N001_r0014_regevt3.fits.gz
# CXOJ100434.8+411239/05794_000/r0014/acisf05794_000N001_r0014_rmf3.fits.gz
# CXOJ100434.8+411239/05794_000/r0014/acisf05794_000N001_r0014b_regexp3.fits.gz
# ...

# %%
obsid_search_csc 5794 download=all outfile="" col=INDEF filetypes=evt,pha,arf,rmf verb=1
# Out:
# obsid_search_csc
#            obsid = 5794
#          outfile =
#          columns = INDEF
#         download = all
#             root = ./
#            bands = broad,wide
#        filetypes = evt,pha,arf,rmf
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 35 rows returned by query
# 35 Different Master Source(s).
# 1 Different Observation(s).
#
# name                	ra          	dec         	obsid
# CXO J100414.3+411259	151.05970   	 41.21640   	 5794
# CXO J100415.2+411155	151.06340   	 41.19878   	 5794
# CXO J100416.7+410813	151.06969   	 41.13700   	 5794
# CXO J100416.8+411203	151.07000   	 41.20109   	 5794
# CXO J100419.0+411029	151.07921   	 41.17494   	 5794
# CXO J100419.4+411024	151.08110   	 41.17341   	 5794
# CXO J100420.3+411414	151.08464   	 41.23730   	 5794
# CXO J100425.2+411159	151.10539   	 41.19974   	 5794
# CXO J100428.3+411128	151.11827   	 41.19136   	 5794
# ...

# %%
find 5794 -type f -print | sort -r | head -20
# Out:
# 5794/acisf05794_000N001_evt3.fits.gz
# 5794/CXOJ100459.0+411059/acisf05794_000N001_r0036_rmf3.fits.gz
# 5794/CXOJ100459.0+411059/acisf05794_000N001_r0036_pha3.fits.gz
# 5794/CXOJ100459.0+411059/acisf05794_000N001_r0036_arf3.fits.gz
# 5794/CXOJ100452.2+411616/acisf05794_000N001_r0042_rmf3.fits.gz
# 5794/CXOJ100452.2+411616/acisf05794_000N001_r0042_pha3.fits.gz
# 5794/CXOJ100452.2+411616/acisf05794_000N001_r0042_arf3.fits.gz
# 5794/CXOJ100451.6+410831/acisf05794_000N001_r0035_rmf3.fits.gz
# 5794/CXOJ100451.6+410831/acisf05794_000N001_r0035_pha3.fits.gz
# 5794/CXOJ100451.6+410831/acisf05794_000N001_r0035_arf3.fits.gz
# 5794/CXOJ100446.4+411447/acisf05794_000N001_r0023_rmf3.fits.gz
# 5794/CXOJ100446.4+411447/acisf05794_000N001_r0023_pha3.fits.gz
# 5794/CXOJ100446.4+411447/acisf05794_000N001_r0023_arf3.fits.gz
# 5794/CXOJ100446.0+411215/acisf05794_000N001_r0010_rmf3.fits.gz
# 5794/CXOJ100446.0+411215/acisf05794_000N001_r0010_pha3.fits.gz
# ...

# %% [markdown]
# ## View table

# %%
obsid_search_csc 5794 out=5794.tsv column=o.theta,o.cnts_aper_b,o.ks_prob_b,o.flux_significance_b verb=0 clob+

# %%
dmlist "5794.tsv[opt kernel=text/tsv]" cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block 5794.tsv
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   name                              String[20]                          Source name in the format 'CXO Jhhmmss.s +/- ddmmss'
#    2   ra                   deg          Real4          -Inf:+Inf            Source position, ICRS right ascension
#    3   dec                  deg          Real4          -Inf:+Inf            Source position, ICRS declination
#    4   instrument                        String[4]                           Instrument used for the observation; 'ACIS' or 'HRC'
#    5   obsid                             Int4           -                    Observation identifier
#    6   obi                               Int4           -                    Observation interval number
# ...

# %%
dmstat "5794.tsv[opt kernel=text/tsv][cols ks_prob_b]" sig+ med+
# Out:
# ks_prob_b
#     min:	0 	      @:	23
#     max:	1 	      @:	14
#    mean:	0.4827142852
#  median:	0.48300001025
#   sigma:	0.29924729863
#     sum:	16.894999982
#    good:	35
#    null:	0

# %%
dmsort "5794.tsv[opt kernel=text/tsv]" sort_by_theta.fits theta cl+

# %%
prism "5794.tsv[opt kernel=text/tsv]" &
sleep 5
xpaset -p prism quit
# Out:
# [1] 30048
# [1]+  Done                    prism "5794.tsv[opt kernel=text/tsv]"

# %%
ds9 5794/acisf05794_000N001_evt3.fits.gz -log -bin factor 2 -catalog import tsv 5794.tsv  \
  -saveimage png ds9.png -quit

display < ds9.png

# %% [markdown]
# ## Upper Limits

# %%
search_csc "10 04 34.2 +41 12 40" radius=1 radunit=arcsec outfile=
# Out:
# search_csc
#              pos = 10 04 34.2 +41 12 40
#           radius = 1
#          outfile =
#          radunit = arcsec
#          columns = INDEF
#      sensitivity = no
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
#
# 0 rows returned by query
# 0 Different Master Source(s).
# 0 Different Observation(s).

# %%
search_csc "10 04 34.2 +41 12 40" radius=1 radunit=arcsec outfile= sensitivity=yes
# Out:
# search_csc
#              pos = 10 04 34.2 +41 12 40
#           radius = 1
#          outfile =
#          radunit = arcsec
#          columns = INDEF
#      sensitivity = yes
#         download = none
#             root = ./
#            bands = broad,wide
#        filetypes = regevt,pha,arf,rmf,lc,psf,regexp
#          catalog = csc1
#          verbose = 1
#          clobber = no
#             mode = ql
#
# CSC Sensitivity for position: 151.1426,41.2112
#   broad band : 3.3601e-7 [photons/cm^2/s]
#   wide band : NaN [photons/cm^2/s]
#
# 0 rows returned by query
# 0 Different Master Source(s).
# 0 Different Observation(s).

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 5794 CXOJ*/
