# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 1843
download_chandra_obsid 1843 evt2
mv -fv 1843/primary/*evt2.fits.gz .
gunzip -f *fits.gz
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       17 Mb  ####################          < 1 s  42880.4 kb/s
#
# '1843/primary/acisf01843N004_evt2.fits.gz' -> './acisf01843N004_evt2.fits.gz'

# %%
dmkeypar acisf01843N004_evt2.fits ASCDSVER echo+
# Out:
# 10.9.2

# %%
dmkeypar acisf01843N004_evt2.fits CALDBVER echo+
# Out:
# 4.9.4

# %%
check_ciao_caldb --latest
# Out:
# CALDB environment variable = /export/CIAOT/ciaot_install/20211019/ciao-4.14/CALDB
#         which is a link to = /data/chandra_caldb/ciao4.12
#              CALDB version = 4.9.6
#              release date  = 2021-09-21T16:00:00 UTC
# CALDB query completed successfully.
# The CALDB installation is up to date.

# %%
dmlist "$CALDB/docs/chandra/caldb_version/caldb_version.fits[cols caldb_ver]" data
# Out:
#
# --------------------------------------------------------------------------------
# Data for Table Block CALDBVER
# --------------------------------------------------------------------------------
#
# ROW    CALDB_VER
#
#      1 4.1.0
#      2 4.1.1
#      3 4.1.2
#      4 4.1.3
#      5 4.1.4
#      6 4.2.0
#      7 4.1.5
#      8 4.2.1
#      9 4.1.6
#     10 4.1.7
#     11 4.2.2
#     12 4.3.0
#     13 4.3.1
#     14 4.4.0
#     15 4.4.1
#     16 4.4.2
#     17 4.4.3
#     18 4.4.4
#     19 4.4.5
#     20 4.4.6
#     21 4.4.6.1
#     22 4.4.7
#     23 4.4.8
#     24 4.4.9
#     25 4.4.10
#     26 4.5.0
#     27 4.5.1
#     28 4.5.1.1
#     29 4.5.2
#     30 4.5.3
#     31 4.5.4
#     32 4.5.5
#     33 4.5.5.1
#     34 4.5.6
#     35 4.5.7
#     36 4.5.8
#     37 4.5.9
#     38 4.6.0
#     39 4.6.1
#     40 4.6.1.1
#     41 4.6.2
#     42 4.6.3
#     43 4.6.4
#     44 4.6.5
#     45 4.6.6
#     46 4.6.7
#     47 4.6.8
#     48 4.6.9
#     49 4.6.10a
#     50 4.7.0
#     51 4.7.1
# ...

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 1843
/bin/rm -f acisf*
