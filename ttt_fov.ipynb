# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# The CIAO setup for this window has changed from
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3
# To:
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 5794
download_chandra_obsid 5794 fov
mv -fv 5794/primary/*fov1.fits.gz acis_fov.fits.gz
gunzip -f acis_fov.fits.gz
# Out:
# Downloading files for ObsId 5794, total size is 5 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        5 Kb  ####################          < 1 s  776.2 kb/s
#
# `5794/primary/acisf05794_000N003_fov1.fits.gz' -> `acis_fov.fits.gz'

# %% [markdown]
# ## Check cel coords inside FOV file

# %%
dmlist acis_fov.fits cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block FOV
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   POS(X,Y)[13]         pixel        Real8(13)      -Inf:+Inf            Position
#    2   SHAPE                             String[16]                          Region shape type
#    3   R[2]                 pixel        Real8(2)       -Inf:+Inf            Radius
#    4   ROTANG[2]            pixel        Real8(2)       -Inf:+Inf            Angle
#    5   COMPONENT                         Int2           -                    Component number
#    6   CCD_ID                            Int2           -                    CCD ID
#
# --------------------------------------------------------------------------------
# World Coord Transforms for Columns in Table Block FOV
# --------------------------------------------------------------------------------
#
# ColNo    Name
# 1:    EQPOS(RA ) = (+151.1396)[degree] +TAN[(-0.000136667)* (POS(X)-(+4096.50))]
#            (DEC)   (+41.2327 )              (+0.000136667)  (   (Y) (+4096.50))

# %%
cat << EOM > p1.py
from region import *
myreg = regParse("region(acis_fov.fits)")
regPrintRegion(myreg)
EOM

python p1.py
# Out:
# 1	Polygon(3444.12,3350.85,3444.27,3350.72,4448.91,3189.87,4486.69,3189.9,4486.87,3189.98,4647.91,4196.68,4647.91,4233.94,4647.88,4234.05,3643.1,4394.84,3605.42,4394.88,3605.36,4394.78,3444.12,3388.11,3444.12,3350.85) (Flag_Coord: Unknown) (Flag_Radius: Unknown)

# %%
cat << EOM > p2.py
from region import *
mycelreg = regParse("region(acis_fov.fits[cols eqpos,shape,component])")
regPrintRegion(mycelreg)
EOM

python p2.py
# Out:
# 1	Polygon(151.258,41.1307,151.258,41.1307,151.076,41.1087,151.069,41.1087,151.069,41.1087,151.039,41.2463,151.039,41.2514,151.039,41.2514,151.222,41.2734,151.229,41.2734,151.229,41.2734,151.258,41.1358,151.258,41.1307) (Flag_Coord: Unknown) (Flag_Radius: Unknown)

# %%
dmlist acis_fov.fits header,clean | grep PNT
# Out:
# RA_PNT                     151.1395864022 [deg]     Pointing RA
# DEC_PNT                     41.2326566497 [deg]     Pointing Dec
# ROLL_PNT                    99.0636885982 [deg]     Pointing Roll

# %%
cat << EOM > p3.py
from region import *
mycelreg = regParse("region(acis_fov.fits[cols eqpos,shape,component])")
pointing=regInsideRegion(mycelreg, 151.1395864022, 41.2326566497 )
random=regInsideRegion(mycelreg, 145.2, 45.0 )
print("Is _PNT inside FOV? {}".format(pointing))
print("Is random location inside FOV? {}".format(random))
EOM

python p3.py
# Out:
# Is _PNT inside FOV? 1
# Is random location inside FOV? 0

# %% [markdown]
# ## Checking several FOVs

# %%
find_chandra_obsid "SDSS J1004+4112"
# Out:
# # obsid  sepn   inst grat   time    obsdate   piname            target
# 5794      0.2 ACIS-S NONE   80.1 2005-01-01    Inada "SDSS J1004+4112"
# 11546     0.1 ACIS-S NONE    6.0 2010-03-08 Kochanek     SDSS1004+4112
# 11547     0.1 ACIS-S NONE    6.0 2010-06-19 Kochanek     SDSS1004+4112
# 11548     0.1 ACIS-S NONE    6.0 2010-09-23 Kochanek     SDSS1004+4112
# 11549     0.1 ACIS-S NONE    6.0 2011-01-30 Kochanek     SDSS1004+4112
# 14495     0.1 ACIS-S NONE   24.7 2013-01-27 Kochanek     SDSS1004+4112
# 14496     0.1 ACIS-S NONE   24.7 2013-03-01 Kochanek     SDSS1004+4112
# 14497     0.1 ACIS-S NONE   24.1 2013-10-05 Kochanek     SDSS1004+4112
# 14498     0.1 ACIS-S NONE   23.8 2013-11-16 Kochanek     SDSS1004+4112
# 14499     0.1 ACIS-S NONE   23.3 2014-04-29 Kochanek     SDSS1004+4112
# 14500     0.1 ACIS-S NONE   24.7 2014-06-02 Kochanek     SDSS1004+4112

# %%
/bin/rm -rf 5794 11546 11547 11548 11549 14495 14496 14499 14500
download_chandra_obsid 5794,11546,11547,11548,11549,14495,14496,14499,14500 fov
# Out:
# Downloading files for ObsId 5794, total size is 5 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        5 Kb  ####################          < 1 s  864.4 kb/s
#
# Downloading files for ObsId 11546, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  968.1 kb/s
#
# Downloading files for ObsId 11547, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  969.6 kb/s
#
# Downloading files for ObsId 11548, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  982.7 kb/s
#
# Downloading files for ObsId 11549, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  1001.2 kb/s
#
# Downloading files for ObsId 14495, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  947.6 kb/s
#
# Downloading files for ObsId 14496, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  888.9 kb/s
#
# Downloading files for ObsId 14499, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  886.2 kb/s
#
# Downloading files for ObsId 14500, total size is 6 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   fov      fits        6 Kb  ####################          < 1 s  990.5 kb/s

# %%
cat << EOM > p4.py
from ciao_contrib.region.check_fov import FOVFiles
regions=FOVFiles("*/primary/*fov1.fits.gz")
print(regions)
print("----")
inside=regions.inside(151.25426, 41.090654)
print(inside)
EOM

python p4.py
# Out:
# List of FOV files
#   14495/primary/acisf14495_000N002_fov1.fits.gz
#   14496/primary/acisf14496_000N002_fov1.fits.gz
#   11549/primary/acisf11549_000N002_fov1.fits.gz
#   11546/primary/acisf11546_000N002_fov1.fits.gz
#   5794/primary/acisf05794_000N003_fov1.fits.gz
#   14499/primary/acisf14499_000N002_fov1.fits.gz
#   11547/primary/acisf11547_000N002_fov1.fits.gz
#   11548/primary/acisf11548_000N002_fov1.fits.gz
#   14500/primary/acisf14500_000N002_fov1.fits.gz
#
# ----
# ['14495/primary/acisf14495_000N002_fov1.fits.gz', '11549/primary/acisf11549_000N002_fov1.fits.gz', '11548/primary/acisf11548_000N002_fov1.fits.gz']
