# %% [markdown]
# # Auxillary Lookup Tables

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 214
download_chandra_obsid 214 evt2,cntr_img
# Out:
# Downloading files for ObsId 214, total size is 29 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   cntr_img fits      316 Kb  ####################          < 1 s  3487.1 kb/s
#   cntr_img jpg       731 Kb  ####################          < 1 s  3189.6 kb/s
#   evt2     fits       28 Mb  ####################            1 s  24482.0 kb/s
#
#       Total download size for ObsId 214 = 29 Mb
#       Total download time for ObsId 214 = 1 s

# %%
plist ximage_lut
# Out:
# Parameters for /export/ciao-4.11/contrib/param/ximage_lut.par
#
# #
# # Color Lookup Tables extracted from NASA XImage package
# #
# #    http://heasarc.gsfc.nasa.gov/xanadu/ximage/ximage.html
# #
# # converted to the ".lut" format used by ds9, chips, and dmimg2jpg
# #
# #
#            (bb = ${ASCDS_CONTRIB}/data/bb.lut -> /export/ciao-4.11/contrib/data/bb.lut) Color Lookup Table
#         (blue1 = ${ASCDS_CONTRIB}/data/blue1.lut -> /export/ciao-4.11/contrib/data/blue1.lut) Color Lookup Table
#         (blue2 = ${ASCDS_CONTRIB}/data/blue2.lut -> /export/ciao-4.11/contrib/data/blue2.lut) Color Lookup Table
#         (blue3 = ${ASCDS_CONTRIB}/data/blue3.lut -> /export/ciao-4.11/contrib/data/blue3.lut) Color Lookup Table
#         (blue4 = ${ASCDS_CONTRIB}/data/blue4.lut -> /export/ciao-4.11/contrib/data/blue4.lut) Color Lookup Table
#     (bluebase1 = ${ASCDS_CONTRIB}/data/bluebase1.lut -> /export/ciao-4.11/contrib/data/bluebase1.lut) Color Lookup Table
#     (bluebase2 = ${ASCDS_CONTRIB}/data/bluebase2.lut -> /export/ciao-4.11/contrib/data/bluebase2.lut) Color Lookup Table
#     (bluebase3 = ${ASCDS_CONTRIB}/data/bluebase3.lut -> /export/ciao-4.11/contrib/data/bluebase3.lut) Color Lookup Table
#     (bluebase4 = ${ASCDS_CONTRIB}/data/bluebase4.lut -> /export/ciao-4.11/contrib/data/bluebase4.lut) Color Lookup Table
#     (bluebase5 = ${ASCDS_CONTRIB}/data/bluebase5.lut -> /export/ciao-4.11/contrib/data/bluebase5.lut) Color Lookup Table
#     (bluebase6 = ${ASCDS_CONTRIB}/data/bluebase6.lut -> /export/ciao-4.11/contrib/data/bluebase6.lut) Color Lookup Table
#     (bluebase7 = ${ASCDS_CONTRIB}/data/bluebase7.lut -> /export/ciao-4.11/contrib/data/bluebase7.lut) Color Lookup Table
#     (bluebase8 = ${ASCDS_CONTRIB}/data/bluebase8.lut -> /export/ciao-4.11/contrib/data/bluebase8.lut) Color Lookup Table
#     (bluebase9 = ${ASCDS_CONTRIB}/data/bluebase9.lut -> /export/ciao-4.11/contrib/data/bluebase9.lut) Color Lookup Table
#        (bluyel = ${ASCDS_CONTRIB}/data/bluyel.lut -> /export/ciao-4.11/contrib/data/bluyel.lut) Color Lookup Table
#         (brown = ${ASCDS_CONTRIB}/data/brown.lut -> /export/ciao-4.11/contrib/data/brown.lut) Color Lookup Table
#      (eyellow1 = ${ASCDS_CONTRIB}/data/eyellow1.lut -> /export/ciao-4.11/contrib/data/eyellow1.lut) Color Lookup Table
#         (gray1 = ${ASCDS_CONTRIB}/data/gray1.lut -> /export/ciao-4.11/contrib/data/gray1.lut) Color Lookup Table
#         (gray2 = ${ASCDS_CONTRIB}/data/gray2.lut -> /export/ciao-4.11/contrib/data/gray2.lut) Color Lookup Table
#        (green1 = ${ASCDS_CONTRIB}/data/green1.lut -> /export/ciao-4.11/contrib/data/green1.lut) Color Lookup Table
#        (green2 = ${ASCDS_CONTRIB}/data/green2.lut -> /export/ciao-4.11/contrib/data/green2.lut) Color Lookup Table
#        (green3 = ${ASCDS_CONTRIB}/data/green3.lut -> /export/ciao-4.11/contrib/data/green3.lut) Color Lookup Table
#        (green4 = ${ASCDS_CONTRIB}/data/green4.lut -> /export/ciao-4.11/contrib/data/green4.lut) Color Lookup Table
#        (green5 = ${ASCDS_CONTRIB}/data/green5.lut -> /export/ciao-4.11/contrib/data/green5.lut) Color Lookup Table
#        (green6 = ${ASCDS_CONTRIB}/data/green6.lut -> /export/ciao-4.11/contrib/data/green6.lut) Color Lookup Table
#        (green7 = ${ASCDS_CONTRIB}/data/green7.lut -> /export/ciao-4.11/contrib/data/green7.lut) Color Lookup Table
#        (green8 = ${ASCDS_CONTRIB}/data/green8.lut -> /export/ciao-4.11/contrib/data/green8.lut) Color Lookup Table
#        (green9 = ${ASCDS_CONTRIB}/data/green9.lut -> /export/ciao-4.11/contrib/data/green9.lut) Color Lookup Table
#       (invgray = ${ASCDS_CONTRIB}/data/invgray.lut -> /export/ciao-4.11/contrib/data/invgray.lut) Color Lookup Table
#      (invgray1 = ${ASCDS_CONTRIB}/data/invgray1.lut -> /export/ciao-4.11/contrib/data/invgray1.lut) Color Lookup Table
#       (invspec = ${ASCDS_CONTRIB}/data/invspec.lut -> /export/ciao-4.11/contrib/data/invspec.lut) Color Lookup Table
#         (pink1 = ${ASCDS_CONTRIB}/data/pink1.lut -> /export/ciao-4.11/contrib/data/pink1.lut) Color Lookup Table
#         (pink2 = ${ASCDS_CONTRIB}/data/pink2.lut -> /export/ciao-4.11/contrib/data/pink2.lut) Color Lookup Table
#         (pink3 = ${ASCDS_CONTRIB}/data/pink3.lut -> /export/ciao-4.11/contrib/data/pink3.lut) Color Lookup Table
#         (pink4 = ${ASCDS_CONTRIB}/data/pink4.lut -> /export/ciao-4.11/contrib/data/pink4.lut) Color Lookup Table
#     (pinkbase1 = ${ASCDS_CONTRIB}/data/pinkbase1.lut -> /export/ciao-4.11/contrib/data/pinkbase1.lut) Color Lookup Table
#     (pinkbase2 = ${ASCDS_CONTRIB}/data/pinkbase2.lut -> /export/ciao-4.11/contrib/data/pinkbase2.lut) Color Lookup Table
#     (pinkbase3 = ${ASCDS_CONTRIB}/data/pinkbase3.lut -> /export/ciao-4.11/contrib/data/pinkbase3.lut) Color Lookup Table
#     (pinkbase4 = ${ASCDS_CONTRIB}/data/pinkbase4.lut -> /export/ciao-4.11/contrib/data/pinkbase4.lut) Color Lookup Table
#     (pinkbase5 = ${ASCDS_CONTRIB}/data/pinkbase5.lut -> /export/ciao-4.11/contrib/data/pinkbase5.lut) Color Lookup Table
#         (purby = ${ASCDS_CONTRIB}/data/purby.lut -> /export/ciao-4.11/contrib/data/purby.lut) Color Lookup Table
#       (purple1 = ${ASCDS_CONTRIB}/data/purple1.lut -> /export/ciao-4.11/contrib/data/purple1.lut) Color Lookup Table
#       (purple2 = ${ASCDS_CONTRIB}/data/purple2.lut -> /export/ciao-4.11/contrib/data/purple2.lut) Color Lookup Table
#       (purple3 = ${ASCDS_CONTRIB}/data/purple3.lut -> /export/ciao-4.11/contrib/data/purple3.lut) Color Lookup Table
#       (purple4 = ${ASCDS_CONTRIB}/data/purple4.lut -> /export/ciao-4.11/contrib/data/purple4.lut) Color Lookup Table
#         (puryb = ${ASCDS_CONTRIB}/data/puryb.lut -> /export/ciao-4.11/contrib/data/puryb.lut) Color Lookup Table
#          (red1 = ${ASCDS_CONTRIB}/data/red1.lut -> /export/ciao-4.11/contrib/data/red1.lut) Color Lookup Table
#          (red2 = ${ASCDS_CONTRIB}/data/red2.lut -> /export/ciao-4.11/contrib/data/red2.lut) Color Lookup Table
#      (redbase1 = ${ASCDS_CONTRIB}/data/redbase1.lut -> /export/ciao-4.11/contrib/data/redbase1.lut) Color Lookup Table
#      (redbase2 = ${ASCDS_CONTRIB}/data/redbase2.lut -> /export/ciao-4.11/contrib/data/redbase2.lut) Color Lookup Table
#      (redbase3 = ${ASCDS_CONTRIB}/data/redbase3.lut -> /export/ciao-4.11/contrib/data/redbase3.lut) Color Lookup Table
#      (redbase4 = ${ASCDS_CONTRIB}/data/redbase4.lut -> /export/ciao-4.11/contrib/data/redbase4.lut) Color Lookup Table
#      (redbase5 = ${ASCDS_CONTRIB}/data/redbase5.lut -> /export/ciao-4.11/contrib/data/redbase5.lut) Color Lookup Table
#      (redbase6 = ${ASCDS_CONTRIB}/data/redbase6.lut -> /export/ciao-4.11/contrib/data/redbase6.lut) Color Lookup Table
#          (rgb4 = ${ASCDS_CONTRIB}/data/rgb4.lut -> /export/ciao-4.11/contrib/data/rgb4.lut) Color Lookup Table
#          (rgb6 = ${ASCDS_CONTRIB}/data/rgb6.lut -> /export/ciao-4.11/contrib/data/rgb6.lut) Color Lookup Table
#      (spectrum = ${ASCDS_CONTRIB}/data/spectrum.lut -> /export/ciao-4.11/contrib/data/spectrum.lut) Color Lookup Table
#           (vt1 = ${ASCDS_CONTRIB}/data/vt1.lut -> /export/ciao-4.11/contrib/data/vt1.lut) Color Lookup Table
#           (vt2 = ${ASCDS_CONTRIB}/data/vt2.lut -> /export/ciao-4.11/contrib/data/vt2.lut) Color Lookup Table
#           (vt3 = ${ASCDS_CONTRIB}/data/vt3.lut -> /export/ciao-4.11/contrib/data/vt3.lut) Color Lookup Table
#           (vt4 = ${ASCDS_CONTRIB}/data/vt4.lut -> /export/ciao-4.11/contrib/data/vt4.lut) Color Lookup Table
#           (vt5 = ${ASCDS_CONTRIB}/data/vt5.lut -> /export/ciao-4.11/contrib/data/vt5.lut) Color Lookup Table
#           (vt6 = ${ASCDS_CONTRIB}/data/vt6.lut -> /export/ciao-4.11/contrib/data/vt6.lut) Color Lookup Table
#           (vt7 = ${ASCDS_CONTRIB}/data/vt7.lut -> /export/ciao-4.11/contrib/data/vt7.lut) Color Lookup Table
#       (yellow1 = ${ASCDS_CONTRIB}/data/yellow1.lut -> /export/ciao-4.11/contrib/data/yellow1.lut) Color Lookup Table
#            (yy = ${ASCDS_CONTRIB}/data/yy.lut -> /export/ciao-4.11/contrib/data/yy.lut) Color Lookup Table
#          (mode = ql)

# %%
plist imagej_lut
# Out:
# Parameters for /export/ciao-4.11/contrib/param/imagej_lut.par
#
# #
# #
# # Color Lookup Tables extracted from the NIH's ImageJ package
# #
# #  http://rsbweb.nih.gov/ij/
# #
# # converted to the ".lut" format used by ds9, chips, and dmimg2jpg
# #
#      (000-gray = ${ASCDS_CONTRIB}/data/000-gray.lut -> /export/ciao-4.11/contrib/data/000-gray.lut) Color Lookup Table
#      (001-fire = ${ASCDS_CONTRIB}/data/001-fire.lut -> /export/ciao-4.11/contrib/data/001-fire.lut) Color Lookup Table
#  (002-spectrum = ${ASCDS_CONTRIB}/data/002-spectrum.lut -> /export/ciao-4.11/contrib/data/002-spectrum.lut) Color Lookup Table
#       (003-ice = ${ASCDS_CONTRIB}/data/003-ice.lut -> /export/ciao-4.11/contrib/data/003-ice.lut) Color Lookup Table
#     (004-phase = ${ASCDS_CONTRIB}/data/004-phase.lut -> /export/ciao-4.11/contrib/data/004-phase.lut) Color Lookup Table
#    (005-random = ${ASCDS_CONTRIB}/data/005-random.lut -> /export/ciao-4.11/contrib/data/005-random.lut) Color Lookup Table
#     (16_colors = ${ASCDS_CONTRIB}/data/16_colors.lut -> /export/ciao-4.11/contrib/data/16_colors.lut) Color Lookup Table
#      (16_equal = ${ASCDS_CONTRIB}/data/16_equal.lut -> /export/ciao-4.11/contrib/data/16_equal.lut) Color Lookup Table
#      (16_ramps = ${ASCDS_CONTRIB}/data/16_ramps.lut -> /export/ciao-4.11/contrib/data/16_ramps.lut) Color Lookup Table
#     (20_colors = ${ASCDS_CONTRIB}/data/20_colors.lut -> /export/ciao-4.11/contrib/data/20_colors.lut) Color Lookup Table
#     (32_colors = ${ASCDS_CONTRIB}/data/32_colors.lut -> /export/ciao-4.11/contrib/data/32_colors.lut) Color Lookup Table
#       (5_ramps = ${ASCDS_CONTRIB}/data/5_ramps.lut -> /export/ciao-4.11/contrib/data/5_ramps.lut) Color Lookup Table
# (6_reserved_colors = ${ASCDS_CONTRIB}/data/6_reserved_colors.lut -> /export/ciao-4.11/contrib/data/6_reserved_colors.lut) Color Lookup Table
#      (6_shades = ${ASCDS_CONTRIB}/data/6_shades.lut -> /export/ciao-4.11/contrib/data/6_shades.lut) Color Lookup Table
#         (amber = ${ASCDS_CONTRIB}/data/amber.lut -> /export/ciao-4.11/contrib/data/amber.lut) Color Lookup Table
#        (auxctq = ${ASCDS_CONTRIB}/data/auxctq.lut -> /export/ciao-4.11/contrib/data/auxctq.lut) Color Lookup Table
#   (blue_orange = ${ASCDS_CONTRIB}/data/blue_orange.lut -> /export/ciao-4.11/contrib/data/blue_orange.lut) Color Lookup Table
# (blue_orange_icb = ${ASCDS_CONTRIB}/data/blue_orange_icb.lut -> /export/ciao-4.11/contrib/data/blue_orange_icb.lut) Color Lookup Table
#         (brain = ${ASCDS_CONTRIB}/data/brain.lut -> /export/ciao-4.11/contrib/data/brain.lut) Color Lookup Table
#      (brgbcmyw = ${ASCDS_CONTRIB}/data/brgbcmyw.lut -> /export/ciao-4.11/contrib/data/brgbcmyw.lut) Color Lookup Table
#         (cells = ${ASCDS_CONTRIB}/data/cells.lut -> /export/ciao-4.11/contrib/data/cells.lut) Color Lookup Table
#        (cequal = ${ASCDS_CONTRIB}/data/cequal.lut -> /export/ciao-4.11/contrib/data/cequal.lut) Color Lookup Table
#      (cmy-cyan = ${ASCDS_CONTRIB}/data/cmy-cyan.lut -> /export/ciao-4.11/contrib/data/cmy-cyan.lut) Color Lookup Table
#   (cmy-magneta = ${ASCDS_CONTRIB}/data/cmy-magneta.lut -> /export/ciao-4.11/contrib/data/cmy-magneta.lut) Color Lookup Table
#    (cmy-yellow = ${ASCDS_CONTRIB}/data/cmy-yellow.lut -> /export/ciao-4.11/contrib/data/cmy-yellow.lut) Color Lookup Table
#           (cmy = ${ASCDS_CONTRIB}/data/cmy.lut -> /export/ciao-4.11/contrib/data/cmy.lut) Color Lookup Table
#          (cold = ${ASCDS_CONTRIB}/data/cold.lut -> /export/ciao-4.11/contrib/data/cold.lut) Color Lookup Table
#       (cti_ras = ${ASCDS_CONTRIB}/data/cti_ras.lut -> /export/ciao-4.11/contrib/data/cti_ras.lut) Color Lookup Table
#         (edges = ${ASCDS_CONTRIB}/data/edges.lut -> /export/ciao-4.11/contrib/data/edges.lut) Color Lookup Table
#        (gem-16 = ${ASCDS_CONTRIB}/data/gem-16.lut -> /export/ciao-4.11/contrib/data/gem-16.lut) Color Lookup Table
#       (gem-256 = ${ASCDS_CONTRIB}/data/gem-256.lut -> /export/ciao-4.11/contrib/data/gem-256.lut) Color Lookup Table
#          (gold = ${ASCDS_CONTRIB}/data/gold.lut -> /export/ciao-4.11/contrib/data/gold.lut) Color Lookup Table
#    (gyr_centre = ${ASCDS_CONTRIB}/data/gyr_centre.lut -> /export/ciao-4.11/contrib/data/gyr_centre.lut) Color Lookup Table
#         (heart = ${ASCDS_CONTRIB}/data/heart.lut -> /export/ciao-4.11/contrib/data/heart.lut) Color Lookup Table
#           (hue = ${ASCDS_CONTRIB}/data/hue.lut -> /export/ciao-4.11/contrib/data/hue.lut) Color Lookup Table
#  (hue_ramps_08 = ${ASCDS_CONTRIB}/data/hue_ramps_08.lut -> /export/ciao-4.11/contrib/data/hue_ramps_08.lut) Color Lookup Table
#  (hue_ramps_16 = ${ASCDS_CONTRIB}/data/hue_ramps_16.lut -> /export/ciao-4.11/contrib/data/hue_ramps_16.lut) Color Lookup Table
#         (icool = ${ASCDS_CONTRIB}/data/icool.lut -> /export/ciao-4.11/contrib/data/icool.lut) Color Lookup Table
#          (iman = ${ASCDS_CONTRIB}/data/iman.lut -> /export/ciao-4.11/contrib/data/iman.lut) Color Lookup Table
#   (invert_gray = ${ASCDS_CONTRIB}/data/invert_gray.lut -> /export/ciao-4.11/contrib/data/invert_gray.lut) Color Lookup Table
#    (isocontour = ${ASCDS_CONTRIB}/data/isocontour.lut -> /export/ciao-4.11/contrib/data/isocontour.lut) Color Lookup Table
#      (log_down = ${ASCDS_CONTRIB}/data/log_down.lut -> /export/ciao-4.11/contrib/data/log_down.lut) Color Lookup Table
#        (log_up = ${ASCDS_CONTRIB}/data/log_up.lut -> /export/ciao-4.11/contrib/data/log_up.lut) Color Lookup Table
#         (mixed = ${ASCDS_CONTRIB}/data/mixed.lut -> /export/ciao-4.11/contrib/data/mixed.lut) Color Lookup Table
#     (neon-blue = ${ASCDS_CONTRIB}/data/neon-blue.lut -> /export/ciao-4.11/contrib/data/neon-blue.lut) Color Lookup Table
#    (neon-green = ${ASCDS_CONTRIB}/data/neon-green.lut -> /export/ciao-4.11/contrib/data/neon-green.lut) Color Lookup Table
#  (neon-magenta = ${ASCDS_CONTRIB}/data/neon-magenta.lut -> /export/ciao-4.11/contrib/data/neon-magenta.lut) Color Lookup Table
#      (neon-red = ${ASCDS_CONTRIB}/data/neon-red.lut -> /export/ciao-4.11/contrib/data/neon-red.lut) Color Lookup Table
#        (pastel = ${ASCDS_CONTRIB}/data/pastel.lut -> /export/ciao-4.11/contrib/data/pastel.lut) Color Lookup Table
#      (rgb-blue = ${ASCDS_CONTRIB}/data/rgb-blue.lut -> /export/ciao-4.11/contrib/data/rgb-blue.lut) Color Lookup Table
#     (rgb-green = ${ASCDS_CONTRIB}/data/rgb-green.lut -> /export/ciao-4.11/contrib/data/rgb-green.lut) Color Lookup Table
#       (rgb-red = ${ASCDS_CONTRIB}/data/rgb-red.lut -> /export/ciao-4.11/contrib/data/rgb-red.lut) Color Lookup Table
#         (royal = ${ASCDS_CONTRIB}/data/royal.lut -> /export/ciao-4.11/contrib/data/royal.lut) Color Lookup Table
#         (sepia = ${ASCDS_CONTRIB}/data/sepia.lut -> /export/ciao-4.11/contrib/data/sepia.lut) Color Lookup Table
#       (siemens = ${ASCDS_CONTRIB}/data/siemens.lut -> /export/ciao-4.11/contrib/data/siemens.lut) Color Lookup Table
#         (smart = ${ASCDS_CONTRIB}/data/smart.lut -> /export/ciao-4.11/contrib/data/smart.lut) Color Lookup Table
# (split_blackblue_redwhite = ${ASCDS_CONTRIB}/data/split_blackblue_redwhite.lut -> /export/ciao-4.11/contrib/data/split_blackblue_redwhite.lut) Color Lookup Table
# (split_blackwhite_ge = ${ASCDS_CONTRIB}/data/split_blackwhite_ge.lut -> /export/ciao-4.11/contrib/data/split_blackwhite_ge.lut) Color Lookup Table
# (split_blackwhite_warmmetal = ${ASCDS_CONTRIB}/data/split_blackwhite_warmmetal.lut -> /export/ciao-4.11/contrib/data/split_blackwhite_warmmetal.lut) Color Lookup Table
# (split_bluered_warmmetal = ${ASCDS_CONTRIB}/data/split_bluered_warmmetal.lut -> /export/ciao-4.11/contrib/data/split_bluered_warmmetal.lut) Color Lookup Table
#    (system_lut = ${ASCDS_CONTRIB}/data/system_lut.lut -> /export/ciao-4.11/contrib/data/system_lut.lut) Color Lookup Table
#       (thal_16 = ${ASCDS_CONTRIB}/data/thal_16.lut -> /export/ciao-4.11/contrib/data/thal_16.lut) Color Lookup Table
#      (thal_256 = ${ASCDS_CONTRIB}/data/thal_256.lut -> /export/ciao-4.11/contrib/data/thal_256.lut) Color Lookup Table
#      (thallium = ${ASCDS_CONTRIB}/data/thallium.lut -> /export/ciao-4.11/contrib/data/thallium.lut) Color Lookup Table
#    (topography = ${ASCDS_CONTRIB}/data/topography.lut -> /export/ciao-4.11/contrib/data/topography.lut) Color Lookup Table
#     (unionjack = ${ASCDS_CONTRIB}/data/unionjack.lut -> /export/ciao-4.11/contrib/data/unionjack.lut) Color Lookup Table
#         (vivid = ${ASCDS_CONTRIB}/data/vivid.lut -> /export/ciao-4.11/contrib/data/vivid.lut) Color Lookup Table
#        (warhol = ${ASCDS_CONTRIB}/data/warhol.lut -> /export/ciao-4.11/contrib/data/warhol.lut) Color Lookup Table
#          (mode = ql)

# %% [markdown]
# ## ds9

# %%
ds9 -iconify 214/primary/*img2.fits.gz -smooth -cmap load $ASCDS_CONTRIB/data/heart.lut \
  -log -export png ds9.png &
sleep 10
xpaset -p ds9 quit

# %%
display < ds9.png

# %% [markdown]
# ## matplotlib

# %%
aconvolve 214/primary/*img2.fits.gz - "lib:gaus(2,5,5,3,3)" meth=slide | \
dmimgcalc - none img_sm_asinh.fits op="imgout=asinh(img1)" clob+

# %%
cat << EOM > cmds.py
import paramio as pio
from pycrates import read_file
import matplotlib.pylab as plt
from matplotlib.colors import ListedColormap

heart_lut = pio.pget("imagej_lut", "heart")
tab = open(heart_lut,"r").readlines()
rgb = [ x.strip().split() for x in tab if not x.startswith("#")]
rgba= [ [float(x[0]),float(x[1]),float(x[2]),1.0] for x in rgb ]
heart_lut_cmap = ListedColormap(rgba)

img = read_file('img_sm_asinh.fits')
imgvals = img.get_image().values
plt.imshow(imgvals, origin='lower', cmap=heart_lut_cmap)
plt.savefig("matplotlib.png")
EOM

python cmds.py

# %%
display < matplotlib.png

# %% [markdown]
# ## dmimg2jpg

# %%
punlearn dmimg2jpg
dmimg2jpg infile=img_sm_asinh.fits outfile=dmimg2jpg.jpg \
  lutfile=")imagej_lut.heart"  \
  scalefun=linear mode=h clobber=yes

# %%
display < dmimg2jpg.jpg

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 214
