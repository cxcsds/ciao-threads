# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
find_chandra_obsid "Mrk 975"
# Out:
# # obsid  sepn   inst grat   time    obsdate    piname    target
# 13899     0.0 ACIS-S NONE   10.0 2012-10-28 Mushotzky "Mrk 975"
# 15575     0.0 ACIS-S NONE    9.1 2012-11-02 Mushotzky "Mrk 975"

# %%
/bin/rm -rf 13899 15575
download_chandra_obsid 13899,15575 --exclude vvref,osol,eph1,evt2
# Out:
# Downloading files for ObsId 13899, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   asol     fits        2 Mb  ####################          < 1 s  16209.8 kb/s
#   mtl      fits        2 Mb  ####################          < 1 s  19191.1 kb/s
#   evt1     fits      632 Kb  ####################          < 1 s  6211.0 kb/s
#   stat     fits      311 Kb  ####################          < 1 s  1770.1 kb/s
#   aqual    fits      176 Kb  ####################          < 1 s  6913.0 kb/s
#   bias     fits       67 Kb  ####################          < 1 s  497.9 kb/s
#   cntr_img jpg        59 Kb  ####################          < 1 s  1555.7 kb/s
#   vv       pdf        38 Kb  ####################          < 1 s  906.4 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1345.5 kb/s
#   cntr_img fits       17 Kb  ####################          < 1 s  414.7 kb/s
#   full_img fits       12 Kb  ####################          < 1 s  269.8 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  284.0 kb/s
#   fov      fits        5 Kb  ####################          < 1 s  157.9 kb/s
#   flt      fits        5 Kb  ####################          < 1 s  138.0 kb/s
#   bpix     fits        4 Kb  ####################          < 1 s  101.8 kb/s
#   msk      fits        4 Kb  ####################          < 1 s  211.0 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  113.2 kb/s
#   full_img jpg         2 Kb  ####################          < 1 s  43.0 kb/s
#
#       Total download size for ObsId 13899 = 6 Mb
#       Total download time for ObsId 13899 = 1 s
#
# Downloading files for ObsId 15575, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   asol     fits        2 Mb  ####################          < 1 s  12986.8 kb/s
#   mtl      fits        2 Mb  ####################          < 1 s  15185.2 kb/s
#   evt1     fits      571 Kb  ####################          < 1 s  13154.1 kb/s
#   stat     fits      282 Kb  ####################          < 1 s  4234.0 kb/s
#   aqual    fits      162 Kb  ####################          < 1 s  7889.4 kb/s
#   bias     fits       66 Kb  ####################          < 1 s  1544.2 kb/s
#   cntr_img jpg        58 Kb  ####################          < 1 s  1283.0 kb/s
#   vv       pdf        38 Kb  ####################          < 1 s  283.7 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  262.3 kb/s
#   cntr_img fits       17 Kb  ####################          < 1 s  152.5 kb/s
#   full_img fits       12 Kb  ####################          < 1 s  216.2 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  92.9 kb/s
#   fov      fits        5 Kb  ####################          < 1 s  66.1 kb/s
#   flt      fits        5 Kb  ####################          < 1 s  34.7 kb/s
#   bpix     fits        4 Kb  ####################          < 1 s  36.3 kb/s
#   msk      fits        4 Kb  ####################          < 1 s  38.4 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  72.8 kb/s
#   full_img jpg         2 Kb  ####################          < 1 s  8.6 kb/s
#
#       Total download size for ObsId 15575 = 5 Mb
#       Total download time for ObsId 15575 = 2 s

# %%
chandra_repro 13899,15575 outdir=""
# Out:
# Running chandra_repro
# version: 14 September 2021
#
# WARNING: "set_ardlib=yes" cannot be used with multiple input directories.  Changing to "no"
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/fluxes_multiobi/13899'
#
# No boresight correction update to asol file is needed.
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/fluxes_multiobi/13899/repro/acisf13899_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/fluxes_multiobi/13899/repro
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/fluxes_multiobi/15575'
#
# No boresight correction update to asol file is needed.
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/fluxes_multiobi/15575/repro/acisf15575_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/fluxes_multiobi/15575/repro

# %%
dmdiff 13899/repro/*evt2.fits 15575/repro/*evt2.fits data- | \
  egrep 'SIM_|_NOM|_PNT|DATE-OBS|MJD_OBS|OBS_ID|FP_TEMP'
# Out:
# DATE-OBS Values are not equal                   2012-10-28T12:07:12  2012-11-02T20:41:44
# SIM_Z    Values are not equal                   -190.14006604987  -190.14258036517  -0.00251432 (+0.00132%)
# RA_PNT   Values are not equal                    18.460110371879  18.460525677222  +0.000415305 (+0.00225%)
# DEC_PNT  Values are not equal                    13.273523446552  13.272951427789  -0.000572019 (-0.00431%)
# ROLL_PNT Values are not equal                    278.15394087308  278.15381775507  -0.000123118 (-4.43e-05%)
# RA_NOM   Values are not equal                    18.460110371879  18.460525677222  +0.000415305 (+0.00225%)
# DEC_NOM  Values are not equal                    13.273523446552  13.272951427789  -0.000572019 (-0.00431%)
# ROLL_NOM Values are not equal                    278.15394087308  278.15381775507  -0.000123118 (-4.43e-05%)
# OBS_ID   Values are not equal                              13899  15575

# %%
ds9 -tile -log \
  13899/repro/acisf13899_repro_evt2.fits \
  -zoom to 8 -pan to 01:13:51.0426 +13:16:17.594 fk5 \
  15575/repro/acisf15575_repro_evt2.fits \
  -zoom to 8 -pan to 01:13:51.0426 +13:16:17.594 fk5 \
  -saveimage png simple_01.png &

sleep 10
xpaset -p ds9 quit
display < simple_01.png
# Out:
# [1] 51541
# [1]+  Done                    ds9 -tile -log 13899/repro/acisf13899_repro_evt2.fits -zoom to 8 -pan to 01:13:51.0426 +13:16:17.594 fk5 15575/repro/acisf15575_repro_evt2.fits -zoom to 8 -pan to 01:13:51.0426 +13:16:17.594 fk5 -saveimage png simple_01.png

# %%
dmstat 13899/repro/acisf13899_repro_evt2.fits'[energy=500:7000,sky=circle(01:13:51.0436,+13:16:17.594,4")][bin sky=1]' \
      centroid=yes verb=0  
pget dmstat out_cntrd_phys
x=$(stk_read_num ")dmstat.out_cntrd_phys" 1 echo+)
y=$(stk_read_num ")dmstat.out_cntrd_phys" 2 echo+)
punlearn dmcoords
dmcoords 13899/repro/acisf13899_repro_evt2.fits op=sky x=$x y=$y celfmt=hms v=0
pget dmcoords ra dec
# Out:
# 4077.8910965,4082.5180297
# 01:13:51.053
# +13:16:17.80

# %%
dmstat 15575/repro/acisf15575_repro_evt2.fits'[energy=500:7000,sky=circle(01:13:51.0436,+13:16:17.594,4")][bin sky=1]' \
      centroid=yes verb=0 
pget dmstat out_cntrd_phys
x=$(stk_read_num ")dmstat.out_cntrd_phys" 1 echo+)
y=$(stk_read_num ")dmstat.out_cntrd_phys" 2 echo+)
punlearn dmcoords
dmcoords 15575/repro/acisf15575_repro_evt2.fits op=sky x=$x y=$y celfmt=hms v=0
pget dmcoords ra dec
# Out:
# 4080.5849903,4086.5903161
# 01:13:51.062
# +13:16:17.74

# %%
merge_obs 13899/repro,15575/repro out=merge/ bin=1 band=broad psfecf=0.9 clob+
# Out:
# Running merge_obs
# Version: 23 February 2021
#
# Found 13899/repro/acisf13899_repro_evt2.fits
# Found 15575/repro/acisf15575_repro_evt2.fits
# Verifying 2 observations.
# Using CSC ACIS broad science energy band.
# Calculating new tangent point.
# New tangent point: RA=1h 13m 50.476s Dec=13d 16' 23.65"
#
# Observations to be reprojected:
#
#   Obsid  Obs Date   Exp    DETNAM     SIM_Z    FP   Sepn   PA
#                    (ks)                (mm)    (K)   (')  (deg)
# ---------------------------------------------------------------
# 1 13899 2012-10-28  10.0 ACIS-7      -190.140 153.3  < 3"   -35
# 2 15575 2012-11-02   9.1 ACIS-7      -190.143 153.3  < 3"  +145
#
# Running tasks in parallel with 4 processors.
# Reprojecting 2 event files to a common tangent point.
# Merging reprojected events files to merge/merged_evt.fits
#
# Calculating the output grid
#
# The merged images will have 312 by 1070 pixels, a pixel size of 0.492 arcsec,
#     and cover x=3962.5:4274.5:1, y=3852.5:4922.5:1.
#
# Creating the fluxed images for 2 observations in parallel.
# Creating aspect histogram for obsid 13899
# Creating aspect histogram for obsid 15575
# Creating instrument map for obsid 15575
# Creating instrument map for obsid 13899
# Creating exposure map for obsid 13899
# Creating exposure map for obsid 15575
# Thresholding data for obsid 15575
# Exposure-correcting image for obsid 15575
# Thresholding data for obsid 13899
# Creating PSF map for obsid 15575
# Exposure-correcting image for obsid 13899
# Creating PSF map for obsid 13899
#
# Combining 2 observations.
#
# The following files were created:
#
# The co-added clipped counts image is:
#      merge/broad_thresh.img
#
# The co-added clipped exposure map is:
#      merge/broad_thresh.expmap
#
# The combined PSF map is:
#      merge/broad_thresh.psfmap
#
# The co-added exposure-corrected image is:
#      merge/broad_flux.img
#
# Warning: the merged event file merge/merged_evt.fits
#    should not be used to create ARF/RMF/exposure maps because
#       the RA_NOM keyword varies by 0.0004 (limit is 0.0003)
#       the DEC_NOM keyword varies by 0.0006 (limit is 0.0003)

# %%
ds9 -log merge/broad_thresh.img \
  -pan to 01:13:51.0436 +13:16:17.594 wcs \
  -zoom to 4 -scale limits 0 25 \
  -region command 'fk5;circle(01:13:51.0436,+13:16:17.594,4")' \
  -saveimage png simple_02.png &

sleep 10
xpaset -p ds9 quit
display < simple_02.png
# Out:
# [1] 52041
# [1]+  Done                    ds9 -log merge/broad_thresh.img -pan to 01:13:51.0436 +13:16:17.594 wcs -zoom to 4 -scale limits 0 25 -region command 'fk5;circle(01:13:51.0436,+13:16:17.594,4")' -saveimage png simple_02.png

# %%
punlearn wavdetect 
pset wavdetect \
  infile=merge/broad_thresh.img \
  expfile=merge/broad_thresh.expmap \
  psffile=merge/broad_thresh.psfmap \
  outfile=merge/wav.src \
  scell=merge/wav.cell defnbkg=merge/wav.nbk imagef=merge/wav.recon \
  scale="1.4 2 4" mode=h clob+
  
wavdetect mode=h

# %%
dmlist merge/wav.src counts
# Out:
# 2

# %%
ds9 -log merge/broad_thresh.img -region merge/wav.src -block to 2 \
  -saveimage png simple_03.png &

sleep 10
xpaset -p ds9 quit
display < simple_03.png
# Out:
# [1] 52271
# [1]+  Done                    ds9 -log merge/broad_thresh.img -region merge/wav.src -block to 2 -saveimage png simple_03.png

# %%
dmlist merge/wav.src"[cols x,y,ra,dec][#row=1]" data,clean
# Out:
# #  POS(X,Y)                                 RA                   DEC
#       4079.2460881935      4084.6097676624        18.4627407642        13.2716124274

# %%
rr=`dmkeypar merge/wav.src ra echo+`
dd=`dmkeypar merge/wav.src dec echo+`
echo $rr $dd
prop_precess from j/deg to j/hms p0 eval $rr $dd
# Out:
# 18.4627407641533 13.271612427391
# 01 13 51.06 +13 16 17.80

# %%
dmstat 'merge/broad_thresh.img[sky=circle(01:13:51.0436,+13:16:17.594,4")]' cen+ v=0
pget dmstat out_cntrd_phys
x=$(stk_read_num ")dmstat.out_cntrd_phys" 1 echo+)
y=$(stk_read_num ")dmstat.out_cntrd_phys" 2 echo+)
punlearn dmcoords 
dmcoords merge/broad_thresh.img op=sky x=$x y=$y celfmt=hms verb=0
pget dmcoords ra dec
# Out:
# 4079.2495379,4084.5799445
# 01:13:51.057
# +13:16:17.79

# %%
/bin/ls */repro/*evt2.fits > evt.lis
cat evt.lis
# Out:
# 13899/repro/acisf13899_repro_evt2.fits
# 15575/repro/acisf15575_repro_evt2.fits
# 18898/repro/acisf18898_repro_evt2.fits
# 20056/repro/acisf20056_repro_evt2.fits

# %%
punlearn srcflux
srcflux \
  infile=@evt.lis \
  out=sf1/out \
  srcreg="" bkgreg="" \
  pos="01:13:51.048,+13:16:17.84" \
  psfmethod=arfcorr bkgresp=no conf=0.68 \
  mode=h clob+
# Out:
# srcflux
#           infile = @evt.lis
#              pos = 01:13:51.048,+13:16:17.84
#          outroot = sf1/out
#            bands = default
#           srcreg =
#           bkgreg =
#          bkgresp = no
#        psfmethod = arfcorr
#          psffile =
#             conf = 0.68
#          binsize = 1
#          rmffile =
#          arffile =
#            model = xspowerlaw.pow1
#        paramvals = pow1.PhoIndex=2.0
#         absmodel = xsphabs.abs1
#        absparams = abs1.nH=%GAL%
#            abund = angr
#          fovfile =
#         asolfile =
#          mskfile =
#         bpixfile =
#          dtffile =
#          ecffile = CALDB
#         parallel = yes
#            nproc = INDEF
#           tmpdir = ./
#      random_seed = -1
#          clobber = yes
#          verbose = 1
#             mode = h
#
# Processing OBI 001
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf1/out_obi001_0001_broad_rates.par
# Running eff2evt for sf1/out_obi001_broad_0001_src.dat
# Running eff2evt for sf1/out_obi001_broad_0001_bkg.dat
# Making response files for sf1/out_obi001_0001
# Running modeflux for region 1
# Using GAL=0.0392 for source 1
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 002
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf1/out_obi002_0001_broad_rates.par
# Running eff2evt for sf1/out_obi002_broad_0001_src.dat
# Making response files for sf1/out_obi002_0001
# Running eff2evt for sf1/out_obi002_broad_0001_bkg.dat
# Running modeflux for region 1
# Using GAL=0.0392 for source 1
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 003
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf1/out_obi003_0001_broad_rates.par
# Running eff2evt for sf1/out_obi003_broad_0001_src.dat
# Making response files for sf1/out_obi003_0001
# Running eff2evt for sf1/out_obi003_broad_0001_bkg.dat
# An error occurred while running 'fluximage':
#   Running fluximage
#   Version: 23 February 2021
#
#   # fluximage (23 February 2021): ERROR There are no events in 18898/repro/acisf18898_repro_evt2.fits[sky=rectangle(-1.0,-1.0,1.0,1.0)]
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 004
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf1/out_obi004_0001_broad_rates.par
# Running eff2evt for sf1/out_obi004_broad_0001_src.dat
# Running eff2evt for sf1/out_obi004_broad_0001_bkg.dat
# Making response files for sf1/out_obi004_0001
# An error occurred while running 'fluximage':
#   Running fluximage
#   Version: 23 February 2021
#
#   # fluximage (23 February 2021): ERROR There are no events in 20056/repro/acisf20056_repro_evt2.fits[sky=rectangle(-1.0,-1.0,1.0,1.0)]
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Combining count rates
# Combining spectra and running model flux for each source
# Running modeflux for region 1
# Using GAL=0.0392 for source 1
#
#
# Summary of source fluxes in OBI 001
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           0.123 c/s (0.119,0.127)
#                               Flux           2.32E-12 erg/cm2/s (2.25E-12,2.4E-12)
#                               Mod.Flux       8.92E-13 erg/cm2/s (8.64E-13,9.19E-13)
#                               Unabs Mod.Flux 9.51E-13 erg/cm2/s (9.22E-13,9.8E-13)
#
#
#
# Summary of source fluxes in OBI 002
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           0.104 c/s (0.1,0.108)
#                               Flux           1.87E-12 erg/cm2/s (1.81E-12,1.94E-12)
#                               Mod.Flux       7.55E-13 erg/cm2/s (7.28E-13,7.81E-13)
#                               Unabs Mod.Flux 8.05E-13 erg/cm2/s (7.77E-13,8.33E-13)
#
#
#
# Summary of source fluxes in OBI 003
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           NAN c/s (NAN,NAN)
#  Outside FOV                  Flux           NAN erg/cm2/s (NAN,NAN)
#                               Mod.Flux       NAN erg/cm2/s (NAN,NAN)
#                               Unabs Mod.Flux NAN erg/cm2/s (NAN,NAN)
#
#
#
# Summary of source fluxes in OBI 004
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           NAN c/s (NAN,NAN)
#  Outside FOV                  Flux           NAN erg/cm2/s (NAN,NAN)
#                               Mod.Flux       NAN erg/cm2/s (NAN,NAN)
#                               Unabs Mod.Flux NAN erg/cm2/s (NAN,NAN)
#
#
#
# Summary of merged source fluxes
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           0.114 c/s (0.111,0.117)
#   NumObi=2                    Mod.Flux       8.26E-13 erg/cm2/s (8.07E-13,8.45E-13)
#                               Unabs Mod.Flux 8.81E-13 erg/cm2/s (8.61E-13,9.02E-13)

# %%
ds9 -tile -log \
  13899/repro/acisf13899_repro_evt2.fits \
  -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 \
  -region sf1/out_obi001_0001_srcreg.fits \
  15575/repro/acisf15575_repro_evt2.fits \
  -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 \
  -region sf1/out_obi002_0001_srcreg.fits \
  -saveimage simple_04.png &
  
sleep 10
xpaset -p ds9 quit
display < simple_04.png
# Out:
# [1] 53833
# [1]+  Done                    ds9 -tile -log 13899/repro/acisf13899_repro_evt2.fits -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 -region sf1/out_obi001_0001_srcreg.fits 15575/repro/acisf15575_repro_evt2.fits -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 -region sf1/out_obi002_0001_srcreg.fits -saveimage simple_04.png

# %%
punlearn srcflux
srcflux \
  infile=@evt.lis \
  out=sf2/out \
  pos="01:13:51.048,+13:16:17.84" \
  srcreg="circle(01:13:51.048,+13:16:17.84,5)" \
  bkgreg="annulus(01:13:51.048,+13:16:17.84,6,12)" \
  psfmethod=arfcorr bkgresp=no conf=0.68 \
  mode=h clob+
# Out:
# srcflux
#           infile = @evt.lis
#              pos = 01:13:51.048,+13:16:17.84
#          outroot = sf2/out
#            bands = default
#           srcreg = circle(01:13:51.048,+13:16:17.84,5)
#           bkgreg = annulus(01:13:51.048,+13:16:17.84,6,12)
#          bkgresp = no
#        psfmethod = arfcorr
#          psffile =
#             conf = 0.68
#          binsize = 1
#          rmffile =
#          arffile =
#            model = xspowerlaw.pow1
#        paramvals = pow1.PhoIndex=2.0
#         absmodel = xsphabs.abs1
#        absparams = abs1.nH=%GAL%
#            abund = angr
#          fovfile =
#         asolfile =
#          mskfile =
#         bpixfile =
#          dtffile =
#          ecffile = CALDB
#         parallel = yes
#            nproc = INDEF
#           tmpdir = ./
#      random_seed = -1
#          clobber = yes
#          verbose = 1
#             mode = h
#
# Processing OBI 001
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2/out_obi001_0001_broad_rates.par
# Running eff2evt for sf2/out_obi001_broad_0001_src.dat
# Running eff2evt for sf2/out_obi001_broad_0001_bkg.dat
# Making response files for sf2/out_obi001_0001
# Running modeflux for region 1
# Using GAL=0.0392 for source 1
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 002
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2/out_obi002_0001_broad_rates.par
# Running eff2evt for sf2/out_obi002_broad_0001_src.dat
# Running eff2evt for sf2/out_obi002_broad_0001_bkg.dat
# Making response files for sf2/out_obi002_0001
# Running modeflux for region 1
# Using GAL=0.0392 for source 1
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 003
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2/out_obi003_0001_broad_rates.par
# Running eff2evt for sf2/out_obi003_broad_0001_src.dat
# Running eff2evt for sf2/out_obi003_broad_0001_bkg.dat
# Making response files for sf2/out_obi003_0001
# An error occurred while running 'fluximage':
#   Running fluximage
#   Version: 23 February 2021
#
#   # fluximage (23 February 2021): ERROR There are no events in 18898/repro/acisf18898_repro_evt2.fits[sky=rectangle(-13.0,-13.0,13.0,13.0)]
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 004
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2/out_obi004_0001_broad_rates.par
# Running eff2evt for sf2/out_obi004_broad_0001_src.dat
# Making response files for sf2/out_obi004_0001
# Running eff2evt for sf2/out_obi004_broad_0001_bkg.dat
# An error occurred while running 'fluximage':
#   Running fluximage
#   Version: 23 February 2021
#
#   # fluximage (23 February 2021): ERROR There are no events in 20056/repro/acisf20056_repro_evt2.fits[sky=rectangle(-13.0,-13.0,13.0,13.0)]
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Combining count rates
# Combining spectra and running model flux for each source
# Running modeflux for region 1
# Using GAL=0.0392 for source 1
#
#
# Summary of source fluxes in OBI 001
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           0.124 c/s (0.121,0.128)
#                               Flux           2.38E-12 erg/cm2/s (2.31E-12,2.45E-12)
#                               Mod.Flux       9.01E-13 erg/cm2/s (8.74E-13,9.27E-13)
#                               Unabs Mod.Flux 9.61E-13 erg/cm2/s (9.33E-13,9.89E-13)
#
#
#
# Summary of source fluxes in OBI 002
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           0.111 c/s (0.107,0.114)
#                               Flux           1.98E-12 erg/cm2/s (1.91E-12,2.04E-12)
#                               Mod.Flux       8.02E-13 erg/cm2/s (7.76E-13,8.28E-13)
#                               Unabs Mod.Flux 8.56E-13 erg/cm2/s (8.28E-13,8.84E-13)
#
#
#
# Summary of source fluxes in OBI 003
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           NAN c/s (NAN,NAN)
#  Outside FOV                  Flux           NAN erg/cm2/s (NAN,NAN)
#                               Mod.Flux       NAN erg/cm2/s (NAN,NAN)
#                               Unabs Mod.Flux NAN erg/cm2/s (NAN,NAN)
#
#
#
# Summary of source fluxes in OBI 004
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           NAN c/s (NAN,NAN)
#  Outside FOV                  Flux           NAN erg/cm2/s (NAN,NAN)
#                               Mod.Flux       NAN erg/cm2/s (NAN,NAN)
#                               Unabs Mod.Flux NAN erg/cm2/s (NAN,NAN)
#
#
#
# Summary of merged source fluxes
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|1 13 51.04 +13 16 17.8  Rate           0.118 c/s (0.115,0.12)
#   NumObi=2                    Mod.Flux       8.54E-13 erg/cm2/s (8.35E-13,8.72E-13)
#                               Unabs Mod.Flux 9.11E-13 erg/cm2/s (8.91E-13,9.31E-13)

# %%
ds9 -tile -log \
  13899/repro/acisf13899_repro_evt2.fits \
  -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 \
  -region sf2/out_obi001_0001_srcreg.fits \
  15575/repro/acisf15575_repro_evt2.fits \
  -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 \
  -region sf2/out_obi002_0001_srcreg.fits \
  -saveimage png simple_05.png &

sleep 10
xpaset -p ds9 quit
display < simple_05.png
# Out:
# [1] 55062
# [1]+  Done                    ds9 -tile -log 13899/repro/acisf13899_repro_evt2.fits -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 -region sf2/out_obi001_0001_srcreg.fits 15575/repro/acisf15575_repro_evt2.fits -zoom to 8 -pan to 01:13:51.048 +13:16:17.84 fk5 -region sf2/out_obi002_0001_srcreg.fits -saveimage png simple_05.png

# %%
dmdiff sf1/out_broad.flux sf2/out_broad.flux  || echo
# Out:
# Infile 1:  sf1/out_broad.flux
# Infile 2:  sf2/out_broad.flux
#
# ----------------------------------------------------------------------
# Compare Headers
# ----------------------------------------------------------------------
# Compare Key Lists:
# Compare Keyword Details:
# # dmdiff (CIAO 4.14): WARNING: keyword 'CHECKSUM' comments differ.
# # dmdiff (CIAO 4.14):   comment1="HDU checksum updated 2021-11-10T17:34:21"
# # dmdiff (CIAO 4.14):   comment2="HDU checksum updated 2021-11-10T17:36:53"
# # dmdiff (CIAO 4.14): WARNING: keyword 'DATASUM' comments differ.
# # dmdiff (CIAO 4.14):   comment1="data unit checksum updated 2021-11-10T17:34:21"
# # dmdiff (CIAO 4.14):   comment2="data unit checksum updated 2021-11-10T17:36:53"
# Compare Keyword Values:
# Keyword: Message:                                                        Value(s):                    Diff:
# -------- -------------------------------------- ---------------------------------- ------------------------
# CHECKSUM Values are not equal                   eFPCgDM9eDMCeDM9  V6apV6WoV6aoV6Wo
# DATASUM  Values are not equal                         2255591475  2326388519
# DATE     Values are not equal                   2021-11-10T17:34:21  2021-11-10T17:36:53
#
# ----------------------------------------------------------------------
# Compare Subspaces
# ----------------------------------------------------------------------
# Compare Subspace Structure:
# Compare Column Details:
# Compare Subspace Ranges: component 1
# Compare Subspace Regions: component 1
#
# ----------------------------------------------------------------------
# Compare Tables
# ----------------------------------------------------------------------
# Compare Table Structure:
#   Block name: HISTOGRAM
# Compare Column Details:
# Compare Virtual Column Details:
# Compare Column Data:
# Column:                             Row:           Message:                                                        Value(s):                    Diff:
# ----------------------------------- -------------- -------------------------------------- ---------------------------------- ------------------------
# TOTAL_COUNTS                               1       Values are not equal                               1887  2134                     +247 (+13.1%)
# TOTAL_BG_COUNTS                            1       Values are not equal                                279  43                       -236 (-84.6%)
# MERGED_NET_RATE_APER                       1       Values are not equal                           0.114038  0.117881            +0.003843 (+3.37%)
# MERGED_NET_RATE_APER_LO                    1       Values are not equal                           0.111423  0.115342            +0.003919 (+3.52%)
# MERGED_NET_RATE_APER_HI                    1       Values are not equal                            0.11668  0.120446            +0.003766 (+3.23%)
# MERGED_RATE_AREASCAL                       1       Values are not equal                   24.3199433847478  4.31433084438745     -20.0056 (-82.3%)
# PSF_WEIGHTED_TOTAL_EXPOSURE_TIME           1       Values are not equal                   16524.4939517712  18095.0599382505     +1570.57 ( +9.5%)
# MERGED_NET_APRATES_PHOTFLUX_APER           1       Values are not equal                        0.000318862  0.000329398       +1.0536e-05 ( +3.3%)
# MERGED_NET_APRATES_PHOTFLUX_APER_LO        1       Values are not equal                         0.00031155  0.000322302       +1.0752e-05 (+3.45%)
# MERGED_NET_APRATES_PHOTFLUX_APER_HI        1       Values are not equal                        0.000326248  0.000336566       +1.0318e-05 (+3.16%)
# MERGED_PHOTFLUX_AREASCAL                   1       Values are not equal                   24.3605314928161  4.31961930847193     -20.0409 (-82.3%)
# PSF_WEIGHTED_TOTAL_SRC_EXPOSURE            1       Values are not equal                   5909884.62084803  6475662.99197475      +565778 (+9.57%)
# PSF_WEIGHTED_TOTAL_BG_EXPOSURE             1       Values are not equal                   679331.802629985  118360.489756458      -560971 (-82.6%)
# MERGED_NET_PHOTFLUX_APER                   1       Values are not equal                   0.000309622367844369  0.000329798252723729 +2.01759e-05 (+6.52%)
# MERGED_NET_PHOTFLUX_APER_LO                1       Values are not equal                   0.000302522431929034  0.000322694836874987 +2.01724e-05 (+6.67%)
# MERGED_NET_PHOTFLUX_APER_HI                1       Values are not equal                   0.000316795610937416  0.000336974409341304 +2.01788e-05 (+6.37%)
# MFLUX_CNV                                  1       Values are not equal                         7.2435e-12  7.2434e-12             -1e-16 (-0.00138%)
# UMFLUX_CNV                                 1       Values are not equal                         7.2435e-12  7.2434e-12             -1e-16 (-0.00138%)
# MERGED_NET_MFLUX_APER                      1       Values are not equal                     8.26034253e-13  8.538592354e-13   +2.7825e-14 (+3.37%)
# MERGED_NET_MFLUX_APER_LO                   1       Values are not equal                    8.070925005e-13  8.354682428e-13  +2.83757e-14 (+3.52%)
# MERGED_NET_MFLUX_APER_HI                   1       Values are not equal                      8.4517158e-13  8.724385564e-13   +2.7267e-14 (+3.23%)
# MERGED_NET_UMFLUX_APER                     1       Values are not equal                    8.811830298e-13  9.10866487e-13   +2.96835e-14 (+3.37%)
# MERGED_NET_UMFLUX_APER_LO                  1       Values are not equal                    8.609766633e-13  8.91247634e-13    +3.0271e-14 (+3.52%)
# MERGED_NET_UMFLUX_APER_HI                  1       Values are not equal                     9.01598028e-13  9.30686242e-13   +2.90882e-14 (+3.23%)
# TOTAL_FLUX_APER                            1       Values are not equal                   1.82060559548256e-12  2.06747565088482e-12  +2.4687e-13 (+13.6%)
# TOTAL_BG_FLUX_APER                         1       Values are not equal                   2.77901053799044e-13  4.86962191916089e-14 -2.29205e-13 (-82.5%)

# %% [markdown]
# ## Longer case, astro offsets

# %%
find_chandra_obsid "12:26:51" "-33:16:12"
# Out:
# # obsid  sepn   inst grat   time    obsdate  piname   target
# 18898     0.0 ACIS-S NONE   35.4 2017-04-09 Kastner "TWA 32"
# 20056     0.0 ACIS-S NONE   24.2 2017-04-14 Kastner "TWA 32"

# %%
/bin/rm -rf 18898 20056
download_chandra_obsid 18898,20056 --exclude vvref,osol,eph1,evt2
# Out:
# Downloading files for ObsId 18898, total size is 100 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       87 Mb  ####################          < 1 s  105537.4 kb/s
#   asol     fits        8 Mb  ####################          < 1 s  77332.3 kb/s
#   mtl      fits        1 Mb  ####################          < 1 s  38928.1 kb/s
#   stat     fits      839 Kb  ####################          < 1 s  30355.8 kb/s
#   aqual    fits      533 Kb  ####################          < 1 s  19743.1 kb/s
#   bias     fits      504 Kb  ####################          < 1 s  20970.2 kb/s
#   bias     fits      469 Kb  ####################          < 1 s  16353.4 kb/s
#   bias     fits      443 Kb  ####################          < 1 s  24062.9 kb/s
#   bias     fits      433 Kb  ####################          < 1 s  20587.8 kb/s
#   cntr_img jpg       338 Kb  ####################          < 1 s  20393.6 kb/s
#   full_img jpg        56 Kb  ####################          < 1 s  3761.4 kb/s
#   cntr_img fits       46 Kb  ####################          < 1 s  3778.5 kb/s
#   vv       pdf        45 Kb  ####################          < 1 s  3887.2 kb/s
#   full_img fits       44 Kb  ####################          < 1 s  3297.0 kb/s
#   bpix     fits       20 Kb  ####################          < 1 s  1160.9 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1601.0 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  1043.0 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  756.1 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  484.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  452.0 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  376.6 kb/s
#
#       Total download size for ObsId 18898 = 100 Mb
#       Total download time for ObsId 18898 = 1 s
#
# Downloading files for ObsId 20056, total size is 68 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       58 Mb  ####################          < 1 s  94378.9 kb/s
#   asol     fits        5 Mb  ####################          < 1 s  76819.5 kb/s
#   mtl      fits     1006 Kb  ####################          < 1 s  29533.5 kb/s
#   stat     fits      581 Kb  ####################          < 1 s  17705.2 kb/s
#   bias     fits      500 Kb  ####################          < 1 s  21101.4 kb/s
#   bias     fits      466 Kb  ####################          < 1 s  12232.7 kb/s
#   bias     fits      445 Kb  ####################          < 1 s  15338.5 kb/s
#   bias     fits      435 Kb  ####################          < 1 s  14401.0 kb/s
#   aqual    fits      366 Kb  ####################          < 1 s  13360.4 kb/s
#   cntr_img jpg       304 Kb  ####################          < 1 s  16364.5 kb/s
#   full_img jpg        61 Kb  ####################          < 1 s  4475.0 kb/s
#   vv       pdf        45 Kb  ####################          < 1 s  3785.3 kb/s
#   full_img fits       39 Kb  ####################          < 1 s  2851.7 kb/s
#   cntr_img fits       38 Kb  ####################          < 1 s  3118.4 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1414.8 kb/s
#   bpix     fits       15 Kb  ####################          < 1 s  1221.7 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  877.0 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  626.5 kb/s
#   flt      fits        5 Kb  ####################          < 1 s  387.4 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  331.1 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  312.8 kb/s
#
#       Total download size for ObsId 20056 = 68 Mb
#       Total download time for ObsId 20056 = 1 s

# %%
chandra_repro 18898,20056 out= verb=0
# Out:
# Output from acis_process_events:
# # acis_process_events (CIAO 4.14): The following error occurred 16 times:
# 	dsAPEPULSEHEIGHTERR -- WARNING: pulse height is less than split threshold when performing serial CTI adjustment.
# Output from acis_process_events:
# # acis_process_events (CIAO 4.14): The following error occurred 10 times:
# 	dsAPEPULSEHEIGHTERR -- WARNING: pulse height is less than split threshold when performing serial CTI adjustment.

# %%
ds9 -tile -log -zoom to 4 \
  "18898/repro/acisf18898_repro_evt2.fits[events,energy=500:7000]" \
  -pan to 12:26:51 -33:16:13 fk5 \
  "20056/repro/acisf20056_repro_evt2.fits[events,energy=500:7000]" \
  -pan to 12:26:51 -33:16:13 fk5 \
  -match frame wcs \
  -saveimage longer_06.png &

sleep 10
xpaset -p ds9 quit
display < longer_06.png
# Out:
# [1] 57118
# [1]+  Done                    ds9 -tile -log -zoom to 4 "18898/repro/acisf18898_repro_evt2.fits[events,energy=500:7000]" -pan to 12:26:51 -33:16:13 fk5 "20056/repro/acisf20056_repro_evt2.fits[events,energy=500:7000]" -pan to 12:26:51 -33:16:13 fk5 -match frame wcs -saveimage longer_06.png

# %%
dmstat "18898/repro/acisf18898_repro_evt2.fits[energy=500:7000,sky=circle(12:26:51,-33:16:13,10)][bin sky=0.5]" cen+ v=0
pget dmstat out_cntrd_phys

punlearn dmcoords
dmcoords 18898/repro/acisf18898_repro_evt2.fits op=sky x=4078.2740023 y=4097.9848871 celfmt=hms v=0
pget dmcoords ra dec
# Out:
# 4078.2387641,4097.9778384
# 12:26:51.266
# -33:16:12.86

# %%
dmstat "20056/repro/acisf20056_repro_evt2.fits[energy=500:7000,sky=circle(12:26:51,-33:16:13,10)][bin sky=0.5]" cen+ v=0
pget dmstat out_cntrd_phys

punlearn dmcoords
dmcoords 20056/repro/acisf20056_repro_evt2.fits op=sky x=4074.0906969 y=4096.6382979 celfmt=hms v=0
pget dmcoords ra dec
# Out:
# 4074.0906969,4096.6382979
# 12:26:51.288
# -33:16:13.19

# %%
mkdir fine_astro
echo "#ra dec" > fine_astro/18898.dat
punlearn dmcoords
dmcoords 18898/repro/acisf18898_repro_evt2.fits op=sky x=4078.2387641 y=4097.9778384 celfmt=deg v=0
pget dmcoords ra dec | paste - - >> fine_astro/18898.dat
cat fine_astro/18898.dat
# Out:
# mkdir: cannot create directory 'fine_astro': File exists
# #ra dec
# 186.713616315192	-33.27024113433137

# %%
echo "#ra dec" > fine_astro/20056.dat
punlearn dmcoords
dmcoords 20056/repro/acisf20056_repro_evt2.fits op=sky x=4074.0906969 y=4096.6382979 celfmt=deg v=0
pget dmcoords ra dec | paste - - >> fine_astro/20056.dat
cat fine_astro/20056.dat
# Out:
# #ra dec
# 186.7137022423231	-33.27033241498094

# %%
punlearn wcs_match
wcs_match \
  infile=fine_astro/18898.dat \
  ref=fine_astro/20056.dat \
  wcs=18898/repro/acisf18898_repro_evt2.fits \
  method=trans\
  out=fine_astro/wav.xform \
  radius=4 \
  clob+ verbose=2 mode=h
# Out:
#  input (dup) src file : fine_astro/18898.dat
#  input ref src file   : fine_astro/20056.dat
#  input wcsfile        : 18898/repro/acisf18898_repro_evt2.fits
#  debug level          : 2
#
# Opening wcsfile:  18898/repro/acisf18898_repro_evt2.fits
# asp values from 18898/repro/acisf18898_repro_evt2.fits are:   186.711   -33.270     0.000
# ref WCS values are:
#  wcrpix 	 4096.500	 4096.500
#  wcrval 	  186.711	   -33.270
#  wcdlt  	 -0.00013667	  0.00013667
# xfmTableFilename is:  fine_astro/wav.xform
# radius in arcsec, radius in sky pixels are:     4.000     8.130
# residlim in arcsec, residlim in sky pixels are:     2.000     4.065
# Opened dup srcs file:  fine_astro/18898.dat
#
# Opened ref srcs file:  fine_astro/20056.dat
#
# 1 common sources found between:
# fine_astro/20056.dat
# fine_astro/18898.dat
# After deleting poor matches, 1 sources remain
# Transform elements are:
# 	delta_x(sky pix):  -0.525661
# 	delta_y(sky pix):  -0.667922
# 	rotation(deg.):    0.000000
# 	scale factor:      1.000000
#
# Source Residuals
# ----------------
#  Match Ref# Dup#    Ref RA      Ref Dec.    Prior Resid           Transfm Resid         Resid  Incl
#  Index              (deg.)      (deg.)      RSS (x,y)             RSS (x,y)             Ratio
#                                             (arcsec)              (arcsec)
#    0    0     0    186.71370   -33.27033    0.42 ( 0.26, 0.33)    0.00 (-0.00,-0.00)    0.00    Y
#
# Source Residuals, before/after transform (arcsec), and percentage improvement:
#
#    Average Residuals:         0.418183   0.000000  100.00%
#    Maximum Residuals:         0.418183   0.000000  100.00%
#    RMS Residuals:             0.295700   0.000000  100.00%
#
# Source Residual Ratios, before/after transform, and percentage improvement:
#
#    Average Residual Ratios:   0.424982   0.000000  100.00%
#    Maximum Residual Ratios:   0.424982   0.000000  100.00%
#    RMS Ratios:                0.300508   0.000000  100.00%
#
# # wcs_match (CIAO 4.14): WARNING: Dup src x_err or ra_err cols not found.  Assuming x_err = 1.
# # wcs_match (CIAO 4.14): WARNING: Dup src y_err or dec_err cols not found.  Assuming y_err = 1.
# # wcs_match (CIAO 4.14): WARNING: Ref src x_err or ra_err cols not found.  Assuming x_err = 1.
# # wcs_match (CIAO 4.14): WARNING: Ref src y_err or dec_err cols not found.  Assuming y_err = 1.

# %%
dmlist fine_astro/wav.xform"[cols t1,t2]" data,clean
# Out:
# #  t1                   t2
#     -0.52566100938611    -0.66792243254622

# %%
mkdir 18898/fine_astro/
dmcopy 18898/repro/acisf18898_repro_evt2.fits 18898/fine_astro/acisf18898_repro_fac_evt2.fits cl+
wcs_update infile=18898/fine_astro/acisf18898_repro_fac_evt2.fits  \
  outfile="" \
  transform=fine_astro/wav.xform \
  wcs="18898/repro/acisf18898_repro_evt2.fits" clob+
wcs_update infile= 18898/repro/pcadf18898_000N001_asol1.fits \
  outfile=18898/fine_astro/pcadf608158476N001_fac_asol1.fits \
  transform=fine_astro/wav.xform \
  wcs="18898/repro/acisf18898_repro_evt2.fits" clob+  
dmhedit 18898/fine_astro/acisf18898_repro_fac_evt2.fits \
  file= op=add key=ASOLFILE value= pcadf608158476N001_fac_asol1.fits

# %%
dmstat "18898/fine_astro/acisf18898_repro_fac_evt2.fits[energy=500:7000,sky=circle(12:26:51,-33:16:13,10)][bin sky=0.5]" cen+ v=0
pget dmstat out_cntrd_phys

punlearn dmcoords
dmcoords 18898/fine_astro/acisf18898_repro_fac_evt2.fits op=sky x=4078.3049873 y=4098.015509 celfmt=hms v=0
pget dmcoords ra dec

echo "#ra dec" > fine_astro/18898_check.dat
punlearn dmcoords
dmcoords 18898/fine_astro/acisf18898_repro_fac_evt2.fits op=sky x=4078.3049873 y=4098.015509 celfmt=deg v=0
pget dmcoords ra dec | paste - - >> fine_astro/18898_check.dat
# Out:
# 4078.293919,4097.9948752
# 12:26:51.285
# -33:16:13.17

# %%
punlearn wcs_match
wcs_match \
  infile=fine_astro/18898_check.dat \
  ref=fine_astro/20056.dat \
  wcs=18898/fine_astro/acisf18898_repro_fac_evt2.fits \
  method=trans\
  out=fine_astro/wav_check.xform \
  radius=4 \
  clob+ verbose=0 mode=h

dmlist fine_astro/wav_check.xform"[cols t1,t2]" data,clean
# Out:
# # wcs_match (CIAO 4.14): WARNING: Dup src x_err or ra_err cols not found.  Assuming x_err = 1.
# # wcs_match (CIAO 4.14): WARNING: Dup src y_err or dec_err cols not found.  Assuming y_err = 1.
# # wcs_match (CIAO 4.14): WARNING: Ref src x_err or ra_err cols not found.  Assuming x_err = 1.
# # wcs_match (CIAO 4.14): WARNING: Ref src y_err or dec_err cols not found.  Assuming y_err = 1.
# #  t1                   t2
#     -0.06622198206742    -0.03765557570205

# %%
/bin/ls 18898/fine_astro/*evt2.fits > fac_evt2.lis
/bin/ls 20056/repro/*evt2.fits >> fac_evt2.lis
cat fac_evt2.lis
# Out:
# 18898/fine_astro/acisf18898_repro_fac_evt2.fits
# 20056/repro/acisf20056_repro_evt2.fits

# %%
merge_obs "@fac_evt2.lis" out=merge_fac/ bin=1 band=broad psfecf=0.9 clob+
# Out:
# Running merge_obs
# Version: 23 February 2021
#
# Verifying 2 observations.
# Using CSC ACIS broad science energy band.
# Calculating new tangent point.
# New tangent point: RA=12h 26m 50.491s Dec=-33d 16' 13.59"
#
# Observations to be reprojected:
#
#   Obsid  Obs Date   Exp    DETNAM     SIM_Z    FP   Sepn   PA
#                    (ks)                (mm)    (K)   (')  (deg)
# ---------------------------------------------------------------
# 1 18898 2017-04-09  35.4 ACIS-5678   -190.143 157.6  < 3"  +108
# 2 20056 2017-04-14  24.2 ACIS-5678   -190.143 158.1  < 3"   -72
#
# Running tasks in parallel with 4 processors.
# Reprojecting 2 event files to a common tangent point.
# Merging reprojected events files to merge_fac/merged_evt.fits
#
# Calculating the output grid
#
# The merged images will have 4146 by 3020 pixels, a pixel size of 0.492 arcsec,
#     and cover x=1812.5:5958.5:1, y=2487.5:5507.5:1.
#
# Creating the fluxed images for 2 observations in parallel.
# Creating aspect histograms for obsid 18898
# Creating aspect histograms for obsid 20056
# Creating 4 instrument maps for obsid 18898
# Creating 4 instrument maps for obsid 20056
# Creating 4 exposure maps for obsid 18898
# Creating 4 exposure maps for obsid 20056
# Combining 4 exposure maps for obsid 18898
# Combining 4 exposure maps for obsid 20056
# Thresholding data for obsid 18898
# Thresholding data for obsid 20056
# Exposure-correcting image for obsid 18898
# Exposure-correcting image for obsid 20056
# Creating PSF map for obsid 18898
# Creating PSF map for obsid 20056
#
# Combining 2 observations.
#
# The following files were created:
#
# The co-added clipped counts image is:
#      merge_fac/broad_thresh.img
#
# The co-added clipped exposure map is:
#      merge_fac/broad_thresh.expmap
#
# The combined PSF map is:
#      merge_fac/broad_thresh.psfmap
#
# The co-added exposure-corrected image is:
#      merge_fac/broad_flux.img
#
# Warning: the merged event file merge_fac/merged_evt.fits
#    should not be used to create ARF/RMF/exposure maps because
#       the RA_NOM keyword varies by 0.0007 (limit is 0.0003)

# %%
ds9 -tile column -log -zoom to 8 \
  merge_fac/18898_broad_thresh.img -pan to 12:26:51.287 -33:16:13.18 fk5 \
  -region command "circle(4076.2,4097.4,15) # color=red" \
  merge_fac/20056_broad_thresh.img -pan to 12:26:51.287 -33:16:13.18 fk5 \
  -region command "circle(4076.2,4097.4,15) # color=cyan" \
  merge_fac/broad_thresh.img -pan to 12:26:51.287 -33:16:13.18 fk5 \
  -region command "circle(4076.2,4097.4,15) # color=yellow"  \
  -saveimage png longer_08.png &

sleep 10
xpaset -p ds9 quit
display < longer_08.png
# Out:
# [1] 59184
# [1]+  Done                    ds9 -tile column -log -zoom to 8 merge_fac/18898_broad_thresh.img -pan to 12:26:51.287 -33:16:13.18 fk5 -region command "circle(4076.2,4097.4,15) # color=red" merge_fac/20056_broad_thresh.img -pan to 12:26:51.287 -33:16:13.18 fk5 -region command "circle(4076.2,4097.4,15) # color=cyan" merge_fac/broad_thresh.img -pan to 12:26:51.287 -33:16:13.18 fk5 -region command "circle(4076.2,4097.4,15) # color=yellow" -saveimage png longer_08.png

# %%
dmstat  "merge_fac/broad_thresh.img[sky=circle(12:26:51,-33:16:13,10)]" cen+ v=0
pget dmstat out_cntrd_phys

punlearn dmcoords
dmcoords merge_fac/broad_thresh.img op=sky x=4076.2134571 y=4097.3712297 celfmt=hms v=0
pget dmcoords ra dec
# Out:
# 4076.225058,4097.3433875
# 12:26:51.286
# -33:16:13.16

# %%
psfsize_srcs merge_fac/18898_broad_thresh.img pos="12:26:51.287,-33:16:13.16" out=merge_fac/18898.src \
  energy=1.0 ecf=0.9 clob+

# %%
dmlist merge_fac/18898.src"[cols x,y,r]" data,clean
# Out:
# #  X                    Y                    R
#       4076.2039350898      4097.3826648022         1.6945846652

# %%
psfsize_srcs merge_fac/20056_broad_thresh.img pos="12:26:51.287,-33:16:13.16" out=merge_fac/20056.src \
    energy=1.0 ecf=0.9 clob+

# %%
ds9 \
  -tile -log -zoom to 8 \
  merge_fac/18898_broad_thresh.img \
  -pan to 12:26:51.299 -33:16:13.04 fk5 \
  -region color red \
  -region merge_fac/18898.src \
  merge_fac/20056_broad_thresh.img \
  -pan to 12:26:51.299 -33:16:13.04 fk5 \
  -region color cyan \
  -region merge_fac/20056.src \
  -saveimage png longer_09.png &

sleep 10
xpaset -p ds9 quit
display < longer_09.png
# Out:
# [1] 59322
# [1]+  Done                    ds9 -tile -log -zoom to 8 merge_fac/18898_broad_thresh.img -pan to 12:26:51.299 -33:16:13.04 fk5 -region color red -region merge_fac/18898.src merge_fac/20056_broad_thresh.img -pan to 12:26:51.299 -33:16:13.04 fk5 -region color cyan -region merge_fac/20056.src -saveimage png longer_09.png

# %%
punlearn srcflux
srcflux \
  infile=@fac_evt2.lis \
  pos="12:26:51.287,-33:16:13.16" \
  srcreg="circle(12:26:51.287,-33:16:13.16,5)" \
  bkgreg="annulus(12:26:51.287,-33:16:13.16,6,12)" \
  out=sf/out \
  bkgresp=no psfmethod=arfcorr conf=0.68 clob+
# Out:
# srcflux
#           infile = @fac_evt2.lis
#              pos = 12:26:51.287,-33:16:13.16
#          outroot = sf/out
#            bands = default
#           srcreg = circle(12:26:51.287,-33:16:13.16,5)
#           bkgreg = annulus(12:26:51.287,-33:16:13.16,6,12)
#          bkgresp = no
#        psfmethod = arfcorr
#          psffile =
#             conf = 0.68
#          binsize = 1
#          rmffile =
#          arffile =
#            model = xspowerlaw.pow1
#        paramvals = pow1.PhoIndex=2.0
#         absmodel = xsphabs.abs1
#        absparams = abs1.nH=%GAL%
#            abund = angr
#          fovfile =
#         asolfile =
#          mskfile =
#         bpixfile =
#          dtffile =
#          ecffile = CALDB
#         parallel = yes
#            nproc = INDEF
#           tmpdir = ./
#      random_seed = -1
#          clobber = yes
#          verbose = 1
#             mode = ql
#
# Processing OBI 001
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf/out_obi001_0001_broad_rates.par
# Running eff2evt for sf/out_obi001_broad_0001_src.dat
# Running eff2evt for sf/out_obi001_broad_0001_bkg.dat
# Making response files for sf/out_obi001_0001
# Running modeflux for region 1
# Using GAL=0.0575 for source 1
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 002
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf/out_obi002_0001_broad_rates.par
# Running eff2evt for sf/out_obi002_broad_0001_bkg.dat
# Running eff2evt for sf/out_obi002_broad_0001_src.dat
# Making response files for sf/out_obi002_0001
# Running modeflux for region 1
# Using GAL=0.0575 for source 1
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Combining count rates
# Combining spectra and running model flux for each source
# Running modeflux for region 1
# Using GAL=0.0575 for source 1
#
#
# Summary of source fluxes in OBI 001
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|12 26 51.28 -33 16 13.1 Rate           0.0098 c/s (0.00926,0.0103)
#                               Flux           9.12E-14 erg/cm2/s (8.62E-14,9.63E-14)
#                               Mod.Flux       9.73E-14 erg/cm2/s (9.19E-14,1.03E-13)
#                               Unabs Mod.Flux 1.07E-13 erg/cm2/s (1.01E-13,1.13E-13)
#
#
#
# Summary of source fluxes in OBI 002
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|12 26 51.28 -33 16 13.1 Rate           0.00433 c/s (0.0039,0.00477)
#                               Flux           4.45E-14 erg/cm2/s (4E-14,4.89E-14)
#                               Mod.Flux       4.31E-14 erg/cm2/s (3.88E-14,4.74E-14)
#                               Unabs Mod.Flux 4.72E-14 erg/cm2/s (4.25E-14,5.2E-14)
#
#
#
# Summary of merged source fluxes
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|12 26 51.28 -33 16 13.1 Rate           0.00757 c/s (0.00721,0.00794)
#   NumObi=2                    Mod.Flux       7.52E-14 erg/cm2/s (7.16E-14,7.89E-14)
#                               Unabs Mod.Flux 8.25E-14 erg/cm2/s (7.85E-14,8.65E-14)

# %%
cat sf/out_summary.txt
# Out:
# Summary of merged source fluxes
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|12 26 51.28 -33 16 13.1 Rate           0.00757 c/s (0.00721,0.00794)
#   NumObi=2                    Mod.Flux       7.52E-14 erg/cm2/s (7.16E-14,7.89E-14)
#                               Unabs Mod.Flux 8.25E-14 erg/cm2/s (7.85E-14,8.65E-14)

# %%
regphystocel in="circle(4076.225058,4097.3433875,5)" out=src.reg wcsfile=merge_fac/broad_thresh.img
cat src.reg
# Out:
# regphystocel
#           infile = circle(4076.225058,4097.3433875,5)
#          outfile = src.reg
#          wcsfile = merge_fac/broad_thresh.img
#             text =
#              tag =
#          clobber = no
#          verbose = 1
#             mode = ql
#
# # Region file format: DS9 version 4.1
# global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1
# fk5
# circle(12:26:51.2861,-33:16:13.1793,2.46") #

# %%
regphystocel in="annulus(4076.225058,4097.3433875,6,12)" out=bkg.reg wcsfile=merge_fac/broad_thresh.img
cat bkg.reg
# Out:
# regphystocel
#           infile = annulus(4076.225058,4097.3433875,6,12)
#          outfile = bkg.reg
#          wcsfile = merge_fac/broad_thresh.img
#             text =
#              tag =
#          clobber = no
#          verbose = 1
#             mode = ql
#
# # Region file format: DS9 version 4.1
# global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1
# fk5
# annulus(12:26:51.2861,-33:16:13.1793,2.952",5.904") #

# %% [markdown]
# ## Multi srcs, multi obi

# %%
find_chandra_obsid "NGC1960"
# Out:
# # obsid  sepn   inst grat   time    obsdate piname     target
# 21168     0.1 ACIS-I NONE   17.8 2018-12-26 Getman "NGC 1960"
# 22031     0.1 ACIS-I NONE   21.8 2018-12-27 Getman "NGC 1960"
# 22032     0.1 ACIS-I NONE   14.9 2019-01-01 Getman "NGC 1960"
# 22033     0.1 ACIS-I NONE   11.9 2019-01-06 Getman "NGC 1960"

# %%
/bin/rm -rf 21168 22031 22032 22033
download_chandra_obsid 21168,22031,22032,22033 --exclude vvref,osol,eph1,evt2
# Out:
# Downloading files for ObsId 21168, total size is 39 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       31 Mb  ####################          < 1 s  34512.5 kb/s
#   asol     fits        4 Mb  ####################          < 1 s  23924.2 kb/s
#   mtl      fits      706 Kb  ####################          < 1 s  20789.9 kb/s
#   stat     fits      439 Kb  ####################          < 1 s  23781.0 kb/s
#   bias     fits      438 Kb  ####################          < 1 s  14688.5 kb/s
#   bias     fits      437 Kb  ####################          < 1 s  20683.6 kb/s
#   bias     fits      436 Kb  ####################          < 1 s  19872.8 kb/s
#   bias     fits      436 Kb  ####################          < 1 s  15495.8 kb/s
#   aqual    fits      268 Kb  ####################          < 1 s  8475.1 kb/s
#   cntr_img jpg       237 Kb  ####################          < 1 s  11962.9 kb/s
#   vv       pdf        72 Kb  ####################          < 1 s  5524.0 kb/s
#   full_img jpg        64 Kb  ####################          < 1 s  5829.9 kb/s
#   bpix     fits       37 Kb  ####################          < 1 s  3017.7 kb/s
#   full_img fits       32 Kb  ####################          < 1 s  2449.9 kb/s
#   cntr_img fits       30 Kb  ####################          < 1 s  1722.9 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1823.6 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  968.7 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  687.7 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  550.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  425.3 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  388.1 kb/s
#
#       Total download size for ObsId 21168 = 39 Mb
#       Total download time for ObsId 21168 = 1 s
#
# Downloading files for ObsId 22031, total size is 45 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       36 Mb  ####################            2 s  16186.1 kb/s
#   asol     fits        5 Mb  ####################          < 1 s  27135.4 kb/s
#   mtl      fits      855 Kb  ####################          < 1 s  26440.6 kb/s
#   stat     fits      535 Kb  ####################          < 1 s  18200.5 kb/s
#   bias     fits      440 Kb  ####################          < 1 s  19085.3 kb/s
#   bias     fits      438 Kb  ####################          < 1 s  20575.0 kb/s
#   bias     fits      436 Kb  ####################          < 1 s  18158.9 kb/s
#   bias     fits      436 Kb  ####################          < 1 s  19500.1 kb/s
#   aqual    fits      324 Kb  ####################          < 1 s  14250.1 kb/s
#   cntr_img jpg       251 Kb  ####################          < 1 s  14904.7 kb/s
#   vv       pdf        69 Kb  ####################          < 1 s  5640.8 kb/s
#   full_img jpg        61 Kb  ####################          < 1 s  4739.7 kb/s
#   bpix     fits       40 Kb  ####################          < 1 s  3243.2 kb/s
#   cntr_img fits       34 Kb  ####################          < 1 s  2914.7 kb/s
#   full_img fits       34 Kb  ####################          < 1 s  2648.7 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1573.2 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  823.6 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  516.2 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  455.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  437.3 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  346.1 kb/s
#
#       Total download size for ObsId 22031 = 45 Mb
#       Total download time for ObsId 22031 = 3 s
#
# Downloading files for ObsId 22032, total size is 32 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       25 Mb  ####################          < 1 s  46664.7 kb/s
#   asol     fits        3 Mb  ####################          < 1 s  48315.8 kb/s
#   mtl      fits      591 Kb  ####################          < 1 s  22286.4 kb/s
#   bias     fits      438 Kb  ####################          < 1 s  17587.6 kb/s
#   bias     fits      436 Kb  ####################          < 1 s  19216.9 kb/s
#   bias     fits      435 Kb  ####################          < 1 s  19337.9 kb/s
#   bias     fits      435 Kb  ####################          < 1 s  20575.2 kb/s
#   stat     fits      367 Kb  ####################          < 1 s  17634.1 kb/s
#   aqual    fits      226 Kb  ####################          < 1 s  10728.1 kb/s
#   cntr_img jpg       187 Kb  ####################          < 1 s  9855.1 kb/s
#   vv       pdf        63 Kb  ####################          < 1 s  4890.5 kb/s
#   full_img jpg        59 Kb  ####################          < 1 s  4535.3 kb/s
#   bpix     fits       34 Kb  ####################          < 1 s  2631.1 kb/s
#   full_img fits       29 Kb  ####################          < 1 s  2264.8 kb/s
#   cntr_img fits       28 Kb  ####################          < 1 s  2324.7 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1556.2 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  823.1 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  497.8 kb/s
#   flt      fits        5 Kb  ####################          < 1 s  446.9 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  449.4 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  377.4 kb/s
#
#       Total download size for ObsId 22032 = 32 Mb
#       Total download time for ObsId 22032 = < 1 s
#
# Downloading files for ObsId 22033, total size is 25 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       20 Mb  ####################          < 1 s  29437.9 kb/s
#   asol     fits        3 Mb  ####################          < 1 s  9878.2 kb/s
#   mtl      fits      474 Kb  ####################          < 1 s  20309.0 kb/s
#   bias     fits      438 Kb  ####################          < 1 s  17700.9 kb/s
#   bias     fits      435 Kb  ####################          < 1 s  18126.5 kb/s
#   bias     fits      434 Kb  ####################          < 1 s  19721.7 kb/s
#   bias     fits      434 Kb  ####################          < 1 s  19911.6 kb/s
#   stat     fits      295 Kb  ####################          < 1 s  17712.7 kb/s
#   aqual    fits      183 Kb  ####################          < 1 s  9989.7 kb/s
#   cntr_img jpg       164 Kb  ####################          < 1 s  9645.1 kb/s
#   vv       pdf        59 Kb  ####################          < 1 s  4033.1 kb/s
#   full_img jpg        54 Kb  ####################          < 1 s  4369.8 kb/s
#   bpix     fits       29 Kb  ####################          < 1 s  2200.9 kb/s
#   full_img fits       28 Kb  ####################          < 1 s  2289.8 kb/s
#   cntr_img fits       26 Kb  ####################          < 1 s  2269.9 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  465.1 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  742.8 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  413.7 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  437.3 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  375.7 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  338.5 kb/s
#
#       Total download size for ObsId 22033 = 25 Mb
#       Total download time for ObsId 22033 = 1 s

# %%
chandra_repro 21168,22031,22032,22033 out= clob+
# Out:
# Running chandra_repro
# version: 14 September 2021
#
# WARNING: "set_ardlib=yes" cannot be used with multiple input directories.  Changing to "no"
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/fluxes_multiobi/21168'
#
# No boresight correction update to asol file is needed.
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/fluxes_multiobi/21168/repro/acisf21168_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/fluxes_multiobi/21168/repro
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/fluxes_multiobi/22031'
#
# No boresight correction update to asol file is needed.
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/fluxes_multiobi/22031/repro/acisf22031_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/fluxes_multiobi/22031/repro
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/fluxes_multiobi/22032'
#
# No boresight correction update to asol file is needed.
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/fluxes_multiobi/22032/repro/acisf22032_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/fluxes_multiobi/22032/repro
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/fluxes_multiobi/22033'
#
# No boresight correction update to asol file is needed.
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/fluxes_multiobi/22033/repro/acisf22033_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/fluxes_multiobi/22033/repro

# %%
merge_obs 21168,22031,22032,22033 out=merge/ bin=1 psfecf=0.9 clob+
# Out:
# Running merge_obs
# Version: 23 February 2021
#
# Found 21168/repro/acisf21168_repro_evt2.fits
# Found 22031/repro/acisf22031_repro_evt2.fits
# Found 22032/repro/acisf22032_repro_evt2.fits
# Found 22033/repro/acisf22033_repro_evt2.fits
# Verifying 4 observations.
# Using CSC ACIS broad science energy band.
# Calculating new tangent point.
# New tangent point: RA=5h 36m 17.099s Dec=34d 8' 20.46"
#
# Observations to be reprojected:
#
#   Obsid  Obs Date   Exp    DETNAM     SIM_Z    FP   Sepn   PA
#                    (ks)                (mm)    (K)   (')  (deg)
# ---------------------------------------------------------------
# 1 21168 2018-12-26  17.8 ACIS-0123   -233.587 156.8  < 3"    -6
# 2 22031 2018-12-27  21.8 ACIS-0123   -233.587 153.9  < 3"   -14
# 3 22032 2019-01-01  14.9 ACIS-0123   -233.587 156.3  < 3"   +59
# 4 22033 2019-01-06  11.9 ACIS-0123   -233.587 157.0  < 3"  +175
#
# Running tasks in parallel with 4 processors.
# Reprojecting 4 event files to a common tangent point.
# Merging reprojected events files to merge/merged_evt.fits
#
# Calculating the output grid
#
# The merged images will have 2861 by 2864 pixels, a pixel size of 0.492 arcsec,
#     and cover x=2731.5:5592.5:1, y=2653.5:5517.5:1.
#
# Creating the fluxed images for 4 observations in parallel.
# Creating aspect histograms for obsid 21168
# Creating aspect histograms for obsid 22031
# Creating aspect histograms for obsid 22032
# Creating aspect histograms for obsid 22033
# Creating 4 instrument maps for obsid 21168
# Creating 4 instrument maps for obsid 22031
# Creating 4 instrument maps for obsid 22032
# Creating 4 instrument maps for obsid 22033
# Creating 4 exposure maps for obsid 21168
# Creating 4 exposure maps for obsid 22031
# Creating 4 exposure maps for obsid 22032
# Creating 4 exposure maps for obsid 22033
# Combining 4 exposure maps for obsid 21168
# Combining 4 exposure maps for obsid 22031
# Combining 4 exposure maps for obsid 22032
# Thresholding data for obsid 21168
# Combining 4 exposure maps for obsid 22033
# Thresholding data for obsid 22031
# Thresholding data for obsid 22032
# Thresholding data for obsid 22033
# Exposure-correcting image for obsid 21168
# Exposure-correcting image for obsid 22031
# Exposure-correcting image for obsid 22032
# Exposure-correcting image for obsid 22033
# Creating PSF map for obsid 22032
# Creating PSF map for obsid 22031
# Creating PSF map for obsid 21168
# Creating PSF map for obsid 22033
#
# Combining 4 observations.
#
# The following files were created:
#
# The co-added clipped counts image is:
#      merge/broad_thresh.img
#
# The co-added clipped exposure map is:
#      merge/broad_thresh.expmap
#
# The combined PSF map is:
#      merge/broad_thresh.psfmap
#
# The co-added exposure-corrected image is:
#      merge/broad_flux.img
#
# Warning: the merged event file merge/merged_evt.fits
#    should not be used to create ARF/RMF/exposure maps because
#       the DEC_NOM keyword varies by 0.0009 (limit is 0.0003)
#       the FP_TEMP keyword varies by 3.1 (limit is 2.0)

# %%
ds9 merge/broad_thresh.img -block to 6 -log \
  -saveimage png manyobi_10.png &

sleep 10
xpaset -p ds9 quit
display < manyobi_10.png
# Out:
# [1] 3255
# [1]+  Done                    ds9 merge/broad_thresh.img -block to 6 -log -saveimage png manyobi_10.png

# %%
mkdir detect_many

punlearn wavdetect
pset wavdetect \
  infile=merge/broad_thresh.img \
  expfile=merge/broad_thresh.expmap \
  psffile=merge/broad_thresh.psfmap \
  outfile=detect_many/wav.src \
  scales="1.4 2 4 8 12" \
  scell=detect_many/wav.cell defn=detect_many/wav.bkg imagef=detect_many/wav.recon \
  interdir=`pwd`/detect_many/ 

wavdetect mode=h clobber=yes

# %%
ds9 merge/broad_thresh.img -region detect_many/wav.src -block to 6 -log\
  -saveimage png manyobi_11.png &

sleep 10
xpaset -p ds9 quit
display < manyobi_11.png
# Out:
# [1] 4017
# [1]+  Done                    ds9 merge/broad_thresh.img -region detect_many/wav.src -block to 6 -log -saveimage png manyobi_11.png

# %%
dmcopy detect_many/wav.src"[src_significance>20]" detect_many/bright.src clob+
dmlist detect_many/bright.src counts
# Out:
# 10

# %%
/bin/ls {21168,22031,22032,22033}/repro/*evt2.fits > evt2.lis
cat evt2.lis
# Out:
# 21168/repro/acisf21168_repro_evt2.fits
# 22031/repro/acisf22031_repro_evt2.fits
# 22032/repro/acisf22032_repro_evt2.fits
# 22033/repro/acisf22033_repro_evt2.fits

# %%
punlearn srcflux
srcflux \
  infile=@evt2.lis \
  pos=detect_many/bright.src \
  srcreg="" bkgreg="" \
  outroot=sf_many/out \
  bkgresp=no clobber=yes conf=0.68 psfmethod=arfcorr \
  mode=h clob+
# Out:
# srcflux
#           infile = @evt2.lis
#              pos = detect_many/bright.src
#          outroot = sf_many/out
#            bands = default
#           srcreg =
#           bkgreg =
#          bkgresp = no
#        psfmethod = arfcorr
#          psffile =
#             conf = 0.68
#          binsize = 1
#          rmffile =
#          arffile =
#            model = xspowerlaw.pow1
#        paramvals = pow1.PhoIndex=2.0
#         absmodel = xsphabs.abs1
#        absparams = abs1.nH=%GAL%
#            abund = angr
#          fovfile =
#         asolfile =
#          mskfile =
#         bpixfile =
#          dtffile =
#          ecffile = CALDB
#         parallel = yes
#            nproc = INDEF
#           tmpdir = ./
#      random_seed = -1
#          clobber = yes
#          verbose = 1
#             mode = h
#
# Processing OBI 001
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf_many/out_obi001_0001_broad_rates.par
# Running aprates for sf_many/out_obi001_0003_broad_rates.par
# Running aprates for sf_many/out_obi001_0002_broad_rates.par
# Running aprates for sf_many/out_obi001_0004_broad_rates.par
# Running aprates for sf_many/out_obi001_0005_broad_rates.par
# Running aprates for sf_many/out_obi001_0006_broad_rates.par
# Running aprates for sf_many/out_obi001_0007_broad_rates.par
# Running aprates for sf_many/out_obi001_0008_broad_rates.par
# Running aprates for sf_many/out_obi001_0009_broad_rates.par
# Running aprates for sf_many/out_obi001_0010_broad_rates.par
# Running eff2evt for sf_many/out_obi001_broad_0001_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0002_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0003_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0004_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0005_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0006_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0007_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0008_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0009_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0010_src.dat
# Running eff2evt for sf_many/out_obi001_broad_0001_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0002_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0003_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0004_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0005_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0006_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0007_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0008_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0009_bkg.dat
# Running eff2evt for sf_many/out_obi001_broad_0010_bkg.dat
# Making response files for sf_many/out_obi001_0001
# Making response files for sf_many/out_obi001_0002
# Making response files for sf_many/out_obi001_0003
# Making response files for sf_many/out_obi001_0004
# Running modeflux for region 1
# Running modeflux for region 2
# Using GAL=0.5765 for source 1
# Using GAL=0.5748 for source 2
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Making response files for sf_many/out_obi001_0005
# Making response files for sf_many/out_obi001_0006
# Making response files for sf_many/out_obi001_0007
# Making response files for sf_many/out_obi001_0008
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 6
# Running modeflux for region 5
# Using GAL=0.5742 for source 6
# Running modeflux for region 8
# Using GAL=0.5727 for source 5
# Using GAL=0.575 for source 8
# Making response files for sf_many/out_obi001_0009
# Making response files for sf_many/out_obi001_0010
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 002
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf_many/out_obi002_0001_broad_rates.par
# Running aprates for sf_many/out_obi002_0002_broad_rates.par
# Running aprates for sf_many/out_obi002_0003_broad_rates.par
# Running aprates for sf_many/out_obi002_0004_broad_rates.par
# Running aprates for sf_many/out_obi002_0005_broad_rates.par
# Running aprates for sf_many/out_obi002_0006_broad_rates.par
# Running aprates for sf_many/out_obi002_0007_broad_rates.par
# Running aprates for sf_many/out_obi002_0008_broad_rates.par
# Running aprates for sf_many/out_obi002_0009_broad_rates.par
# Running aprates for sf_many/out_obi002_0010_broad_rates.par
# Running eff2evt for sf_many/out_obi002_broad_0001_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0002_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0003_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0004_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0005_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0006_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0007_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0008_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0009_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0010_src.dat
# Running eff2evt for sf_many/out_obi002_broad_0001_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0002_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0003_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0004_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0005_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0006_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0007_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0008_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0009_bkg.dat
# Running eff2evt for sf_many/out_obi002_broad_0010_bkg.dat
# Making response files for sf_many/out_obi002_0001
# Making response files for sf_many/out_obi002_0002
# Making response files for sf_many/out_obi002_0003
# Making response files for sf_many/out_obi002_0004
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Making response files for sf_many/out_obi002_0005
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Making response files for sf_many/out_obi002_0006
# Making response files for sf_many/out_obi002_0007
# Making response files for sf_many/out_obi002_0008
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# Making response files for sf_many/out_obi002_0009
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Making response files for sf_many/out_obi002_0010
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 003
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf_many/out_obi003_0001_broad_rates.par
# Running aprates for sf_many/out_obi003_0002_broad_rates.par
# Running aprates for sf_many/out_obi003_0003_broad_rates.par
# Running aprates for sf_many/out_obi003_0004_broad_rates.par
# Running aprates for sf_many/out_obi003_0005_broad_rates.par
# Running aprates for sf_many/out_obi003_0006_broad_rates.par
# Running aprates for sf_many/out_obi003_0007_broad_rates.par
# Running aprates for sf_many/out_obi003_0008_broad_rates.par
# Running aprates for sf_many/out_obi003_0009_broad_rates.par
# Running aprates for sf_many/out_obi003_0010_broad_rates.par
# Running eff2evt for sf_many/out_obi003_broad_0001_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0002_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0003_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0004_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0005_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0006_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0007_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0008_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0009_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0010_src.dat
# Running eff2evt for sf_many/out_obi003_broad_0001_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0002_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0003_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0004_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0005_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0006_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0007_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0008_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0009_bkg.dat
# Running eff2evt for sf_many/out_obi003_broad_0010_bkg.dat
# Making response files for sf_many/out_obi003_0001
# Making response files for sf_many/out_obi003_0002
# Making response files for sf_many/out_obi003_0003
# Making response files for sf_many/out_obi003_0004
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Making response files for sf_many/out_obi003_0005
# Making response files for sf_many/out_obi003_0006
# Running modeflux for region 2
# Running modeflux for region 4
# Using GAL=0.5748 for source 2
# Using GAL=0.5746 for source 4
# Making response files for sf_many/out_obi003_0007
# Making response files for sf_many/out_obi003_0008
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Making response files for sf_many/out_obi003_0009
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# Making response files for sf_many/out_obi003_0010
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 004
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf_many/out_obi004_0001_broad_rates.par
# Running aprates for sf_many/out_obi004_0003_broad_rates.par
# Running aprates for sf_many/out_obi004_0004_broad_rates.par
# Running aprates for sf_many/out_obi004_0002_broad_rates.par
# Running aprates for sf_many/out_obi004_0005_broad_rates.par
# Running aprates for sf_many/out_obi004_0006_broad_rates.par
# Running aprates for sf_many/out_obi004_0007_broad_rates.par
# Running aprates for sf_many/out_obi004_0008_broad_rates.par
# Running aprates for sf_many/out_obi004_0009_broad_rates.par
# Running aprates for sf_many/out_obi004_0010_broad_rates.par
# Running eff2evt for sf_many/out_obi004_broad_0001_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0002_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0003_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0004_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0005_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0006_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0007_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0008_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0009_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0010_src.dat
# Running eff2evt for sf_many/out_obi004_broad_0001_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0002_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0003_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0004_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0005_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0006_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0007_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0008_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0009_bkg.dat
# Running eff2evt for sf_many/out_obi004_broad_0010_bkg.dat
# Making response files for sf_many/out_obi004_0001
# Making response files for sf_many/out_obi004_0002
# Making response files for sf_many/out_obi004_0003
# Making response files for sf_many/out_obi004_0004
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Making response files for sf_many/out_obi004_0005
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Making response files for sf_many/out_obi004_0006
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Making response files for sf_many/out_obi004_0007
# Making response files for sf_many/out_obi004_0008
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Making response files for sf_many/out_obi004_0009
# Making response files for sf_many/out_obi004_0010
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Combining count rates
# Combining spectra and running model flux for each source
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Running modeflux for region 10
# Using GAL=0.578 for source 10
#
#
# Summary of source fluxes in OBI 001
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|5 36 2.24 +34 4 41.0    Rate           0.00183 c/s (0.0015,0.0022)
#                               Flux           1.82E-14 erg/cm2/s (1.5E-14,2.2E-14)
#                               Mod.Flux       2.77E-14 erg/cm2/s (2.27E-14,3.34E-14)
#                               Unabs Mod.Flux 4.59E-14 erg/cm2/s (3.77E-14,5.53E-14)
#
# #0002|5 36 13.97 +34 4 54.7   Rate           0.000294 c/s (0.000168,0.000464)
#                               Flux           9.62E-15 erg/cm2/s (5.5E-15,1.52E-14)
#                               Mod.Flux       4.95E-15 erg/cm2/s (2.83E-15,7.81E-15)
#                               Unabs Mod.Flux 8.21E-15 erg/cm2/s (4.69E-15,1.29E-14)
#
# #0003|5 35 57.71 +34 5 0.2    Rate           0.00224 c/s (0.00187,0.00265)
#                               Flux           4.05E-14 erg/cm2/s (3.39E-14,4.79E-14)
#                               Mod.Flux       3.35E-14 erg/cm2/s (2.8E-14,3.96E-14)
#                               Unabs Mod.Flux 5.56E-14 erg/cm2/s (4.65E-14,6.57E-14)
#
# #0004|5 36 17.98 +34 5 38.7   Rate           0.000995 c/s (0.000766,0.00126)
#                               Flux           1.09E-14 erg/cm2/s (8.42E-15,1.38E-14)
#                               Mod.Flux       1.54E-14 erg/cm2/s (1.18E-14,1.95E-14)
#                               Unabs Mod.Flux 2.54E-14 erg/cm2/s (1.96E-14,3.23E-14)
#
# #0005|5 36 33.39 +34 6 5.1    Rate           0.000573 c/s (0.000398,0.000794)
#                               Flux           5.69E-15 erg/cm2/s (3.95E-15,7.88E-15)
#                               Mod.Flux       2.61E-14 erg/cm2/s (1.81E-14,3.61E-14)
#                               Unabs Mod.Flux 4.32E-14 erg/cm2/s (3E-14,5.98E-14)
#
# #0006|5 36 22.80 +34 6 7.3    Rate           5.78E-05 c/s (1.05E-05,0.000154)
#                               Flux           6.73E-16 erg/cm2/s (1.22E-16,1.79E-15)
:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2029 (2.0K)
# Saving to: 'plotit.py'
#
# 100%[======================================>] 2,029       --.-K/s   in 0s
#
# 2021-11-10 13:24:34 (120 MB/s) - 'plotit.py' saved [2029/2029]

# %%
display < plot_10.png

# %%
display < plot_6.png

# %%
ds9 -tile column -log \
  21168/repro/acisf21168_repro_evt2.fits \
  -region sf_many/out_obi001_broad.flux \
  22031/repro/acisf22031_repro_evt2.fits \
  -region sf_many/out_obi002_broad.flux \
  22032/repro/acisf22032_repro_evt2.fits \
  -region sf_many/out_obi003_broad.flux \
  22033/repro/acisf22033_repro_evt2.fits \
  -region sf_many/out_obi004_broad.flux \
  -pan to 05:36:22.809 34:06:07.2869 fk5 \
  -bin to 1 -zoom to 8 \
  -match frame wcs \
  -saveimage manyobi_14.png &

sleep 10
xpaset -p ds9 quit
display < manyobi_14.png
# Out:
# [1] 15677
# [1]+  Done                    ds9 -tile column -log 21168/repro/acisf21168_repro_evt2.fits -region sf_many/out_obi001_broad.flux 22031/repro/acisf22031_repro_evt2.fits -region sf_many/out_obi002_broad.flux 22032/repro/acisf22032_repro_evt2.fits -region sf_many/out_obi003_broad.flux 22033/repro/acisf22033_repro_evt2.fits -region sf_many/out_obi004_broad.flux -pan to 05:36:22.809 34:06:07.2869 fk5 -bin to 1 -zoom to 8 -match frame wcs -saveimage manyobi_14.png

# %%
mkdir roi
punlearn roi
roi \
  infile=detect_many/bright.src \
  outsrc=roi/bright_%02d.fits \
  group=indi target=target \
  compute_conf- clob+ mode=h

# %%
/bin/ls roi
# Out:
# bright_03.fits	bright_05.fits	bright_17.fits	bright_19.fits	bright_68.fits
# bright_04.fits	bright_12.fits	bright_18.fits	bright_25.fits	bright_74.fits

# %%
/bin/ls roi/*fits | xargs -I@ regphystocel @ @.srcreg clob+ verb=0
/bin/ls roi/*fits | xargs -I@ regphystocel @"[bkgreg]" @.bkgreg clob+ verb=0

# %%
/bin/ls roi/*srcreg > srcreg.lis
/bin/ls roi/*bkgreg > bkgreg.lis

# %%
punlearn srcflux
srcflux \
  infile=@evt2.lis \
  pos=detect_many/bright.src \
  outroot=sf2_many/out \
  srcreg=@srcreg.lis \
  bkgreg=@bkgreg.lis \
  bkgresp=no clobber=yes conf=0.68 psfmethod=arfcorr \
  mode=h clob+
# Out:
# srcflux
#           infile = @evt2.lis
#              pos = detect_many/bright.src
#          outroot = sf2_many/out
#            bands = default
#           srcreg = @srcreg.lis
#           bkgreg = @bkgreg.lis
#          bkgresp = no
#        psfmethod = arfcorr
#          psffile =
#             conf = 0.68
#          binsize = 1
#          rmffile =
#          arffile =
#            model = xspowerlaw.pow1
#        paramvals = pow1.PhoIndex=2.0
#         absmodel = xsphabs.abs1
#        absparams = abs1.nH=%GAL%
#            abund = angr
#          fovfile =
#         asolfile =
#          mskfile =
#         bpixfile =
#          dtffile =
#          ecffile = CALDB
#         parallel = yes
#            nproc = INDEF
#           tmpdir = ./
#      random_seed = -1
#          clobber = yes
#          verbose = 1
#             mode = h
#
# Processing OBI 001
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2_many/out_obi001_0002_broad_rates.par
# Running aprates for sf2_many/out_obi001_0003_broad_rates.par
# Running aprates for sf2_many/out_obi001_0001_broad_rates.par
# Running aprates for sf2_many/out_obi001_0004_broad_rates.par
# Running aprates for sf2_many/out_obi001_0005_broad_rates.par
# Running aprates for sf2_many/out_obi001_0006_broad_rates.par
# Running aprates for sf2_many/out_obi001_0007_broad_rates.par
# Running aprates for sf2_many/out_obi001_0008_broad_rates.par
# Running aprates for sf2_many/out_obi001_0009_broad_rates.par
# Running aprates for sf2_many/out_obi001_0010_broad_rates.par
# Running eff2evt for sf2_many/out_obi001_broad_0001_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0002_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0003_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0004_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0005_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0006_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0007_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0008_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0009_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0010_src.dat
# Running eff2evt for sf2_many/out_obi001_broad_0001_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0002_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0003_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0004_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0005_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0006_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0007_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0008_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0009_bkg.dat
# Running eff2evt for sf2_many/out_obi001_broad_0010_bkg.dat
# Making response files for sf2_many/out_obi001_0001
# Making response files for sf2_many/out_obi001_0002
# Making response files for sf2_many/out_obi001_0003
# Making response files for sf2_many/out_obi001_0004
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Making response files for sf2_many/out_obi001_0005
# Making response files for sf2_many/out_obi001_0006
# Making response files for sf2_many/out_obi001_0007
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Making response files for sf2_many/out_obi001_0008
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Making response files for sf2_many/out_obi001_0009
# Running modeflux for region 8
# Running modeflux for region 6
# Using GAL=0.575 for source 8
# Using GAL=0.5742 for source 6
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Making response files for sf2_many/out_obi001_0010
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 002
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2_many/out_obi002_0001_broad_rates.par
# Running aprates for sf2_many/out_obi002_0002_broad_rates.par
# Running aprates for sf2_many/out_obi002_0003_broad_rates.par
# Running aprates for sf2_many/out_obi002_0004_broad_rates.par
# Running aprates for sf2_many/out_obi002_0005_broad_rates.par
# Running aprates for sf2_many/out_obi002_0006_broad_rates.par
# Running aprates for sf2_many/out_obi002_0007_broad_rates.par
# Running aprates for sf2_many/out_obi002_0008_broad_rates.par
# Running aprates for sf2_many/out_obi002_0009_broad_rates.par
# Running aprates for sf2_many/out_obi002_0010_broad_rates.par
# Running eff2evt for sf2_many/out_obi002_broad_0001_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0002_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0003_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0004_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0005_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0006_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0007_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0008_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0009_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0010_src.dat
# Running eff2evt for sf2_many/out_obi002_broad_0001_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0002_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0003_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0004_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0005_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0006_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0007_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0008_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0009_bkg.dat
# Running eff2evt for sf2_many/out_obi002_broad_0010_bkg.dat
# Making response files for sf2_many/out_obi002_0001
# Making response files for sf2_many/out_obi002_0002
# Making response files for sf2_many/out_obi002_0003
# Making response files for sf2_many/out_obi002_0004
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Running modeflux for region 4
# Making response files for sf2_many/out_obi002_0005
# Using GAL=0.5746 for source 4
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Making response files for sf2_many/out_obi002_0006
# Making response files for sf2_many/out_obi002_0007
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Making response files for sf2_many/out_obi002_0008
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Making response files for sf2_many/out_obi002_0009
# Making response files for sf2_many/out_obi002_0010
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 003
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2_many/out_obi003_0002_broad_rates.par
# Running aprates for sf2_many/out_obi003_0003_broad_rates.par
# Running aprates for sf2_many/out_obi003_0001_broad_rates.par
# Running aprates for sf2_many/out_obi003_0004_broad_rates.par
# Running aprates for sf2_many/out_obi003_0005_broad_rates.par
# Running aprates for sf2_many/out_obi003_0006_broad_rates.par
# Running aprates for sf2_many/out_obi003_0007_broad_rates.par
# Running aprates for sf2_many/out_obi003_0008_broad_rates.par
# Running aprates for sf2_many/out_obi003_0009_broad_rates.par
# Running aprates for sf2_many/out_obi003_0010_broad_rates.par
# Running eff2evt for sf2_many/out_obi003_broad_0001_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0002_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0003_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0004_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0005_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0006_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0007_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0008_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0009_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0010_src.dat
# Running eff2evt for sf2_many/out_obi003_broad_0001_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0002_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0003_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0004_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0005_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0006_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0007_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0008_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0009_bkg.dat
# Running eff2evt for sf2_many/out_obi003_broad_0010_bkg.dat
# Making response files for sf2_many/out_obi003_0001
# Making response files for sf2_many/out_obi003_0002
# Making response files for sf2_many/out_obi003_0003
# Making response files for sf2_many/out_obi003_0004
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Making response files for sf2_many/out_obi003_0005
# Making response files for sf2_many/out_obi003_0006
# Making response files for sf2_many/out_obi003_0007
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Making response files for sf2_many/out_obi003_0008
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Making response files for sf2_many/out_obi003_0009
# Running modeflux for region 6
# Running modeflux for region 8
# Using GAL=0.5742 for source 6
# Using GAL=0.575 for source 8
# Making response files for sf2_many/out_obi003_0010
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Processing OBI 004
# Extracting counts
# Making PSF models
# Getting PSF fraction by running arfcorr 1
# Getting PSF fraction by running arfcorr 2
# Getting PSF fraction by running arfcorr 3
# Getting PSF fraction by running arfcorr 4
# Getting PSF fraction by running arfcorr 5
# Getting PSF fraction by running arfcorr 6
# Getting PSF fraction by running arfcorr 7
# Getting PSF fraction by running arfcorr 8
# Getting PSF fraction by running arfcorr 9
# Getting PSF fraction by running arfcorr 10
# Combining PSF fractions together
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Running tasks in parallel with 4 processors.
# Running aprates for sf2_many/out_obi004_0001_broad_rates.par
# Running aprates for sf2_many/out_obi004_0003_broad_rates.par
# Running aprates for sf2_many/out_obi004_0002_broad_rates.par
# Running aprates for sf2_many/out_obi004_0004_broad_rates.par
# Running aprates for sf2_many/out_obi004_0005_broad_rates.par
# Running aprates for sf2_many/out_obi004_0006_broad_rates.par
# Running aprates for sf2_many/out_obi004_0007_broad_rates.par
# Running aprates for sf2_many/out_obi004_0008_broad_rates.par
# Running aprates for sf2_many/out_obi004_0009_broad_rates.par
# Running aprates for sf2_many/out_obi004_0010_broad_rates.par
# Running eff2evt for sf2_many/out_obi004_broad_0001_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0002_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0003_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0004_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0005_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0006_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0007_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0008_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0009_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0010_src.dat
# Running eff2evt for sf2_many/out_obi004_broad_0001_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0002_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0003_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0004_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0005_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0006_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0007_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0008_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0009_bkg.dat
# Running eff2evt for sf2_many/out_obi004_broad_0010_bkg.dat
# Making response files for sf2_many/out_obi004_0001
# Making response files for sf2_many/out_obi004_0002
# Making response files for sf2_many/out_obi004_0003
# Making response files for sf2_many/out_obi004_0004
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Making response files for sf2_many/out_obi004_0005
# Making response files for sf2_many/out_obi004_0006
# Making response files for sf2_many/out_obi004_0007
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Making response files for sf2_many/out_obi004_0008
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Making response files for sf2_many/out_obi004_0009
# Making response files for sf2_many/out_obi004_0010
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 10
# Using GAL=0.578 for source 10
# Running modeflux for region 9
# Using GAL=0.5739 for source 9
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Combining count rates
# Combining spectra and running model flux for each source
# Running modeflux for region 1
# Using GAL=0.5765 for source 1
# Running modeflux for region 2
# Using GAL=0.5748 for source 2
# Running modeflux for region 3
# Using GAL=0.5777 for source 3
# Running modeflux for region 4
# Using GAL=0.5746 for source 4
# Running modeflux for region 5
# Using GAL=0.5727 for source 5
# Running modeflux for region 6
# Using GAL=0.5742 for source 6
# Running modeflux for region 7
# Using GAL=0.5746 for source 7
# Running modeflux for region 8
# Using GAL=0.575 for source 8
# #0004|5 36 17.98 +34 5 38.7   Rate           0.00167 c/s (0.0015,0.00184)
#   NumObi=4                    Mod.Flux       2.58E-14 erg/cm2/s (2.32E-14,2.84E-14)
#                               Unabs Mod.Flux 4.27E-14 erg/cm2/s (3.85E-14,4.7E-14)
#
# #0005|5 36 33.39 +34 6 5.1    Rate           0.00105 c/s (0.000919,0.00118)
#   NumObi=4                    Mod.Flux       4.71E-14 erg/cm2/s (4.12E-14,5.31E-14)
#                               Unabs Mod.Flux 7.8E-14 erg/cm2/s (6.82E-14,8.79E-14)
#
# #0006|5 36 22.80 +34 6 7.3    Rate           0.00163 c/s (0.00146,0.0018)
#   NumObi=4                    Mod.Flux       2.37E-14 erg/cm2/s (2.13E-14,2.61E-14)
#                               Unabs Mod.Flux 3.92E-14 erg/cm2/s (3.52E-14,4.32E-14)
# #0007|5 36 20.05 +34 6 11.6   Rate           0.00233 c/s (0.00213,0.00253)
#   NumObi=4                    Mod.Flux       3.54E-14 erg/cm2/s (3.23E-14,3.84E-14)
#                               Unabs Mod.Flux 5.86E-14 erg/cm2/s (5.36E-14,6.36E-14)
#
# #0008|5 36 17.87 +34 6 31.8   Rate           0.00196 c/s (0.00178,0.00214)
#   NumObi=4                    Mod.Flux       2.99E-14 erg/cm2/s (2.71E-14,3.26E-14)
#                               Unabs Mod.Flux 4.95E-14 erg/cm2/s (4.5E-14,5.4E-14)
#
# #0009|5 36 40.84 +34 10 14.1  Rate           0.00348 c/s (0.00324,0.00372)
#   NumObi=4                    Mod.Flux       5.44E-14 erg/cm2/s (5.06E-14,5.83E-14)
#                               Unabs Mod.Flux 9.01E-14 erg/cm2/s (8.38E-14,9.65E-14)
#
# #0010|5 36 11.47 +34 10 37.4  Rate           0.00112 c/s (0.000984,0.00125)
#   NumObi=4                    Mod.Flux       1.71E-14 erg/cm2/s (1.5E-14,1.92E-14)
#                               Unabs Mod.Flux 2.83E-14 erg/cm2/s (2.49E-14,3.18E-14)

# %%
ds9 -tile column -log \
  21168/repro/acisf21168_repro_evt2.fits \
  -region sf2_many/out_obi001_broad.flux \
  22031/repro/acisf22031_repro_evt2.fits \
  -region sf2_many/out_obi002_broad.flux \
  22032/repro/acisf22032_repro_evt2.fits \
  -region sf2_many/out_obi003_broad.flux \
  22033/repro/acisf22033_repro_evt2.fits \
  -region sf2_many/out_obi004_broad.flux \
  -pan to 05:36:22.809 34:06:07.2869 fk5 \
  -bin to 1 -zoom to 8 \
  -match frame wcs \
  -saveimage png manyobi_15.png &

sleep 10
xpaset -p ds9 quit
display < manyobi_15.png
# Out:
# [1] 28070
# [1]+  Done                    ds9 -tile column -log 21168/repro/acisf21168_repro_evt2.fits -region sf2_many/out_obi001_broad.flux 22031/repro/acisf22031_repro_evt2.fits -region sf2_many/out_obi002_broad.flux 22032/repro/acisf22032_repro_evt2.fits -region sf2_many/out_obi003_broad.flux 22033/repro/acisf22033_repro_evt2.fits -region sf2_many/out_obi004_broad.flux -pan to 05:36:22.809 34:06:07.2869 fk5 -bin to 1 -zoom to 8 -match frame wcs -saveimage png manyobi_15.png
