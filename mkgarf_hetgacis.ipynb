# %% [markdown]
# # mkgarf hetg acis

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 459
download_chandra_obsid 459
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      10 Kb  ####################          < 1 s  1823.7 kb/s
#   oif      fits       25 Kb  ####################          < 1 s  3824.2 kb/s
#   vv       pdf        39 Kb  ####################          < 1 s  4728.8 kb/s
#   cntr_img jpg       625 Kb  ####################          < 1 s  23692.6 kb/s
#   evt2     fits       22 Mb  ####################          < 1 s  76812.6 kb/s
#   full_img jpg        74 Kb  ####################          < 1 s  8869.8 kb/s
#   pha2     fits        1 Mb  ####################          < 1 s  35570.3 kb/s
#   bpix     fits       11 Kb  ####################          < 1 s  1849.6 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  912.4 kb/s
#   eph1     fits      301 Kb  ####################          < 1 s  20141.8 kb/s
# ...

# %%
/bin/rm -rf acisf00459* tg/*
chandra_repro 459 out="."
# Out:
# Processing input directory '/data/sdsreg/thread_output/CIAO4.9/mkgarf_hetgacis/459'
#
# Resetting afterglow status bits in evt1.fits file...
#
# Running the destreak tool on the evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Output from acis_process_events:
# # acis_process_events (CIAO 4.9): WARNING: problem reading ctifile, cti adjustment will not be applied. Changing apply_cti=yes to apply_cti=no.
# Copy existing [REGION] block from evt2 file to use with tg_resolve_events
# Assign grating events to spectral orders with tg_resolve_events...
# The new evt1a file is: /data/sdsreg/thread_output/CIAO4.9/mkgarf_hetgacis/acisf00459_evt1a.fits
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# ...

# %% [markdown]
# ## Inspect pha2 file

# %%
prism acisf00459_repro_pha2.fits &
sleep 3
import -window prism prism.png
xpaset -p prism quit

display < prism.png
# Out:
# [1] 13645
# [1]+  Done                    prism acisf00459_repro_pha2.fits

# %% [markdown]
# ## Run fullgarf

# %%
cat acisf00459_asol1.lis
# Out:
# /data/sdsreg/thread_output/CIAO4.9/mkgarf_hetgacis/459/primary/pcadf063874624N003_asol1.fits

# %%
pset fullgarf phafile=acisf00459_repro_pha2.fits
pset fullgarf pharow=1
pset fullgarf evtfile=acisf00459_repro_evt2.fits
pset fullgarf asol=@acisf00459_asol1.lis
pset fullgarf engrid=compute # "grid(rmf.fits[cols ENERG_LO,ENERG_HI])"
pset fullgarf badpix=acisf00459_repro_bpix1.fits
pset fullgarf maskfile=acisf00459_000N003_msk1.fits
pset fullgarf dafile=CALDB
pset fullgarf rootname=acisf00459
pset fullgarf mode=h
pset fullgarf clobber=yes
fullgarf
# Out:
# Will use /data/sdsreg/thread_output/CIAO4.9/mkgarf_hetgacis/param/fullgarf.par for the parameter file.
#
# /data/sdsreg/thread_output/CIAO4.9/mkgarf_hetgacis/param/fullgarf.par contains 14 parameters . . .
#
# Getting the pha file type . . .
# Grating arm is HEG, order=-3
# Source location is X=4122.22509765625, Y=4071.310546875
#
# Detector is ACIS
# Will run asphist for ccd_id= 4 5 6 7
#
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah4.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=4] dtffile=acisf00459_repro_evt2.fits mode=hl
# # asphist (CIAO 4.9): WARNING: '/data/sdsreg/thread_output/CIAO4.9/mkgarf_hetgacis/459/primary/pcadf063874624N003_asol1.fits' has no records fall in event gti's.
#
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah5.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=5] dtffile=acisf00459_repro_evt2.fits mode=hl
#
# ...
