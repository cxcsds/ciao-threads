# %% [markdown]
# # mkgarf hetg acis

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 459
download_chandra_obsid 459 --exclude vvref,osol,eph1
# Out:
# Downloading files for ObsId 459, total size is 215 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       97 Mb  ####################            2 s  46898.3 kb/s
#   evt1a    fits       75 Mb  ####################            2 s  48175.5 kb/s
#   evt2     fits       22 Mb  ####################          < 1 s  49741.4 kb/s
#   asol     fits       10 Mb  ####################          < 1 s  41262.2 kb/s
#   aoff     fits        4 Mb  ####################          < 1 s  43457.1 kb/s
#   mtl      fits        2 Mb  ####################          < 1 s  34562.1 kb/s
#   stat     fits        1 Mb  ####################          < 1 s  30406.8 kb/s
#   pha2     fits        1 Mb  ####################          < 1 s  30369.5 kb/s
#   cntr_img jpg       625 Kb  ####################          < 1 s  24562.8 kb/s
#   aqual    fits      611 Kb  ####################          < 1 s  28188.7 kb/s
#   bias     fits      501 Kb  ####################          < 1 s  15094.3 kb/s
#   bias     fits      446 Kb  ####################          < 1 s  23785.6 kb/s
#   bias     fits      444 Kb  ####################          < 1 s  22609.9 kb/s
#   bias     fits      437 Kb  ####################          < 1 s  17256.0 kb/s
#   bias     fits      435 Kb  ####################          < 1 s  16611.3 kb/s
#   full_img jpg        74 Kb  ####################          < 1 s  5279.1 kb/s
#   vv       pdf        39 Kb  ####################          < 1 s  3427.5 kb/s
#   oif      fits       25 Kb  ####################          < 1 s  2207.1 kb/s
#   bpix     fits       11 Kb  ####################          < 1 s  950.4 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  602.8 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  515.2 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  421.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  437.7 kb/s
#   soff     fits        5 Kb  ####################          < 1 s  431.5 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  291.4 kb/s
#
#       Total download size for ObsId 459 = 215 Mb
#       Total download time for ObsId 459 = 5 s

# %%
/bin/rm -rf acisf00459* pcadf* tg/*
chandra_repro 459 out="." clob+
# Out:
# Running chandra_repro
# version: 14 September 2021
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/459'
#
# Applying boresight update to aspect solution file
# WARNING: The grating 0th order location must be recomputed when asol_update=yes.  Changing recreate_tg_mask=yes.
# Resetting afterglow status bits in evt1.fits file...
#
# Running the destreak tool on the evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Output from acis_process_events:
# # acis_process_events (CIAO 4.14): WARNING: The ra_targ, dec_targ, or roll_nom specified by /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/pcadf00459_repro_obs.par does not match the values in the event file- using the obs.par values.
# # acis_process_events (CIAO 4.14): WARNING: problem reading ctifile, cti adjustment will not be applied. Changing apply_cti=yes to apply_cti=no.
# Getting the zero-order source position with tgdetect2...
# Assign grating events to spectral orders with tg_resolve_events...
# The new evt1a file is: /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/acisf00459_evt1a.fits
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/acisf00459_repro_evt2.fits
# Extracting a grating spectrum with tgextract...
# The new level=2 PHA file is: /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/acisf00459_repro_pha2.fits
# Creating grating response files
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
# Setting observation-specific bad pixel file in local ardlib.par.
#
# Cleaning up intermediate files
#
# WARNING: Observation-specific bad pixel file set for session use:
#          /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/acisf00459_repro_bpix1.fits
#          Run 'punlearn ardlib' when analysis of this dataset completed.
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis

# %% [markdown]
# ## Inspect pha2 file

# %% [markdown]
# ```bash
# # No longer
# prism acisf00459_repro_pha2.fits &
# sleep 3
# import -window prism prism.png
# xpaset -p prism quit
#
# display < prism.png
# ```

# %% [markdown]
# ## Run fullgarf

# %%
cat acisf00459_asol1.lis
# Out:
# /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/pcadf00459_repro_asol1.fits

# %%
pset fullgarf phafile=acisf00459_repro_pha2.fits
pset fullgarf pharow=1
pset fullgarf evtfile=acisf00459_repro_evt2.fits
pset fullgarf asol=@acisf00459_asol1.lis
pset fullgarf engrid=compute # "grid(rmf.fits[cols ENERG_LO,ENERG_HI])"
pset fullgarf badpix=acisf00459_repro_bpix1.fits
pset fullgarf maskfile=acisf00459_000N004_msk1.fits
pset fullgarf dafile=CALDB
pset fullgarf rootname=acisf00459
pset fullgarf mode=h
pset fullgarf clobber=yes
fullgarf
echo $?
# Out:
# Will use /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/param/fullgarf.par for the parameter file.
#
# /proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/param/fullgarf.par contains 15 parameters . . .
#
# Getting the pha file type . . .
# Grating arm is HEG, order=-3
# Source location is X=4128.19384765625, Y=4076.613037109375
#
# Detector is ACIS
# Will run asphist for ccd_id= 4 5 6 7 8
#
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah4.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=4] dtffile=acisf00459_repro_evt2.fits mode=hl
# # asphist (CIAO 4.14): WARNING: '/proj/sds/Staff/kjg/Threads/mkgarf_hetgacis/pcadf00459_repro_asol1.fits' has no records fall in event gti's.
#
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah5.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=5] dtffile=acisf00459_repro_evt2.fits mode=hl
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah6.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=6] dtffile=acisf00459_repro_evt2.fits mode=hl
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah7.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=7] dtffile=acisf00459_repro_evt2.fits mode=hl
#
# asphist infile=@acisf00459_asol1.lis outfile=acisf00459_ah8.fits evtfile=acisf00459_repro_evt2.fits[ccd_id=8] dtffile=acisf00459_repro_evt2.fits mode=hl
#
# Finished processing aspect histograms for ccd_id= 4 5 6 7 8
# Will run mkgarf for the same ccd_id list
#
# mkgarf detsubsys=ACIS-S0 order=-3 grating_arm=HEG outfile=acisf00459_S0_HEG_-3.fits asphistfile=acisf00459_ah4.fits[ASPHIST] obsfile=acisf00459_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf00459_000N003_msk1.fits mirror=HRMA sourcepixelx=4128.19384765625 sourcepixely=4076.613037109375 mode=hl verb=0
# *** ERROR: aspect histogram acisf00459_ah4.fits[ASPHIST] contains no rows
#
# mkgarf detsubsys=ACIS-S1 order=-3 grating_arm=HEG outfile=acisf00459_S1_HEG_-3.fits asphistfile=acisf00459_ah5.fits[ASPHIST] obsfile=acisf00459_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf00459_000N003_msk1.fits mirror=HRMA sourcepixelx=4128.19384765625 sourcepixely=4076.613037109375 mode=hl verb=0
#
# mkgarf detsubsys=ACIS-S2 order=-3 grating_arm=HEG outfile=acisf00459_S2_HEG_-3.fits asphistfile=acisf00459_ah6.fits[ASPHIST] obsfile=acisf00459_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf00459_000N003_msk1.fits mirror=HRMA sourcepixelx=4128.19384765625 sourcepixely=4076.613037109375 mode=hl verb=0
#
# mkgarf detsubsys=ACIS-S3 order=-3 grating_arm=HEG outfile=acisf00459_S3_HEG_-3.fits asphistfile=acisf00459_ah7.fits[ASPHIST] obsfile=acisf00459_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf00459_000N003_msk1.fits mirror=HRMA sourcepixelx=4128.19384765625 sourcepixely=4076.613037109375 mode=hl verb=0
# *** WARNING: The ARF was computed to be zero at all the specified energies.
#              This is probably due to an incorrect source position
#
# mkgarf detsubsys=ACIS-S4 order=-3 grating_arm=HEG outfile=acisf00459_S4_HEG_-3.fits asphistfile=acisf00459_ah8.fits[ASPHIST] obsfile=acisf00459_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf00459_000N003_msk1.fits mirror=HRMA sourcepixelx=4128.19384765625 sourcepixely=4076.613037109375 mode=hl verb=0
# *** WARNING: The ARF was computed to be zero at all the specified energies.
#              This is probably due to an incorrect source position
#
#
# Finished processing grating arfs for ccd_id= 4 5 6 7 8
#
# dmarfadd @thisfile.istemporary acisf00459HEG_-3_garf.fits
#
# /export/CIAOT/ciaot_install/20211019/ciao-4.14/contrib/bin/fullgarf finished.
#
# 0

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf tg 459 acisf00459_repro* acisf00459_000N003* acisf00459_evt1a.fits \
  acisf*_pbk0.fits pcadf*_asol1.fits
