# %% [markdown]
# # peg

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 1843
/bin/rm -f {acis,pcad}f*.fits
download_chandra_obsid 1843
mv -fv 1843/{primary,secondary}/*fits.gz .
gunzip -f {acis,pcad}f*.fits.gz
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb  ####################          < 1 s  630.9 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  1329.7 kb/s
#   vv       pdf        40 Kb  ####################          < 1 s  560.8 kb/s
#   cntr_img fits      237 Kb  ####################          < 1 s  5548.4 kb/s
#   cntr_img jpg       925 Kb  ####################          < 1 s  18665.2 kb/s
#   evt2     fits       17 Mb  ####################          < 1 s  45192.7 kb/s
#   full_img fits       80 Kb  ####################          < 1 s  2681.1 kb/s
#   full_img jpg        82 Kb  ####################          < 1 s  7640.6 kb/s
#   bpix     fits       13 Kb  ####################          < 1 s  1883.6 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  883.8 kb/s
# ...

# %% [markdown]
# ## Launch peg

# %%
peg &
sleep 3
import -window peg peg_01.png 
xpaset -p peg quit
display < peg_01.png
# Out:
# [1] 19220
# [1]+  Done                    peg

# %%
peg dmlist &
sleep 3
import -window 'peg : dmlist' peg_02.png 
xpaset -p peg quit
display < peg_02.png
# Out:
# [1] 19239
# [1]+  Done                    peg dmlist

# %%
peg `pwd`/param/dmlist.par &
sleep 3
import -window 'peg : dmlist' peg_03.png 
xpaset -p peg quit
display < peg_03.png
# Out:
# [1] 19261
# [1]+  Done                    peg `pwd`/param/dmlist.par

# %% [markdown]
# ## Running command

# %%
peg dmlist &
sleep 3

xpaset -p peg set infile acisf01843N003_evt2.fits
xpaset -p peg set opt data
xpaset -p peg set rows 1:5
xpaset -p peg set verbose 1

import -window "peg : dmlist" peg_04.png 
display < peg_04.png
# Out:
# [1] 19282

# %%
##xpaset -p peg run

xpaset -p peg save cmd.par
taskmonitor dmlist @@cmd.par mode=h &
sleep 3
import -window Taskmonitor taskmonitor_01.png

display < taskmonitor_01.png
# Out:
# [2] 19309

# %%
xpaset -p taskmonitor quit
xpaset -p peg quit
# Out:
# [2]+  Done                    taskmonitor dmlist @@cmd.par mode=h
# [1]+  Done                    peg dmlist

# %%
dmlist @@cmd.par mode=h
# Out:
#
# --------------------------------------------------------------------------------
# Block    2: EVENTS                         Table        15 cols x 490794   rows
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Data for Table Block EVENTS
# --------------------------------------------------------------------------------
#
# ROW    time                 ccd_id node_id expno      chip(chipx,chipy) tdet(tdetx,tdety) det(detx,dety)                           sky(x,y)                                 pha        pha_ro     energy               pi     fltgrade grade status[4]
#
# ...
