# %% [markdown]
# # Add grating spectra
#
# aka `combine_grating_spectra`

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 8985 8986 
download_chandra_obsid 8985,8986
# Out:
# Downloading files for ObsId 8985, total size is 71 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      10 Kb  ####################          < 1 s  454.6 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  717.3 kb/s
#   vv       pdf        36 Kb  ####################          < 1 s  2512.0 kb/s
#   cntr_img jpg       397 Kb  ####################          < 1 s  3658.7 kb/s
#   evt2     fits        4 Mb  ####################          < 1 s  41138.0 kb/s
#   full_img jpg        78 Kb  ####################          < 1 s  3525.6 kb/s
#   pha2     fits        1 Mb  ####################          < 1 s  24935.8 kb/s
#   bpix     fits       18 Kb  ####################          < 1 s  908.6 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  376.2 kb/s
#   eph1     fits      282 Kb  ####################          < 1 s  7312.7 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  26538.6 kb/s
#   evt1     fits       22 Mb  ####################          < 1 s  53546.8 kb/s
#   evt1a    fits       17 Mb  ####################          < 1 s  44978.4 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  249.3 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  863.2 kb/s
#   mtl      fits      279 Kb  ####################          < 1 s  10993.1 kb/s
#   stat     fits      235 Kb  ####################          < 1 s  9836.9 kb/s
#   bias     fits      450 Kb  ####################          < 1 s  14441.3 kb/s
#   bias     fits      495 Kb  ####################          < 1 s  12681.7 kb/s
#   bias     fits      451 Kb  ####################          < 1 s  13247.0 kb/s
#   bias     fits      444 Kb  ####################          < 1 s  5009.7 kb/s
#   bias     fits      450 Kb  ####################          < 1 s  7532.8 kb/s
#   bias     fits      440 Kb  ####################          < 1 s  5105.0 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  598.6 kb/s
#   vv       pdf        19 Mb  ####################          < 1 s  58645.8 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  202.1 kb/s
#   eph1     fits      276 Kb  ####################          < 1 s  5707.9 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  7407.0 kb/s
#   osol     fits      350 Kb  ####################          < 1 s  11728.4 kb/s
#   aqual    fits      144 Kb  ####################          < 1 s  10044.6 kb/s
#   osol     fits      341 Kb  ####################          < 1 s  13220.3 kb/s
#   osol     fits       19 Kb  ####################          < 1 s  2630.5 kb/s
#   osol     fits      188 Kb  ####################          < 1 s  11236.5 kb/s
#
#       Total download size for ObsId 8985 = 71 Mb
#       Total download time for ObsId 8985 = 2 s
#
# Downloading files for ObsId 8986, total size is 77 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      10 Kb  ####################          < 1 s  1927.3 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  3556.2 kb/s
#   vv       pdf        36 Kb  ####################          < 1 s  5306.9 kb/s
#   cntr_img jpg       432 Kb  ####################          < 1 s  25242.1 kb/s
#   evt2     fits        5 Mb  ####################          < 1 s  58171.3 kb/s
#   full_img jpg        85 Kb  ####################          < 1 s  10503.4 kb/s
#   pha2     fits        1 Mb  ####################          < 1 s  41870.7 kb/s
#   bpix     fits       20 Kb  ####################          < 1 s  3216.1 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  1066.7 kb/s
#   eph1     fits      283 Kb  ####################          < 1 s  22477.2 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  49052.5 kb/s
#   evt1     fits       27 Mb  ####################          < 1 s  74867.7 kb/s
#   evt1a    fits       20 Mb  ####################          < 1 s  70839.1 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  612.4 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  1024.4 kb/s
#   mtl      fits      329 Kb  ####################          < 1 s  21508.5 kb/s
#   stat     fits      279 Kb  ####################          < 1 s  17870.7 kb/s
#   bias     fits      452 Kb  ####################          < 1 s  21917.0 kb/s
#   bias     fits      497 Kb  ####################          < 1 s  25185.2 kb/s
#   bias     fits      452 Kb  ####################          < 1 s  24440.4 kb/s
#   bias     fits      444 Kb  ####################          < 1 s  24867.0 kb/s
#   bias     fits      451 Kb  ####################          < 1 s  24573.4 kb/s
#   bias     fits      443 Kb  ####################          < 1 s  24180.0 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  729.9 kb/s
#   vv       pdf        17 Mb  ####################          < 1 s  74824.3 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  624.3 kb/s
#   eph1     fits      277 Kb  ####################          < 1 s  19016.0 kb/s
#   eph1     fits      260 Kb  ####################          < 1 s  19471.7 kb/s
#   osol     fits      361 Kb  ####################          < 1 s  22069.7 kb/s
#   aqual    fits      124 Kb  ####################          < 1 s  12036.7 kb/s
#   osol     fits      361 Kb  ####################          < 1 s  21977.6 kb/s
#
#       Total download size for ObsId 8986 = 77 Mb
#       Total download time for ObsId 8986 = 1 s

# %%
chandra_repro 8985,8986 out=""
# Out:
# WARNING: "set_ardlib=yes" cannot be used with multiple input directories.  Changing to "no"
#
#
# Processing input directory '/data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8985'
#
# Resetting afterglow status bits in evt1.fits file...
#
# Running the destreak tool on the evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Output from acis_process_events:
# # acis_process_events (CIAO 4.9): The following error occurred 17 times:
# 	dsAPEPULSEHEIGHTERR -- WARNING: pulse height is less than split threshold when performing serial CTI adjustment.
# Copy existing [REGION] block from evt2 file to use with tg_resolve_events
# Assign grating events to spectral orders with tg_resolve_events...
# The new evt1a file is: /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8985/repro/acisf08985_evt1a.fits
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8985/repro/acisf08985_repro_evt2.fits
# Extracting a grating spectrum with tgextract...
# The new level=2 PHA file is: /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8985/repro/acisf08985_repro_pha2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8985/repro
#
#
# Processing input directory '/data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8986'
#
# Resetting afterglow status bits in evt1.fits file...
#
# Running the destreak tool on the evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Output from acis_process_events:
# # acis_process_events (CIAO 4.9): The following error occurred 31 times:
# 	dsAPEPULSEHEIGHTERR -- WARNING: pulse height is less than split threshold when performing serial CTI adjustment.
# Copy existing [REGION] block from evt2 file to use with tg_resolve_events
# Assign grating events to spectral orders with tg_resolve_events...
# The new evt1a file is: /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8986/repro/acisf08986_evt1a.fits
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8986/repro/acisf08986_repro_evt2.fits
# Extracting a grating spectrum with tgextract...
# The new level=2 PHA file is: /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8986/repro/acisf08986_repro_pha2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
#
# Cleaning up intermediate files
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /data/sdsreg/thread_output/CIAO4.9/add_grating_spectra/8986/repro

# %%
/bin/ls 898?/repro/*
# Out:
# 8985/repro/acisf08985_001N002_bpix1.fits
# 8985/repro/acisf08985_001N002_fov1.fits
# 8985/repro/acisf08985_001N002_msk1.fits
# 8985/repro/acisf08985_001N002_mtl1.fits
# 8985/repro/acisf08985_001N002_stat1.fits
# 8985/repro/acisf08985_asol1.lis
# 8985/repro/acisf08985_evt1a.fits
# 8985/repro/acisf08985_repro_bpix1.fits
# 8985/repro/acisf08985_repro_evt2.fits
# 8985/repro/acisf08985_repro_flt2.fits
# 8985/repro/acisf08985_repro_fov1.fits
# 8985/repro/acisf08985_repro_pha2.fits
# 8985/repro/acisf08985_tgmask.fits
# 8985/repro/acisf319781625N002_pbk0.fits
# 8985/repro/pcadf319779046N002_asol1.fits
# 8986/repro/acisf08986_001N002_bpix1.fits
# 8986/repro/acisf08986_001N002_fov1.fits
# 8986/repro/acisf08986_001N002_msk1.fits
# 8986/repro/acisf08986_001N002_mtl1.fits
# 8986/repro/acisf08986_001N002_stat1.fits
# 8986/repro/acisf08986_asol1.lis
# 8986/repro/acisf08986_evt1a.fits
# 8986/repro/acisf08986_repro_bpix1.fits
# 8986/repro/acisf08986_repro_evt2.fits
# 8986/repro/acisf08986_repro_flt2.fits
# 8986/repro/acisf08986_repro_fov1.fits
# 8986/repro/acisf08986_repro_pha2.fits
# 8986/repro/acisf08986_tgmask.fits
# 8986/repro/acisf320289394N002_pbk0.fits
# 8986/repro/pcadf320289352N002_asol1.fits
#
# 8985/repro/tg:
# acisf08985_repro_heg_m1.arf  acisf08985_repro_meg_m1.arf
# acisf08985_repro_heg_m1.rmf  acisf08985_repro_meg_m1.rmf
# acisf08985_repro_heg_p1.arf  acisf08985_repro_meg_p1.arf
# acisf08985_repro_heg_p1.rmf  acisf08985_repro_meg_p1.rmf
#
# 8986/repro/tg:
# acisf08986_repro_heg_m1.arf  acisf08986_repro_meg_m1.arf
# acisf08986_repro_heg_m1.rmf  acisf08986_repro_meg_m1.rmf
# acisf08986_repro_heg_p1.arf  acisf08986_repro_meg_p1.arf
# acisf08986_repro_heg_p1.rmf  acisf08986_repro_meg_p1.rmf

# %% [markdown]
# ## Run c_g_s

# %%
/bin/ls */repro/*pha2.fits > pha.lis
/bin/ls */repro/tg/*arf > arf.lis
/bin/ls */repro/tg/*rmf > rmf.lis

# %%
punlearn combine_grating_spectra

pset combine_grating_spectra infile=@pha.lis
pset combine_grating_spectra arf=@arf.lis
pset combine_grating_spectra rmf=@rmf.lis
pset combine_grating_spectra add_plusminus=yes
pset combine_grating_spectra outroot=h1743-322

combine_grating_spectra mode=h clob+
# Out:
# Input TYPE:II pha file(s).  The output will be one or more TYPE:I pha files
# Splitting TYPE:II pha files into TYPE:I
# Combining spectra across observations
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_meg_p1.pha
#        ARF: 8985/repro/tg/acisf08985_repro_meg_p1.arf
#        RMF: 8985/repro/tg/acisf08985_repro_meg_p1.rmf
#     background PHA: h1743-322_tmp00_meg_p1_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_meg_p1.pha
#        ARF: 8986/repro/tg/acisf08986_repro_meg_p1.arf
#        RMF: 8986/repro/tg/acisf08986_repro_meg_p1.rmf
#     background PHA: h1743-322_tmp01_meg_p1_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_p1.pha
#   h1743-322_meg_p1_bkg.pha
#   h1743-322_meg_p1.arf
#   h1743-322_meg_p1.rmf
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_heg_m1.pha
#        ARF: 8985/repro/tg/acisf08985_repro_heg_m1.arf
#        RMF: 8985/repro/tg/acisf08985_repro_heg_m1.rmf
#     background PHA: h1743-322_tmp00_heg_m1_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_heg_m1.pha
#        ARF: 8986/repro/tg/acisf08986_repro_heg_m1.arf
#        RMF: 8986/repro/tg/acisf08986_repro_heg_m1.rmf
#     background PHA: h1743-322_tmp01_heg_m1_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_m1.pha
#   h1743-322_heg_m1_bkg.pha
#   h1743-322_heg_m1.arf
#   h1743-322_heg_m1.rmf
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_meg_m1.pha
#        ARF: 8985/repro/tg/acisf08985_repro_meg_m1.arf
#        RMF: 8985/repro/tg/acisf08985_repro_meg_m1.rmf
#     background PHA: h1743-322_tmp00_meg_m1_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_meg_m1.pha
#        ARF: 8986/repro/tg/acisf08986_repro_meg_m1.arf
#        RMF: 8986/repro/tg/acisf08986_repro_meg_m1.rmf
#     background PHA: h1743-322_tmp01_meg_m1_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_m1.pha
#   h1743-322_meg_m1_bkg.pha
#   h1743-322_meg_m1.arf
#   h1743-322_meg_m1.rmf
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_meg_p3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_meg_p3_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_meg_p3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_meg_p3_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_p3.pha
#   h1743-322_meg_p3_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_heg_p3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_heg_p3_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_heg_p3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_heg_p3_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_p3.pha
#   h1743-322_heg_p3_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_heg_m2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_heg_m2_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_heg_m2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_heg_m2_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_m2.pha
#   h1743-322_heg_m2_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_heg_p2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_heg_p2_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_heg_p2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_heg_p2_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_p2.pha
#   h1743-322_heg_p2_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_heg_m3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_heg_m3_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_heg_m3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_heg_m3_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_m3.pha
#   h1743-322_heg_m3_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_meg_m3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_meg_m3_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_meg_m3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_meg_m3_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_m3.pha
#   h1743-322_meg_m3_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_meg_m2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_meg_m2_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_meg_m2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_meg_m2_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_m2.pha
#   h1743-322_meg_m2_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_meg_p2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp00_meg_p2_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_meg_p2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_tmp01_meg_p2_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_p2.pha
#   h1743-322_meg_p2_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_tmp00_heg_p1.pha
#        ARF: 8985/repro/tg/acisf08985_repro_heg_p1.arf
#        RMF: 8985/repro/tg/acisf08985_repro_heg_p1.rmf
#     background PHA: h1743-322_tmp00_heg_p1_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_tmp01_heg_p1.pha
#        ARF: 8986/repro/tg/acisf08986_repro_heg_p1.arf
#        RMF: 8986/repro/tg/acisf08986_repro_heg_p1.rmf
#     background PHA: h1743-322_tmp01_heg_p1_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_p1.pha
#   h1743-322_heg_p1_bkg.pha
#   h1743-322_heg_p1.arf
#   h1743-322_heg_p1.rmf
# Combining plus and minus orders
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_meg_p1.pha
#        ARF: h1743-322_meg_p1.arf
#        RMF: h1743-322_meg_p1.rmf
#     background PHA: h1743-322_meg_p1_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_meg_m1.pha
#        ARF: h1743-322_meg_m1.arf
#        RMF: h1743-322_meg_m1.rmf
#     background PHA: h1743-322_meg_m1_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_abs1.pha
#   h1743-322_meg_abs1_bkg.pha
#   h1743-322_meg_abs1.arf
#   h1743-322_meg_abs1.rmf
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_meg_p3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_meg_p3_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_meg_m3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_meg_m3_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_abs3.pha
#   h1743-322_meg_abs3_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_heg_p3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_heg_p3_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_heg_m3.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_heg_m3_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_abs3.pha
#   h1743-322_heg_abs3_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_heg_m2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_heg_m2_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_heg_p2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_heg_p2_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_abs2.pha
#   h1743-322_heg_abs2_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_meg_m2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_meg_m2_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_meg_p2.pha
#        ARF: None
#        RMF: None
#     background PHA: h1743-322_meg_p2_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_meg_abs2.pha
#   h1743-322_meg_abs2_bkg.pha
# Prepared to combine 2 spectra
#
# source PHA: h1743-322_heg_m1.pha
#        ARF: h1743-322_heg_m1.arf
#        RMF: h1743-322_heg_m1.rmf
#     background PHA: h1743-322_heg_m1_bkg.pha
#                ARF: None
#                RMF: None
# source PHA: h1743-322_heg_p1.pha
#        ARF: h1743-322_heg_p1.arf
#        RMF: h1743-322_heg_p1.rmf
#     background PHA: h1743-322_heg_p1_bkg.pha
#                ARF: None
#                RMF: None
#
# The following files were created:
#   h1743-322_heg_abs1.pha
#   h1743-322_heg_abs1_bkg.pha
#   h1743-322_heg_abs1.arf
#   h1743-322_heg_abs1.rmf
# Created output source spectrum 'h1743-322_meg_abs1.pha'
#     with background spectrum 'h1743-322_meg_abs1_bkg.pha'
#     with source ARF 'h1743-322_meg_abs1.arf'
#     with source RMF 'h1743-322_meg_abs1.rmf'
#
# Created output source spectrum 'h1743-322_meg_abs3.pha'
#     with background spectrum 'h1743-322_meg_abs3_bkg.pha'
#
# Created output source spectrum 'h1743-322_heg_abs3.pha'
#     with background spectrum 'h1743-322_heg_abs3_bkg.pha'
#
# Created output source spectrum 'h1743-322_heg_abs2.pha'
#     with background spectrum 'h1743-322_heg_abs2_bkg.pha'
#
# Created output source spectrum 'h1743-322_meg_abs2.pha'
#     with background spectrum 'h1743-322_meg_abs2_bkg.pha'
#
# Created output source spectrum 'h1743-322_heg_abs1.pha'
#     with background spectrum 'h1743-322_heg_abs1_bkg.pha'
#     with source ARF 'h1743-322_heg_abs1.arf'
#     with source RMF 'h1743-322_heg_abs1.rmf'

# %%
/bin/ls h1743*
# Out:
# h1743-322_heg_abs1.arf	    h1743-322_meg_abs1.arf
# h1743-322_heg_abs1.pha	    h1743-322_meg_abs1.pha
# h1743-322_heg_abs1.rmf	    h1743-322_meg_abs1.rmf
# h1743-322_heg_abs1_bkg.pha  h1743-322_meg_abs1_bkg.pha
# h1743-322_heg_abs2.pha	    h1743-322_meg_abs2.pha
# h1743-322_heg_abs2_bkg.pha  h1743-322_meg_abs2_bkg.pha
# h1743-322_heg_abs3.pha	    h1743-322_meg_abs3.pha
# h1743-322_heg_abs3_bkg.pha  h1743-322_meg_abs3_bkg.pha

# %% [markdown]
# ## Sherpa

# %%
python -c 'from sherpa.astro.datastack import *;load_data("h1743-322_?eg_abs?.pha");show_stack();group_counts([],10)'
# Out:
# WARNING: systematic errors were not found in file 'h1743-322_heg_abs1.pha'
# statistical errors were found in file 'h1743-322_heg_abs1.pha'
# but not used; to use them, re-read with use_errors=True
# read ARF file h1743-322_heg_abs1.arf
# read RMF file h1743-322_heg_abs1.rmf
# read background file h1743-322_heg_abs1_bkg.pha
# WARNING: systematic errors were not found in file 'h1743-322_heg_abs2.pha'
# statistical errors were found in file 'h1743-322_heg_abs2.pha'
# but not used; to use them, re-read with use_errors=True
# read background file h1743-322_heg_abs2_bkg.pha
# WARNING: systematic errors were not found in file 'h1743-322_heg_abs3.pha'
# statistical errors were found in file 'h1743-322_heg_abs3.pha'
# but not used; to use them, re-read with use_errors=True
# read background file h1743-322_heg_abs3_bkg.pha
# WARNING: systematic errors were not found in file 'h1743-322_meg_abs1.pha'
# statistical errors were found in file 'h1743-322_meg_abs1.pha'
# but not used; to use them, re-read with use_errors=True
# read ARF file h1743-322_meg_abs1.arf
# read RMF file h1743-322_meg_abs1.rmf
# read background file h1743-322_meg_abs1_bkg.pha
# WARNING: systematic errors were not found in file 'h1743-322_meg_abs2.pha'
# statistical errors were found in file 'h1743-322_meg_abs2.pha'
# but not used; to use them, re-read with use_errors=True
# read background file h1743-322_meg_abs2_bkg.pha
# WARNING: systematic errors were not found in file 'h1743-322_meg_abs3.pha'
# statistical errors were found in file 'h1743-322_meg_abs3.pha'
# but not used; to use them, re-read with use_errors=True
# read background file h1743-322_meg_abs3_bkg.pha
# 1: h1743-322_heg_abs1.pha OBS_ID: Merged MJD_OBS: 54515.1400341
# 2: h1743-322_heg_abs2.pha OBS_ID: Merged MJD_OBS: 54515.1400341
# 3: h1743-322_heg_abs3.pha OBS_ID: Merged MJD_OBS: 54515.1400341
# 4: h1743-322_meg_abs1.pha OBS_ID: Merged MJD_OBS: 54515.1400341
# 5: h1743-322_meg_abs2.pha OBS_ID: Merged MJD_OBS: 54515.1400341
# 6: h1743-322_meg_abs3.pha OBS_ID: Merged MJD_OBS: 54515.1400341
