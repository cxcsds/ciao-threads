# %% [markdown]
# # mkgrmf hrc s

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 460
 download_chandra_obsid 460 --exclude vvref,osol,eph1,evt1a
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits      163 Mb  ####################            4 s  37153.9 kb/s
#   evt1a    fits      143 Mb  ####################            4 s  40663.1 kb/s
#   evt2     fits       91 Mb  ####################            2 s  57150.5 kb/s
#   asol     fits       10 Mb  ####################          < 1 s  60014.4 kb/s
#   mtl      fits        6 Mb  ####################          < 1 s  11821.9 kb/s
#   aoff     fits        4 Mb  ####################          < 1 s  17342.2 kb/s
#   aqual    fits      614 Kb  ####################          < 1 s  25024.1 kb/s
#   pha2     fits      432 Kb  ####################          < 1 s  17091.1 kb/s
#   dtf      fits      418 Kb  ####################          < 1 s  13459.5 kb/s
#   cntr_img jpg       258 Kb  ####################          < 1 s  13342.4 kb/s
# ...

# %%
chandra_repro 460 out="./" clob+
# Out:
# Running chandra_repro
# version: 14 September 2021
#
#
# Processing input directory '/proj/sds/Staff/kjg/Threads/mkgrmf_hrcs/460'
#
# Applying boresight update to aspect solution file
# WARNING: The grating 0th order location must be recomputed when asol_update=yes.  Changing recreate_tg_mask=yes.
#
# Running hrc_build_badpix to create new bad pixel file...
#
# Running hrc_process_events to reprocess the evt1.fits file...
# Output from hrc_process_events:
# # hrc_process_events (CIAO 4.14):  WARNING:  range_switch_level  not found in /proj/sds/Staff/kjg/Threads/mkgrmf_hrcs/pcadf00460_repro_obs.par.
# # hrc_process_events (CIAO 4.14): WARNING: ra_nom in obsfile and infile not same. taking from obsfile.
#
# # hrc_process_events (CIAO 4.14): WARNING: dec_nom in obsfile and infile not same. taking from obsfile.
#
# # hrc_process_events (CIAO 4.14): The following error occurred 349 times:
# ...

# %% [markdown]
# ## About cal

# %%
ls -1 $CALDB/data/chandra/hrc/lsfparm/
# Out:
# hrcileg-1D1999-07-22lsfparmN0004.fits
# hrcileg1D1999-07-22lsfparmN0004.fits
# hrcsleg-1D1999-07-22lsfparmN0003.fits
# hrcsleg-1D1999-07-22lsfparmN0004.fits
# hrcsleg1D1999-07-22lsfparmN0003.fits
# hrcsleg1D1999-07-22lsfparmN0004.fits

# %% [markdown]
# ## Run mkgrmf

# %%
pset mkgrmf order=1
pset mkgrmf grating_arm=LEG
pset mkgrmf outfile=leg_p1.rmf
pset mkgrmf obsfile="hrcf00460_repro_evt2.fits[EVENTS]"
pset mkgrmf regionfile=hrcf00460_repro_pha2.fits
pset mkgrmf detsubsys=HRC-S2
pset mkgrmf wvgrid_arf=compute
pset mkgrmf wvgrid_chan=compute
mkgrmf mode=h clob+

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 460 tg hrcf00460* pcadf*
