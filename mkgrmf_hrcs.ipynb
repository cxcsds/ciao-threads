# %% [markdown]
# # mkgrmf hrc s

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 460
 download_chandra_obsid 460
# Out:
# Downloading files for ObsId 460, total size is 504 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      10 Kb  ####################          < 1 s  621.6 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  981.7 kb/s
#   vv       pdf        27 Kb  ####################          < 1 s  1948.4 kb/s
#   cntr_img jpg       258 Kb  ####################          < 1 s  7329.6 kb/s
#   evt2     fits       91 Mb  ####################            2 s  51946.3 kb/s
#   full_img jpg       107 Kb  ####################          < 1 s  2814.2 kb/s
#   pha2     fits      432 Kb  ####################          < 1 s  6703.0 kb/s
#   dtf      fits      418 Kb  ####################          < 1 s  12166.6 kb/s
#   fov      fits        5 Kb  ####################          < 1 s  768.0 kb/s
#   eph1     fits      301 Kb  ####################          < 1 s  5169.1 kb/s
#   asol     fits       10 Mb  ####################          < 1 s  52131.0 kb/s
#   vv       pdf        80 Mb  ####################            2 s  40615.1 kb/s
#   aoff     fits        4 Mb  ####################          < 1 s  13554.3 kb/s
#   bpix     fits        3 Kb  ####################          < 1 s  477.7 kb/s
#   evt1     fits      163 Mb  ####################            3 s  54041.6 kb/s
#   evt1a    fits      143 Mb  ####################            3 s  55258.4 kb/s
#   msk      fits        3 Kb  ####################          < 1 s  137.0 kb/s
#   mtl      fits        6 Mb  ####################          < 1 s  38683.9 kb/s
#   soff     fits       11 Kb  ####################          < 1 s  1505.2 kb/s
#   dtf      fits        4 Kb  ####################          < 1 s  517.1 kb/s
#   flt      fits        3 Kb  ####################          < 1 s  449.3 kb/s
#   eph1     fits       16 Kb  ####################          < 1 s  480.9 kb/s
#   eph1     fits      293 Kb  ####################          < 1 s  4351.5 kb/s
#   eph1     fits      271 Kb  ####################          < 1 s  3866.8 kb/s
#   osol     fits      357 Kb  ####################          < 1 s  5043.3 kb/s
#   aqual    fits      614 Kb  ####################          < 1 s  16588.4 kb/s
#   osol     fits      360 Kb  ####################          < 1 s  5209.4 kb/s
#   osol     fits      359 Kb  ####################          < 1 s  14041.8 kb/s
#   osol     fits      359 Kb  ####################          < 1 s  10255.2 kb/s
#   osol     fits      277 Kb  ####################          < 1 s  10221.7 kb/s
#   osol     fits      360 Kb  ####################          < 1 s  12797.5 kb/s
#   osol     fits      237 Kb  ####################          < 1 s  5533.8 kb/s
#   osol     fits      361 Kb  ####################          < 1 s  9346.9 kb/s
#
#       Total download size for ObsId 460 = 504 Mb
#       Total download time for ObsId 460 = 11 s

# %%
chandra_repro 460 out="./" clob+
# Out:
# Processing input directory '/data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs/460'
#
#
# Running hrc_build_badpix to create new bad pixel file...
#
# Running hrc_process_events to reprocess the evt1.fits file...
# Output from hrc_process_events:
# # hrc_process_events (CIAO 4.9): The following error occurred 1225 times:
# 	WARNING: can't find a proper degap value for this raw coord. in hrcf00460_000N005_evt1.fits
#
# # hrc_process_events (CIAO 4.9): The following error occurred 349 times:
# 	dsHPEEVENTSEQERR -- WARNING: Out of sequence events discovered in /data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs/460/secondary/hrcf00460_000N005_evt1.fits.
# Copy existing [REGION] block from evt2 file to use with tg_resolve_events
# Assign grating events to spectral orders with tg_resolve_events...
# The new evt1a file is: /data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs/hrcf00460_evt1a.fits
# Applying the HRC-S/LETG background filter...
# Filtering the evt1.fits file on grade and status...
# Applying the good time intervals from the flt1.fits file...
#
# Running hrc_dtfstats to recompute the average dead time corrections...
# The new level=2 event file is: /data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs/hrcf00460_repro_evt2.fits
# Extracting a grating spectrum with tgextract...
# The new level=2 PHA file is: /data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs/hrcf00460_repro_pha2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
# Setting observation-specific bad pixel file in local ardlib.par.
#
# Cleaning up intermediate files
#
# WARNING: Observation-specific bad pixel file set for session use:
#          /data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs/hrcf00460_repro_bpix1.fits
#          Run 'punlearn ardlib' when analysis of this dataset completed.
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /data/sdsreg/thread_output/CIAO4.9/mkgrmf_hrcs

# %% [markdown]
# ## About cal

# %%
ls -1 $CALDB/data/chandra/hrc/lsfparm/
# Out:
# hrcsleg-1D1999-07-22lsfparmN0003.fits
# hrcsleg-1D1999-07-22lsfparmN0004.fits
# hrcsleg1D1999-07-22lsfparmN0003.fits
# hrcsleg1D1999-07-22lsfparmN0004.fits

# %% [markdown]
# ## Run mkgrmf

# %%
pset mkgrmf order=1
pset mkgrmf grating_arm=LEG
pset mkgrmf outfile=leg_p1.rmf
pset mkgrmf obsfile="hrcf00460_repro_evt2.fits[EVENTS]"
pset mkgrmf regionfile=hrcf00460_repro_pha2.fits
pset mkgrmf detsubsys=HRC-S2
pset mkgrmf wvgrid_arf=compute
pset mkgrmf wvgrid_chan=compute
mkgrmf mode=h clob+
