# %% [markdown]
# # param files

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 1843
/bin/rm -f {acis,pcad}f*.fits
download_chandra_obsid 1843
mv -fv 1843/{primary,secondary}/*fits.gz .
gunzip -f {acis,pcad}f*.fits.gz
# Out:
# Downloading files for ObsId 1843, total size is 81 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb  ####################          < 1 s  1793.7 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  3424.6 kb/s
#   vv       pdf        40 Kb  ####################          < 1 s  5435.2 kb/s
#   cntr_img fits      237 Kb  ####################          < 1 s  14927.0 kb/s
#   cntr_img jpg       925 Kb  ####################          < 1 s  23214.8 kb/s
#   evt2     fits       17 Mb  ####################          < 1 s  71219.0 kb/s
#   full_img fits       80 Kb  ####################          < 1 s  8808.4 kb/s
#   full_img jpg        82 Kb  ####################          < 1 s  9004.8 kb/s
#   bpix     fits       13 Kb  ####################          < 1 s  2229.0 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  977.9 kb/s
#   eph1     fits      281 Kb  ####################          < 1 s  19037.7 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  48776.1 kb/s
#   evt1     fits       35 Mb  ####################          < 1 s  77825.2 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  750.8 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  935.8 kb/s
#   mtl      fits      344 Kb  ####################          < 1 s  22139.4 kb/s
#   stat     fits      290 Kb  ####################          < 1 s  19118.8 kb/s
#   bias     fits      426 Kb  ####################          < 1 s  22317.9 kb/s
#   bias     fits      494 Kb  ####################          < 1 s  23653.2 kb/s
#   bias     fits      430 Kb  ####################          < 1 s  21655.1 kb/s
#   bias     fits      423 Kb  ####################          < 1 s  22504.3 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  19117.4 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  22455.2 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  682.5 kb/s
#   vv       pdf        19 Mb  ####################          < 1 s  68420.2 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  531.2 kb/s
#   eph1     fits      274 Kb  ####################          < 1 s  18144.1 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  16714.7 kb/s
#   osol     fits      353 Kb  ####################          < 1 s  18058.8 kb/s
#   aqual    fits      148 Kb  ####################          < 1 s  11661.4 kb/s
#   osol     fits      343 Kb  ####################          < 1 s  19491.8 kb/s
#   osol     fits      354 Kb  ####################          < 1 s  18347.1 kb/s
#
#       Total download size for ObsId 1843 = 81 Mb
#       Total download time for ObsId 1843 = 1 s
#
# `1843/primary/acisf01843N003_cntr_img2.fits.gz' -> `./acisf01843N003_cntr_img2.fits.gz'
# `1843/primary/acisf01843N003_evt2.fits.gz' -> `./acisf01843N003_evt2.fits.gz'
# `1843/primary/acisf01843N003_full_img2.fits.gz' -> `./acisf01843N003_full_img2.fits.gz'
# `1843/primary/acisf01843_000N003_bpix1.fits.gz' -> `./acisf01843_000N003_bpix1.fits.gz'
# `1843/primary/acisf01843_000N003_fov1.fits.gz' -> `./acisf01843_000N003_fov1.fits.gz'
# `1843/primary/orbitf084197100N001_eph1.fits.gz' -> `./orbitf084197100N001_eph1.fits.gz'
# `1843/primary/pcadf084271087N003_asol1.fits.gz' -> `./pcadf084271087N003_asol1.fits.gz'
# `1843/secondary/acisf01843_000N003_evt1.fits.gz' -> `./acisf01843_000N003_evt1.fits.gz'
# `1843/secondary/acisf01843_000N003_flt1.fits.gz' -> `./acisf01843_000N003_flt1.fits.gz'
# `1843/secondary/acisf01843_000N003_msk1.fits.gz' -> `./acisf01843_000N003_msk1.fits.gz'
# `1843/secondary/acisf01843_000N003_mtl1.fits.gz' -> `./acisf01843_000N003_mtl1.fits.gz'
# `1843/secondary/acisf01843_000N003_stat1.fits.gz' -> `./acisf01843_000N003_stat1.fits.gz'
# `1843/secondary/acisf084271178N003_0_bias0.fits.gz' -> `./acisf084271178N003_0_bias0.fits.gz'
# `1843/secondary/acisf084271178N003_1_bias0.fits.gz' -> `./acisf084271178N003_1_bias0.fits.gz'
# `1843/secondary/acisf084271178N003_2_bias0.fits.gz' -> `./acisf084271178N003_2_bias0.fits.gz'
# `1843/secondary/acisf084271178N003_3_bias0.fits.gz' -> `./acisf084271178N003_3_bias0.fits.gz'
# `1843/secondary/acisf084271178N003_4_bias0.fits.gz' -> `./acisf084271178N003_4_bias0.fits.gz'
# `1843/secondary/acisf084271178N003_5_bias0.fits.gz' -> `./acisf084271178N003_5_bias0.fits.gz'
# `1843/secondary/acisf084272477N003_pbk0.fits.gz' -> `./acisf084272477N003_pbk0.fits.gz'

# %% [markdown]
# ## Reset defaults

# %%
punlearn dmlist
plist dmlist
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile =                  Input dataset/block specification
#            opt = data             Option
#       (outfile = )                Output file (optional)
#          (rows = )                Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %% [markdown]
# ## View

# %%
plist dmlist
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile =                  Input dataset/block specification
#            opt = data             Option
#       (outfile = )                Output file (optional)
#          (rows = )                Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %%
pline dmlist
# Out:
# infile='' opt='data' outfile='' rows='' cells='' verbose='0' mode='ql'

# %%
pget dmlist opt
# Out:
# data

# %%
pget dmlist infile

# %%
pdump dmlist
# Out:
# infile=''
# opt='data'
# outfile=''
# rows=''
# cells=''
# verbose='0'
# mode='ql'
# # EOF

# %%
dmlist + || echo
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile =                  Input dataset/block specification
#            opt = data             Option
#       (outfile = )                Output file (optional)
#          (rows = )                Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %%
plist dmlist dmcopy
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile =                  Input dataset/block specification
#            opt = data             Option
#       (outfile = )                Output file (optional)
#          (rows = )                Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)
#
#
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmcopy.par
#
#         infile =                  Input dataset/block specification
#        outfile = three.fits       Output dataset name
#        (kernel = default)         Output file format type
#        (option = )                Option - force output type
#       (verbose = 0)               Debug Level
#       (clobber = yes)             Clobber existing file
#          (mode = ql)

# %% [markdown]
# ## Setting Parameters

# %% [markdown]
# ### _Interactive parameter prompting not supported in this notebook_

# %% [markdown]
# ### One parameter

# %%
pset dmlist infile=pcadf084271087N002_asol1.fits
pset dmlist opt=cols
plist dmlist
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile = pcadf084271087N002_asol1.fits Input dataset/block specification
#            opt = cols             Option
#       (outfile = )                Output file (optional)
#          (rows = )                Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %% [markdown]
# ### Several at once

# %%
pset dmlist infile=acisf01843N002_evt2.fits opt=data rows=1:5
plist dmlist
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile = acisf01843N002_evt2.fits Input dataset/block specification
#            opt = data             Option
#       (outfile = )                Output file (optional)
#          (rows = 1:5)             Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %% [markdown]
# ### Setting to empty, blank string

# %% [markdown]
# ### _no interactive_

# %%
pset dmlist in=acisf01843N002_evt2.fits
pget dmlist infile
# Out:
# acisf01843N002_evt2.fits

# %%
pset dmlist infile=""
pget dmlist infile

# %% [markdown]
# ## Setting w/o pset

# %%
punlearn dmlist
dmlist infile=pcadf084271087N003_asol1.fits opt=cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block ASPSOL
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   time                 s            Real8          84271087.9497569948: 84280448.5063589960 Time field
#    2   ra                   deg          Real8          -Inf:+Inf            RA of MNC frame (x-axis)
#    3   dec                  deg          Real8          -Inf:+Inf            DEC of MNC frame (x-axis)
#    4   roll                 deg          Real8          -Inf:+Inf            ROLL of MNC frame
#    5   ra_err               deg          Real4          -Inf:+Inf            Uncertainty in  RA
#    6   dec_err              deg          Real4          -Inf:+Inf            Uncertainty in  DEC
#    7   roll_err             deg          Real4          -Inf:+Inf            Uncertainty in  ROLL
#    8   dy                   mm           Real4          -Inf:+Inf            dY of STF frame - FC frame
#    9   dz                   mm           Real4          -Inf:+Inf            dZ of STF frame - FC frame
#   10   dtheta               deg          Real4          -Inf:+Inf            dTHETA of STF frame - FC frame
#   11   dy_err               mm           Real4          -Inf:+Inf            Uncertainty in dY
#   12   dz_err               mm           Real4          -Inf:+Inf            Uncertainty in dZ
#   13   dtheta_err           deg          Real4          -Inf:+Inf            Uncertainty in dTHETA
#   14   q_att[4]                          Real8(4)       -Inf:+Inf            S/C attitude quaternion
#   15   roll_bias            deg/s        Real4          -Inf:+Inf            Roll bias rate
#   16   pitch_bias           deg/s        Real4          -Inf:+Inf            Pitch bias rate
#   17   yaw_bias             deg/s        Real4          -Inf:+Inf            Yaw bias rate
#   18   roll_bias_err        deg/s        Real4          -Inf:+Inf            Roll bias rate error
#   19   pitch_bias_err       deg/s        Real4          -Inf:+Inf            Pitch bias rate error
#   20   yaw_bias_err         deg/s        Real4          -Inf:+Inf            Yaw bias rate error

# %%
plist dmlist
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile = pcadf084271087N003_asol1.fits Input dataset/block specification
#            opt = cols             Option
#       (outfile = )                Output file (optional)
#          (rows = )                Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %% [markdown]
# ## Omitting parameter name

# %%
dmlist pcadf084271087N003_asol1.fits cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block ASPSOL
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   time                 s            Real8          84271087.9497569948: 84280448.5063589960 Time field
#    2   ra                   deg          Real8          -Inf:+Inf            RA of MNC frame (x-axis)
#    3   dec                  deg          Real8          -Inf:+Inf            DEC of MNC frame (x-axis)
#    4   roll                 deg          Real8          -Inf:+Inf            ROLL of MNC frame
#    5   ra_err               deg          Real4          -Inf:+Inf            Uncertainty in  RA
#    6   dec_err              deg          Real4          -Inf:+Inf            Uncertainty in  DEC
#    7   roll_err             deg          Real4          -Inf:+Inf            Uncertainty in  ROLL
#    8   dy                   mm           Real4          -Inf:+Inf            dY of STF frame - FC frame
#    9   dz                   mm           Real4          -Inf:+Inf            dZ of STF frame - FC frame
#   10   dtheta               deg          Real4          -Inf:+Inf            dTHETA of STF frame - FC frame
#   11   dy_err               mm           Real4          -Inf:+Inf            Uncertainty in dY
#   12   dz_err               mm           Real4          -Inf:+Inf            Uncertainty in dZ
#   13   dtheta_err           deg          Real4          -Inf:+Inf            Uncertainty in dTHETA
#   14   q_att[4]                          Real8(4)       -Inf:+Inf            S/C attitude quaternion
#   15   roll_bias            deg/s        Real4          -Inf:+Inf            Roll bias rate
#   16   pitch_bias           deg/s        Real4          -Inf:+Inf            Pitch bias rate
#   17   yaw_bias             deg/s        Real4          -Inf:+Inf            Yaw bias rate
#   18   roll_bias_err        deg/s        Real4          -Inf:+Inf            Roll bias rate error
#   19   pitch_bias_err       deg/s        Real4          -Inf:+Inf            Pitch bias rate error
#   20   yaw_bias_err         deg/s        Real4          -Inf:+Inf            Yaw bias rate error

# %%
dmlist pcadf084271087N003_asol1.fits cols outfile=output.txt
cat output.txt
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block ASPSOL
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   time                 s            Real8          84271087.9497569948: 84280448.5063589960 Time field
#    2   ra                   deg          Real8          -Inf:+Inf            RA of MNC frame (x-axis)
#    3   dec                  deg          Real8          -Inf:+Inf            DEC of MNC frame (x-axis)
#    4   roll                 deg          Real8          -Inf:+Inf            ROLL of MNC frame
#    5   ra_err               deg          Real4          -Inf:+Inf            Uncertainty in  RA
#    6   dec_err              deg          Real4          -Inf:+Inf            Uncertainty in  DEC
#    7   roll_err             deg          Real4          -Inf:+Inf            Uncertainty in  ROLL
#    8   dy                   mm           Real4          -Inf:+Inf            dY of STF frame - FC frame
#    9   dz                   mm           Real4          -Inf:+Inf            dZ of STF frame - FC frame
#   10   dtheta               deg          Real4          -Inf:+Inf            dTHETA of STF frame - FC frame
#   11   dy_err               mm           Real4          -Inf:+Inf            Uncertainty in dY
#   12   dz_err               mm           Real4          -Inf:+Inf            Uncertainty in dZ
#   13   dtheta_err           deg          Real4          -Inf:+Inf            Uncertainty in dTHETA
#   14   q_att[4]                          Real8(4)       -Inf:+Inf            S/C attitude quaternion
#   15   roll_bias            deg/s        Real4          -Inf:+Inf            Roll bias rate
#   16   pitch_bias           deg/s        Real4          -Inf:+Inf            Pitch bias rate
#   17   yaw_bias             deg/s        Real4          -Inf:+Inf            Yaw bias rate
#   18   roll_bias_err        deg/s        Real4          -Inf:+Inf            Roll bias rate error
#   19   pitch_bias_err       deg/s        Real4          -Inf:+Inf            Pitch bias rate error
#   20   yaw_bias_err         deg/s        Real4          -Inf:+Inf            Yaw bias rate error

# %% [markdown]
# ## order matters

# %%
dmlist pcadf084271087N003_asol1.fits op=blocks
# Out:
#
# --------------------------------------------------------------------------------
# Dataset: pcadf084271087N003_asol1.fits
# --------------------------------------------------------------------------------
#
#      Block Name                          Type         Dimensions
# --------------------------------------------------------------------------------
# Block    1: PRIMARY                        Null
# Block    2: ASPSOL                         Table        20 cols x 36529    rows

# %%
dmlist infile=pcadf084271087N003_asol1.fits blocks || echo ""
# Out:
# Sorry, Arguments not ok, try again.
# Problem opening parameter file: parameter error?

# %% [markdown]
# ## Hidden parameters not saved

# %%
punlearn dmlist
dmlist infile=acisf01843N003_evt2.fits"[cols time,sky,energy]" opt=data rows=1:2
# Out:
#
# --------------------------------------------------------------------------------
# Data for Table Block EVENTS
# --------------------------------------------------------------------------------
#
# ROW    time                 sky(x,y)                                 energy
#
#      1  84272488.5507295579 (     1442.1685791016,     3552.9848632812)       14032.38281250
#      2  84272488.5507295579 (     1896.7814941406,     3678.8435058594)     15597.4228515625

# %%
pget dmlist rows

# %%
pset dmlist rows=1:2

# %%
dmlist acisf01843N003_evt2.fits"[cols time,sky,energy]" data
# Out:
#
# --------------------------------------------------------------------------------
# Data for Table Block EVENTS
# --------------------------------------------------------------------------------
#
# ROW    time                 sky(x,y)                                 energy
#
#      1  84272488.5507295579 (     1442.1685791016,     3552.9848632812)       14032.38281250
#      2  84272488.5507295579 (     1896.7814941406,     3678.8435058594)     15597.4228515625

# %%
plist dmlist
# Out:
# Parameters for /data/sdsreg/thread_output/CIAO4.9/param_files/param/dmlist.par
#
#         infile = acisf01843N003_evt2.fits[cols time,sky,energy] Input dataset/block specification
#            opt = data             Option
#       (outfile = )                Output file (optional)
#          (rows = 1:2)             Range of table rows to print (min:max)
#         (cells = )                Range of array indices to print (min:max)
#       (verbose = 0)               Debug Level(0-5)
#          (mode = ql)

# %% [markdown]
# ## Abbreviations

# %%
punlearn dmcopy
pget dmcopy clobber
# Out:
# no

# %%
pset dmcopy cl+
pget dmcopy clobber
# Out:
# yes

# %%
pset dmcopy outfile=one.fits
pget dmcopy outfile
# Out:
# one.fits

# %%
pset dmcopy out=two.fits
pget dmcopy outfile
# Out:
# two.fits

# %%
pset dmcopy o=three.fits
pset dmcopy ou=three.fits
pget dmcopy outfile
# Out:
# parammatch : parameter name o not uniq (outfile, option)
# parameter not unique
# three.fits

# %%
dmlist in=pcadf084271087N003_asol1.fits out=list.txt opt=blocks
cat list.txt
# Out:
#
# --------------------------------------------------------------------------------
# Dataset: pcadf084271087N003_asol1.fits
# --------------------------------------------------------------------------------
#
#      Block Name                          Type         Dimensions
# --------------------------------------------------------------------------------
# Block    1: PRIMARY                        Null
# Block    2: ASPSOL                         Table        20 cols x 36529    rows

# %%
grep grouptype $ASCDS_INSTALL/param/dmgroup.par
# Out:
# grouptype,s,a,"NONE",NONE|BIN|SNR|NUM_BINS|NUM_CTS|ADAPTIVE|ADAPTIVE_SNR|BIN_WIDTH|MIN_SLOPE|MAX_SLOPE|BIN_FILE,,"Grouping type"
# grouptypeval,r,a,0,,,"Grouping type value"

# %%
punlearn dmgroup
pget dmgroup grouptype
# Out:
# NONE

# %%
pset dmgroup grouptype=MA
pget dmgroup grouptype
# Out:
# MAX_SLOPE

# %% [markdown]
# ## _no interactive_

# %% [markdown]
# ## Running multiple instances

# %%
apply_fov_limits acisf01843N003_evt2.fits[energy=500:7000] img.fits clob+ bin=8
# Out:
# Running: apply_fov_limits
#   version: 12 September 2016
# Observation: ObsId 1843 - ACIS-012367
# Using ccd_id=0,1,2,3,6,7 from acisf01843N003_evt2.fits[energy=500:7000]
# Calculating FOV file using:
#   Aspect solution pcadf084271087N003_asol1.fits
#   Mask file       acisf01843_000N003_msk1.fits
#
# The output image will have 445 by 310 pixels, pixel size of 3.936 arcsec,
#     and cover x=1200.5:4760.5:8,y=2664.5:5144.5:8.
#
# Created: img.fits

# %%
paccess aconvolve
# Out:
# /data/sdsreg/thread_output/CIAO4.9/param_files/param/aconvolve.par

# %%
cp -fv `paccess aconvolve` ./aconvolve.g3.par
chmod +w ./aconvolve.g3.par
# Out:
# `/data/sdsreg/thread_output/CIAO4.9/param_files/param/aconvolve.par' -> `./aconvolve.g3.par'

# %%
cp -fv `paccess aconvolve` ./aconvolve.g5.par
chmod +w ./aconvolve.g5.par
# Out:
# `/data/sdsreg/thread_output/CIAO4.9/param_files/param/aconvolve.par' -> `./aconvolve.g5.par'

# %%
pset aconvolve.g3.par infile=img.fits method=fft cl+
pset aconvolve.g3.par outfile=img.sm3.fits 
pset aconvolve.g3.par kernelspec="lib:gauss(2,5,1,3,3)"

# %%
pset aconvolve.g5.par infile=img.fits method=fft cl+
pset aconvolve.g5.par outfile=img.sm5.fits 
pset aconvolve.g5.par kernelspec="lib:gauss(2,5,1,5,5)"

# %%
aconvolve @@aconvolve.g3 mode=h && aconvolve @@aconvolve.g5 mode=h

# %% [markdown]
# ## White space

# %%
punlearn dmlist
pset dmlist infile=pcadf084271087N002_asol1.fits
pget dmlist infile
# Out:
# pcadf084271087N002_asol1.fits

# %%
pset dmlist infile= pcadf084271087N002_asol1.fits
pget dmlist infile
# Out:
# pcadf084271087N002_asol1.fits

# %%
pset dmlist infile = pcadf084271087N002_asol1.fits
pget dmlist infile
# Out:
# pcadf084271087N002_asol1.fits

# %%
pset dmlist infile =" pcadf084271087N002_asol1.fits"
pget dmlist infile
# Out:
#  pcadf084271087N002_asol1.fits

# %% [markdown]
# ## Redirects

# %%
pset acis_process_events eventdef=")stdlev1"
pget acis_process_events eventdef
# Out:
# {d:time,l:expno,s:ccd_id,s:node_id,s:chip,s:tdet,f:det,f:sky,s:phas,l:pha,l:pha_ro,f:energy,l:pi,s:fltgrade,s:grade,x:status}

# %%
plist dmimg2jpg | grep colors
# Out:
#  (colorstretch = 1)               Color lookup strech factor
#    (colorshift = 0)               Color lookup table shift
#        (invert = no)              Invert colors
#   (regioncolor = )colors.green -> 0 1 0) Region color triple
#     (gridcolor = )colors.white -> 1 1 1) Grid color triple

# %%
pget dmimg2jpg regioncolor
# Out:
# 0 1 0

# %%
pget colors green
# Out:
# 0 1 0

# %%
punlearn dmcoords
pset dmcoords infile=acisf01843N003_evt2.fits
pset dmcoords celfmt=deg
pset dmcoords ra="))dmkeypar acisf01843N003_evt2.fits ra_nom echo+"
pset dmcoords dec="))dmkeypar acisf01843N003_evt2.fits dec_nom echo+"
plist dmcoords | egrep -2 "ra =|dec ="
# Out:
#       logicalx =                  X coordinate in binned image [pixel]
#       logicaly =                  Y coordinate in binned image [pixel]
#             ra = ))dmkeypar acisf01843N003_evt2.fits ra_nom echo+ -> 278.04787065101 RA [deg or hh:mm:ss]
#            dec = ))dmkeypar acisf01843N003_evt2.fits dec_nom echo+ -> -10.57039625623 Dec [deg or dd:mm:ss]
#          theta =                  Off axis angle [arcmin]
#            phi =                  Azimuthal angle [deg]

# %%
pget dmcoords ra dec
# Out:
# 278.04787065101
# -10.57039625623

# %%
/bin/rm -rf 1843
/bin/rm -f acisf* pcadf* orbitf*
