# %%
#~ mkdir -p HL_Tau
#~ cd HL_Tau

ciaover -v
# Out:
# The current environment is configured for:
#   CIAO        : CIAO 4.15 Monday, November 21, 2022
#   Tools       : Package release 1  Monday, November 21, 2022
#   Sherpa      : Package release 1  Monday, November 21, 2022
#   Obsvis      : Not Installed
#   Core        : Package release 1  Monday, November 21, 2022
#   Contrib     : Package release 1  Tuesday, January 24, 2023
#   bindir      : /export/ciao_from_source/ciao-4.15/bin
#   Python path : /export/ciao_from_source/ciao-4.15/ots/bin
#   CALDB       : 4.10.4
#
# CIAO Installation: Linux
# System information:
# Linux lenin.cfa.harvard.edu 4.18.0-425.13.1.el8_7.x86_64 #1 SMP Thu Feb 2 13:01:45 EST 2023 x86_64 x86_64 x86_64 GNU/Linux

# %%
echo "18915,20906" | tr "," "\012" > obi.lis

# %%
download_chandra_obsid @obi.lis \
  --exclude evt2,vvref,adat,eph1,osol,full_img,cntr_img,oif,aqual,readme --quiet

chandra_repro @obi.lis out= clob+ verb=0

/bin/ls */repro/*evt2.fits > evt.lis

merge_obs @evt.lis"[ccd_id=7]" out=merge/out bin=1 band=broad psfecf=0.5 mode=h clob+ verb=0

# %%
punlearn wavdetect wrecon wtransform

for obsid in `stk_build @obi.lis out=stdout`
do
  punlearn wavdetect wrecon wtransform
  pset wavdetect \
     infile=merge/out_${obsid}_broad_thresh.img \
     expfile=merge/out_${obsid}_broad_thresh.expmap \
     psffile=merge/out_${obsid}_broad_thresh.psfmap \
     outfile=wav_${obsid}.src \
     scales="1.4 2 4" \
     scell=wav.cell defn=wav.nbg imagef=wav.recon clob+ 
  wavdetect mode=h
done

/bin/rm wav.cell wav.nbg wav.recon

# %%
ref=20906
for obsid in `stk_build @obi.lis out=stdout`
do

  punlearn wcs_match
  wcs_match infile=wav_${obsid}.src ref=wav_${ref}.src out=xform_${obsid}.fits method=trans radius=4 clob+ \
          wcs=merge/out_${obsid}_reproj_evt.fits
  dmlist xform_${obsid}.fits"[cols t1,t2]" data,clean
done
# Out:
# #  t1                   t2
#  -0.16420759778384    -0.59824529646612
# #  t1                   t2
#  0                    0

# %%
mkdir -p fine_astro

for obsid in `stk_build @obi.lis out=stdout`
do

  cp ${obsid}/repro/*{bpix,msk}1.fits fine_astro/
  cp merge/out_${obsid}_reproj_evt.fits fine_astro/out_${obsid}_reproj_fa_evt.fits 
  wcs_update fine_astro/out_${obsid}_reproj_fa_evt.fits trans=xform_${obsid}.fits outfile= \
    wcs=merge/out_${obsid}_reproj_evt.fits
  wcs_update ${obsid}/repro/pcadf${obsid}_00?N00?_asol1.fits \
    outfile=fine_astro/out_${obsid}_fa_asol.fits \
    trans=xform_${obsid}.fits wcs=merge/out_${obsid}_reproj_evt.fits clob+
  dmhedit fine_astro/out_${obsid}_reproj_fa_evt.fits file= op=add key=ASOLFILE value=out_${obsid}_fa_asol.fits

done

# %%
/bin/ls fine_astro/*evt.fits > fa_evt2.lis

merge_obs @fa_evt2.lis merge_fa/out bin=1 band=broad psfecf=0.5 mode=h clob+

punlearn wavdetect wrecon wtransform

pset wavdetect \
  infile=merge_fa/out_broad_thresh.img \
  expfile=merge_fa/out_broad_thresh.expmap \
  psffile=merge_fa/out_broad_thresh.psfmap \
  outfile=wav_merge.src scell=wav.cell defn=wav.nbkg imagef=wav.recon \
  scales="1.4 2 4" clob+

wavdetect mode=h
# Out:
# Running merge_obs
# Version: 05 November 2021
#
# Verifying 2 observations.
# Using CSC ACIS broad science energy band.
# Calculating new tangent point.
# New tangent point: RA=4h 31m 38.078s Dec=18d 13' 59.24"
#
# Observations to be reprojected:
#
#   Obsid  Obs Date   Exp    DETNAM     SIM_Z    FP   Sepn   PA
#                    (ks)                (mm)    (K)   (')  (deg)
# ---------------------------------------------------------------
# 1 20906 2017-12-27  36.0 ACIS-678    -190.140 155.5  < 3"   -15
# 2 18915 2018-01-06  26.9 ACIS-678    -190.143 157.6  < 3"  +165
#
# Running tasks in parallel with 4 processors.
# Reprojecting 2 event files to a common tangent point.
# Merging reprojected events files to merge_fa/out_merged_evt.fits
#
# Calculating the output grid
#
# The merged images will have 556 by 1095 pixels, a pixel size of 0.492 arcsec,
#     and cover x=3875.5:4431.5:1, y=3835.5:4930.5:1.
#
# Creating the fluxed images for 2 observations in parallel.
# Creating aspect histogram for obsid 20906
# Creating aspect histogram for obsid 18915
# Creating instrument map for obsid 18915
# Creating instrument map for obsid 20906
# Creating exposure map for obsid 18915
# Creating exposure map for obsid 20906
# Thresholding data for obsid 18915
# Exposure-correcting image for obsid 18915
# Creating PSF map for obsid 18915
# Thresholding data for obsid 20906
# Exposure-correcting image for obsid 20906
# Creating PSF map for obsid 20906
#
# Combining 2 observations.
#
# The following files were created:
#
# The co-added clipped counts image is:
#      merge_fa/out_broad_thresh.img
#
# The co-added clipped exposure map is:
#      merge_fa/out_broad_thresh.expmap
#
# The combined PSF map is:
#      merge_fa/out_broad_thresh.psfmap
#
# The combined FOV is:
#      merge_fa/out_merged.fov
#
# The co-added exposure-corrected image is:
#      merge_fa/out_broad_flux.img
#
# Warning: the merged event file merge_fa/out_merged_evt.fits
#    should not be used to create ARF/RMF/exposure maps because
#       the FP_TEMP keyword varies by 2.1 (limit is 2.0)

# %%
dmlist wav_merge.src counts
# Out:
# 6

# %%
/bin/rm my_plugin*
wget -q https://cxc.cfa.harvard.edu/ciao/threads/srcflux_plugin/my_plugin.py
pygmentize my_plugin.py
# Out:
# 'An example plugin for the scrflux script'
#
# import os
# import numpy as np
# import matplotlib
# import matplotlib.pylab as plt
# from sherpa.astro.ui import *
#
# from collections import namedtuple
# ReturnValue = namedtuple('ReturnValue', 'name value units description')
#
# matplotlib.use("agg")
#
# def srcflux_obsid_plugin(infile, outroot, band, elo, ehi, src_num):
#     """
#     Sample srcflux plugin: fitting spectrum for each individual obsid
#
#     This sample plugin uses sherpa to fit a spectral model, and
#     return an estimate of the flux w/ errors calculated with
#     the sample_flux routine.
#
#     We wrap the actual fitting code below in a try/except block
#     here so that we can always return nan's in the case of any error.
#     """
#
#     try:
#         return doit_specfit(infile, outroot, band, elo, ehi, src_num)
#     except Exception as wrong:
#         print(str(wrong))
#         print(f"Problem fitting {outroot} spectrum. Skipping it.")
#
#         return [ReturnValue("fitted_Nh", np.nan, "cm**22", "Fitted Absorption value"),
#                 ReturnValue("kT", np.nan, "keV", "Plasma Temperature"),
#                 ReturnValue("normalization", np.nan, "", "Spectrum Normalization"),
#                 ReturnValue("reduced_statistic", np.nan, "", "Reduced Fit Statistic"),
#                 ReturnValue("fit_statistic", np.nan, "", "Fit Statistic"),
#                 ReturnValue("dof", np.nan, "", "Degrees of Freedom"),
#                 ReturnValue("sample_flux", np.nan, "", "2-10 keV Sample Flux"),
#                 ReturnValue("sample_flux_lo", np.nan, "", "2-10 Sample Flux Uncertainty Low"),
#                 ReturnValue("sample_flux_hi", np.nan, "", "2-10 Sample Flux Uncertainty Low"),
#                 ]
#
#
# def srcflux_merge_plugin(infile, outroot, band, elo, ehi, src_num):
#     """
#     Sample srcflux plugin: fitting spectrum for the combine spectra.
#
#     In this example it is the same plugin as the per-observation plugin,
#     but it does not have to be.
#     """
#
#     return srcflux_obsid_plugin(infile, outroot, band, elo, ehi, src_num)
#
#
# def doit_specfit(infile, outroot, band, elo, ehi, src_num):
#     'Perform the spectral fit: an absorbed APEEC model'
#
#     from sherpa.utils.logging import SherpaVerbosity
#
#     # Find the spectrum file (per-obi vs. merged file names)
#     if os.path.exists(outroot+".pi"):
#         pi_file = outroot+".pi"
#     elif os.path.exists(outroot+"_src.pi"):
#         pi_file = outroot+"_src.pi"
#     else:
#         raise IOError(f"Unable to locate source spectrum for this source number: {src_num}")
#
#     # Suppress some of the sherpa chatter
#     with SherpaVerbosity('WARN'):
#         load_data(pi_file)
#         group_counts(10)
#         set_source(xsphabs.abs1*xsapec.thrm)
#         set_method("neldermead")
#         subtract()
#         counts = calc_data_sum(lo=0.5, hi=7.0)
#         if counts < 100:
#             raise ValueError(f"{pi_file} only has {counts} counts. Need 100 to do spectral fit")
#         notice(0.5, 8.0)
#         fit()
#         fit_info = get_fit_results()
#         fflux, cflux, vals = sample_flux(lo=2.0, hi=10.0)
#         f0, fhi, flo = cflux
#         plot_fit_delchi()
#         plt.savefig(outroot+".png")
#
#     return [ReturnValue("fitted_Nh", abs1.nH.val, "cm**-22", "Fitted Absorption value"),
#             ReturnValue("kT", thrm.kT.val, "keV", "Plasma Temperature"),
#             ReturnValue("normalization", thrm.norm.val, "", "Spectrum Normalization"),
#             ReturnValue("reduced_statistic", fit_info.rstat, "", "Reduced Fit Statistic"),
#             ReturnValue("fit_statistic", fit_info.statval, "", "Fit Statistic"),
#             ReturnValue("dof", fit_info.dof, "", "Degrees of Freedom"),
#             ReturnValue("sample_flux", f0, "", "2-10 keV Sample Flux"),
#             ReturnValue("sample_flux_lo", flo, "", "2-10 keV Sample Flux Uncertainty Low"),
#             ReturnValue("sample_flux_hi", fhi, "", "2-10 Sample Flux Uncertainty Low"),
#             ]

# %%
mkdir -p flux
punlearn srcflux

srcflux \
  infile=@fa_evt2.lis \
  pos=wav_merge.src \
  outroot=flux/out \
  psfmethod=marx \
  bkgresp=yes conf=0.68 \
  plugin=my_plugin.py \
  mode=h clob+
# Out:
# srcflux
#           infile = @fa_evt2.lis
#              pos = wav_merge.src
#          outroot = flux/out
#            bands = default
#           srcreg =
#           bkgreg =
#          bkgresp = yes
#        psfmethod = marx
#          psffile =
#             conf = 0.68
#          binsize = 1
#          rmffile =
#          arffile =
#            model = xspowerlaw.pow1
#        paramvals = pow1.PhoIndex=2.0
#         absmodel = xsphabs.abs1
#        absparams = abs1.nH=%GAL%
#            abund = angr
#       pluginfile = my_plugin.py
#          fovfile =
#         asolfile =
#          mskfile =
#         bpixfile =
#          dtffile =
#          ecffile = CALDB
#         parallel = yes
#            nproc = INDEF
#           tmpdir = /tmp
#      random_seed = -1
#          clobber = yes
#          verbose = 1
#             mode = h
#
# Processing OBI 001
# Extracting counts
# Simulating psfs using marx
# Simulating PSF: flux/out_obi001_0001_broad
# Simulating PSF: flux/out_obi001_0002_broad
# Simulating PSF: flux/out_obi001_0003_broad
# Simulating PSF: flux/out_obi001_0004_broad
# Simulating PSF: flux/out_obi001_0005_broad
# Simulating PSF: flux/out_obi001_0006_broad
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Getting variability
# Running tasks in parallel with 4 processors.
# Running aprates for flux/out_obi001_0001_broad_rates.par
# Running aprates for flux/out_obi001_0002_broad_rates.par
# Running aprates for flux/out_obi001_0003_broad_rates.par
# Running aprates for flux/out_obi001_0004_broad_rates.par
# Running aprates for flux/out_obi001_0005_broad_rates.par
# Running aprates for flux/out_obi001_0006_broad_rates.par
# Running eff2evt for flux/out_obi001_broad_0001_src.dat
# Running eff2evt for flux/out_obi001_broad_0002_src.dat
# Running eff2evt for flux/out_obi001_broad_0003_src.dat
# Running eff2evt for flux/out_obi001_broad_0004_src.dat
# Running eff2evt for flux/out_obi001_broad_0005_src.dat
# Running eff2evt for flux/out_obi001_broad_0006_src.dat
# Running eff2evt for flux/out_obi001_broad_0001_bkg.dat
# Running eff2evt for flux/out_obi001_broad_0002_bkg.dat
# Running eff2evt for flux/out_obi001_broad_0003_bkg.dat
# Running eff2evt for flux/out_obi001_broad_0004_bkg.dat
# Running eff2evt for flux/out_obi001_broad_0005_bkg.dat
# Running eff2evt for flux/out_obi001_broad_0006_bkg.dat
# Making response files for flux/out_obi001_0001
# Making response files for flux/out_obi001_0002
# Making response files for flux/out_obi001_0003
# Making response files for flux/out_obi001_0004
# Running modeflux for region 1
# Using GAL=0.1807 for source 1
# Running modeflux for region 2
# Using GAL=0.1809 for source 2
# Running modeflux for region 4
# Using GAL=0.1814 for source 4
# Running modeflux for region 3
# Using GAL=0.1807 for source 3
# Making response files for flux/out_obi001_0005
# Making response files for flux/out_obi001_0006
# Running fluximage for flux/out_obi001_0001
# Running fluximage for flux/out_obi001_0002
# Running fluximage for flux/out_obi001_0003
# Running fluximage for flux/out_obi001_0004
# Running fluximage for flux/out_obi001_0005
# Running fluximage for flux/out_obi001_0006
# Making Lightcurve for source 1
# Making Lightcurve for source 2
# Running modeflux for region 5
# Running modeflux for region 6
# Using GAL=0.1811 for source 5
# Using GAL=0.1821 for source 6
# Making Lightcurve for source 3
# Making Lightcurve for source 4
# Making Lightcurve for source 5
# Making Lightcurve for source 6
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Appending variability results onto output
# Running user plugin from 'my_plugin.py'
# flux/out_obi001_0001.pi only has 14.44082023906261 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi001_0001 spectrum. Skipping it.
# flux/out_obi001_0002.pi only has 3.0032852954630744 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi001_0002 spectrum. Skipping it.
# flux/out_obi001_0003.pi only has 31.003395044292073 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi001_0003 spectrum. Skipping it.
# Reading APEC data from 3.0.9
#
# flux/out_obi001_0006.pi only has 7.9182515358234244 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi001_0006 spectrum. Skipping it.
# Processing OBI 002
# Extracting counts
# Simulating psfs using marx
# Simulating PSF: flux/out_obi002_0001_broad
# Simulating PSF: flux/out_obi002_0002_broad
# Simulating PSF: flux/out_obi002_0003_broad
# Simulating PSF: flux/out_obi002_0004_broad
# Simulating PSF: flux/out_obi002_0005_broad
# Simulating PSF: flux/out_obi002_0006_broad
# Getting net rate and confidence limits
# Getting model independent fluxes
# Getting model fluxes
# Getting photon fluxes
# Getting variability
# Running tasks in parallel with 4 processors.
# Running aprates for flux/out_obi002_0001_broad_rates.par
# Running aprates for flux/out_obi002_0002_broad_rates.par
# Running aprates for flux/out_obi002_0003_broad_rates.par
# Running aprates for flux/out_obi002_0004_broad_rates.par
# Running aprates for flux/out_obi002_0005_broad_rates.par
# Running aprates for flux/out_obi002_0006_broad_rates.par
# Running eff2evt for flux/out_obi002_broad_0001_src.dat
# Running eff2evt for flux/out_obi002_broad_0002_src.dat
# Running eff2evt for flux/out_obi002_broad_0003_src.dat
# Running eff2evt for flux/out_obi002_broad_0004_src.dat
# Running eff2evt for flux/out_obi002_broad_0005_src.dat
# Running eff2evt for flux/out_obi002_broad_0006_src.dat
# Running eff2evt for flux/out_obi002_broad_0001_bkg.dat
# Running eff2evt for flux/out_obi002_broad_0002_bkg.dat
# Running eff2evt for flux/out_obi002_broad_0003_bkg.dat
# Running eff2evt for flux/out_obi002_broad_0004_bkg.dat
# Running eff2evt for flux/out_obi002_broad_0005_bkg.dat
# Running eff2evt for flux/out_obi002_broad_0006_bkg.dat
# Making response files for flux/out_obi002_0001
# Making response files for flux/out_obi002_0002
# Making response files for flux/out_obi002_0003
# Making response files for flux/out_obi002_0004
# Running modeflux for region 3
# Running modeflux for region 2
# Using GAL=0.1807 for source 3
# Using GAL=0.1809 for source 2
# Running modeflux for region 4
# Using GAL=0.1814 for source 4
# Running modeflux for region 1
# Using GAL=0.1807 for source 1
# Making response files for flux/out_obi002_0005
# Making response files for flux/out_obi002_0006
# Running fluximage for flux/out_obi002_0001
# Running fluximage for flux/out_obi002_0002
# Running fluximage for flux/out_obi002_0003
# Running fluximage for flux/out_obi002_0004
# Running fluximage for flux/out_obi002_0005
# Running fluximage for flux/out_obi002_0006
# Running modeflux for region 6
# Running modeflux for region 5
# Using GAL=0.1821 for source 6
# Using GAL=0.1811 for source 5
# Making Lightcurve for source 1
# Making Lightcurve for source 2
# Making Lightcurve for source 3
# Making Lightcurve for source 4
# Making Lightcurve for source 5
# Making Lightcurve for source 6
# Adding net rates to output
# Appending flux results onto output
# Appending photflux results onto output
# Computing Net fluxes
# Adding model fluxes to output
# Scaling model flux confidence limits
# Appending variability results onto output
# Running user plugin from 'my_plugin.py'
# flux/out_obi002_0001.pi only has 23.22241617768667 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi002_0001 spectrum. Skipping it.
# flux/out_obi002_0002.pi only has 18.821272454515007 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi002_0002 spectrum. Skipping it.
# flux/out_obi002_0003.pi only has 14.63876212278057 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi002_0003 spectrum. Skipping it.
# WARNING: hard minimum hit for parameter abs1.nH
# WARNING: hard maximum hit for parameter abs1.nH
# WARNING: hard minimum hit for parameter thrm.kT
# WARNING: hard maximum hit for parameter thrm.kT
# WARNING: hard minimum hit for parameter thrm.norm
# WARNING: hard maximum hit for parameter thrm.norm
# WARNING: Covariance failed for 'abs1.nH', trying Confidence...
# WARNING: Covariance failed for 'thrm.kT', trying Confidence...
# WARNING: Covariance failed for 'thrm.norm', trying Confidence...
# flux/out_obi002_0006.pi only has 4.50757727416939 counts. Need 100 to do spectral fit
# Problem fitting flux/out_obi002_0006 spectrum. Skipping it.
# Combining count rates
# Combining spectra and running model flux for each source
# Running modeflux for region 1
# Using GAL=0.1807 for source 1
# Running modeflux for region 2
# Using GAL=0.1809 for source 2
# Running modeflux for region 3
# Using GAL=0.1807 for source 3
# Running modeflux for region 4
# Using GAL=0.1814 for source 4
# Running modeflux for region 5
# Using GAL=0.1811 for source 5
# Running modeflux for region 6
# Using GAL=0.1821 for source 6
# Running user plugin from 'my_plugin.py'
# flux/out_0001_src.pi only has 37.66323641674928 counts. Need 100 to do spectral fit
# Problem fitting flux/out_0001 spectrum. Skipping it.
# flux/out_0002_src.pi only has 22.552543701019964 counts. Need 100 to do spectral fit
# Problem fitting flux/out_0002 spectrum. Skipping it.
# flux/out_0003_src.pi only has 45.32505559025648 counts. Need 100 to do spectral fit
# Problem fitting flux/out_0003 spectrum. Skipping it.
# flux/out_0006_src.pi only has 14.154296401621957 counts. Need 100 to do spectral fit
# Problem fitting flux/out_0006 spectrum. Skipping it.
#
#
# Summary of source fluxes in OBI 001
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|4 31 40.28 +18 12 11.9  Rate           0.000636 c/s (0.000483,0.000815)
#                               Flux           8.43E-15 erg/cm2/s (6.4E-15,1.08E-14)
#                               Mod.Flux       1.42E-14 erg/cm2/s (1.08E-14,1.81E-14)
#                               Unabs Mod.Flux 1.8E-14 erg/cm2/s (1.37E-14,2.31E-14)
#
# #0002|4 31 39.02 +18 13 3.2   Rate           7.6E-05 c/s (2.66E-05,0.000156)
#                               Flux           7.29E-16 erg/cm2/s (2.55E-16,1.5E-15)
#                               Mod.Flux       7.91E-16 erg/cm2/s (2.76E-16,1.63E-15)
#                               Unabs Mod.Flux 1.01E-15 erg/cm2/s (3.52E-16,2.07E-15)
#
# #0003|4 31 36.14 +18 13 42.7  Rate           0.00132 c/s (0.0011,0.00158)
#                               Flux           3.05E-14 erg/cm2/s (2.53E-14,3.63E-14)
#                               Mod.Flux       1.39E-14 erg/cm2/s (1.15E-14,1.65E-14)
#                               Unabs Mod.Flux 1.77E-14 erg/cm2/s (1.47E-14,2.1E-14)
#
# #0004|4 31 40.08 +18 13 56.4  Rate           0.0534 c/s (0.0519,0.055)
#                               Flux           4.76E-13 erg/cm2/s (4.63E-13,4.9E-13)
#                               Mod.Flux       5.55E-13 erg/cm2/s (5.4E-13,5.71E-13)
#                               Unabs Mod.Flux 7.08E-13 erg/cm2/s (6.88E-13,7.28E-13)
#
# #0005|4 31 38.40 +18 13 57.0  Rate           0.0507 c/s (0.0493,0.0522)
#                               Flux           7.46E-13 erg/cm2/s (7.25E-13,7.68E-13)
#                               Mod.Flux       5.27E-13 erg/cm2/s (5.12E-13,5.42E-13)
#                               Unabs Mod.Flux 6.72E-13 erg/cm2/s (6.53E-13,6.91E-13)
#
# #0006|4 31 38.35 +18 16 14.7  Rate           0.000242 c/s (0.000153,0.00036)
#                               Flux           2.93E-15 erg/cm2/s (1.85E-15,4.34E-15)
#                               Mod.Flux       3.1E-15 erg/cm2/s (1.96E-15,4.6E-15)
#                               Unabs Mod.Flux 3.96E-15 erg/cm2/s (2.5E-15,5.87E-15)
#
#
#
# Summary of source fluxes in OBI 002
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|4 31 40.28 +18 12 11.9  Rate           0.000729 c/s (0.00059,0.000889)
#                               Flux           1.18E-14 erg/cm2/s (9.57E-15,1.44E-14)
#                               Mod.Flux       1.72E-14 erg/cm2/s (1.39E-14,2.1E-14)
#                               Unabs Mod.Flux 2.19E-14 erg/cm2/s (1.77E-14,2.67E-14)
#
# #0002|4 31 39.02 +18 13 3.2   Rate           0.000536 c/s (0.000413,0.000678)
#                               Flux           7.44E-15 erg/cm2/s (5.74E-15,9.42E-15)
#                               Mod.Flux       5.57E-15 erg/cm2/s (4.29E-15,7.04E-15)
#                               Unabs Mod.Flux 7.09E-15 erg/cm2/s (5.47E-15,8.98E-15)
#
# #0003|4 31 36.14 +18 13 42.7  Rate           0.000445 c/s (0.000333,0.000578)
#                               Flux           6.1E-15 erg/cm2/s (4.56E-15,7.92E-15)
#                               Mod.Flux       4.65E-15 erg/cm2/s (3.48E-15,6.04E-15)
#                               Unabs Mod.Flux 5.92E-15 erg/cm2/s (4.43E-15,7.69E-15)
#
# #0004|4 31 40.08 +18 13 56.4  Rate           0.0425 c/s (0.0413,0.0436)
#                               Flux           3.76E-13 erg/cm2/s (3.66E-13,3.86E-13)
#                               Mod.Flux       4.4E-13 erg/cm2/s (4.28E-13,4.53E-13)
#                               Unabs Mod.Flux 5.62E-13 erg/cm2/s (5.46E-13,5.77E-13)
#
# #0005|4 31 38.40 +18 13 57.0  Rate           0.0278 c/s (0.0269,0.0288)
#                               Flux           3.79E-13 erg/cm2/s (3.66E-13,3.92E-13)
#                               Mod.Flux       2.88E-13 erg/cm2/s (2.78E-13,2.98E-13)
#                               Unabs Mod.Flux 3.67E-13 erg/cm2/s (3.55E-13,3.8E-13)
#
# #0006|4 31 38.35 +18 16 14.7  Rate           0.000212 c/s (0.000137,0.000307)
#                               Flux           4.33E-15 erg/cm2/s (2.8E-15,6.27E-15)
#                               Mod.Flux       2.56E-15 erg/cm2/s (1.66E-15,3.72E-15)
#                               Unabs Mod.Flux 3.27E-15 erg/cm2/s (2.12E-15,4.75E-15)
#
#
#
# Summary of merged source fluxes
#
#       Position                               0.5 - 7.0 keV
#                                              Value        68% Conf Interval
# #0001|4 31 40.28 +18 12 11.9  Rate           0.000699 c/s (0.000594,0.000817)
#   NumObi=2                    Mod.Flux       1.61E-14 erg/cm2/s (1.37E-14,1.88E-14)
#                               Unabs Mod.Flux 2.05E-14 erg/cm2/s (1.74E-14,2.4E-14)
#
# #0002|4 31 39.02 +18 13 3.2   Rate           0.000342 c/s (0.000268,0.000429)
#   NumObi=2                    Mod.Flux       3.55E-15 erg/cm2/s (2.78E-15,4.46E-15)
#                               Unabs Mod.Flux 4.52E-15 erg/cm2/s (3.54E-15,5.68E-15)
#
# #0003|4 31 36.14 +18 13 42.7  Rate           0.000826 c/s (0.000703,0.000951)
#   NumObi=2                    Mod.Flux       8.64E-15 erg/cm2/s (7.35E-15,9.94E-15)
#                               Unabs Mod.Flux 1.1E-14 erg/cm2/s (9.36E-15,1.27E-14)
#
# #0004|4 31 40.08 +18 13 56.4  Rate           0.0471 c/s (0.0462,0.0481)
#   NumObi=2                    Mod.Flux       4.89E-13 erg/cm2/s (4.79E-13,4.99E-13)
#                               Unabs Mod.Flux 6.24E-13 erg/cm2/s (6.11E-13,6.36E-13)
#
# #0005|4 31 38.40 +18 13 57.0  Rate           0.0377 c/s (0.0368,0.0385)
#   NumObi=2                    Mod.Flux       3.91E-13 erg/cm2/s (3.82E-13,3.99E-13)
#                               Unabs Mod.Flux 4.98E-13 erg/cm2/s (4.87E-13,5.09E-13)
#
# #0006|4 31 38.35 +18 16 14.7  Rate           0.000225 c/s (0.000166,0.000297)
#   NumObi=2                    Mod.Flux       2.79E-15 erg/cm2/s (2.06E-15,3.68E-15)
#                               Unabs Mod.Flux 3.57E-15 erg/cm2/s (2.63E-15,4.69E-15)

# %%
dmlist flux/out_obi001_broad.flux cols
# Out:
#
#
# ⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼
#
# Columns for Table Block HISTOGRAM
#
# ⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼
#
#
# ColNo  Name                 Unit        Type             Range
#    1   sky(X,Y)             pixel        Real8          -Inf:+Inf            Position
#    2   EQPOS(RA,Dec)        deg          Real8          -360.0:360.0         Position
#    3   SHAPE                             String[16]                          Region shape type
#    4   R[2]                 pixel        Real8(2)       -Inf:+Inf            Radius
#    5   RMID                 pixel        Real8          -Inf:+Inf            Mean of valid R[2] values
#    6   ROTANG[2]            pixel        Real8(2)       -Inf:+Inf            Angle
#    7   COMPONENT                         Int2           -                    Component number
#    8   COUNTS               count        Real8          -Inf:+Inf            Counts
#    9   ERR_COUNTS           count        Real8          -Inf:+Inf            Error on counts
#   10   AREA                 pixel**2     Real8          -Inf:+Inf            Area of extraction
#   11   EXPOSURE             s            Real8          -Inf:+Inf            Exposure time of source file
#   12   COUNT_RATE           count/s      Real8          -Inf:+Inf            Rate
#   13   COUNT_RATE_ERR       count/s      Real8          -Inf:+Inf            Rate Error
#   14   BG_COUNTS            count        Real8          -Inf:+Inf            Background Counts
#   15   BG_ERR               count        Real8          -Inf:+Inf            Error on Background counts
#   16   BG_AREA              pixel**2     Real8          -Inf:+Inf            Background Area of Extraction
#   17   BG_EXPOSURE          s            Real8          -Inf:+Inf            Exposure time of background file
#   18   BG_RATE              count/s      Real8          -Inf:+Inf            Background Rate
#   19   BG_SUR_BRI           count/pixel**2 Real8          -Inf:+Inf            Background Counts per square pixel
#   20   BG_SUR_BRI_ERR       count/pixel**2 Real8          -Inf:+Inf            Error on background counts per square pixel
#   21   NET_COUNTS           count        Real8          -Inf:+Inf            Net Counts
#   22   NET_ERR              count        Real8          -Inf:+Inf            Error on Net Counts
#   23   NET_RATE             count/s      Real8          -Inf:+Inf            Net Count Rate
#   24   ERR_RATE             count/s      Real8          -Inf:+Inf            Error Rate
#   25   SUR_BRI              count/pixel**2 Real8          -Inf:+Inf            Net Counts per square pixel
#   26   SUR_BRI_ERR          count/pixel**2 Real8          -Inf:+Inf            Error on net counts per square pixel
#   27   XPOS                 pixel        Real8          -Inf:+Inf            X center
#   28   YPOS                 pixel        Real8          -Inf:+Inf            Y center
#   29   THETA                arcmin       Real8          -Inf:+Inf            Off axis angle
#   30   PHI                  deg          Real8          -Inf:+Inf            Azimuth angle
#   31   RAPOS                deg          Real8          -Inf:+Inf            Right Ascencion
#   32   DECPOS               deg          Real8          -Inf:+Inf            Declination
#   33   INSIDE_FOV                        Logical                             Is XPOS,YPOS inside the FOV?
#   34   NEAR_CHIP_EDGE                    Logical                             Is POS near or off any chip edge?
#   35   CHIP_ID                           Int4           -                    Chip ID
#   36   CHIPX                pixel        Real8          -Inf:+Inf            Chip X
#   37   CHIPY                pixel        Real8          -Inf:+Inf            Chip Y
#   38   PSFFRAC              count        Real8          -Inf:+Inf            Source region PSF fraction
#   39   BG_PSFFRAC           count        Real8          -Inf:+Inf            Background region PSF fraction
#   40   NET_RATE_APER        counts/s     Real8          -Inf:+Inf            Net count rate
#   41   NET_RATE_APER_LO     counts/s     Real8          -Inf:+Inf            Lower limit on net count rate
#   42   NET_RATE_APER_HI     counts/s     Real8          -Inf:+Inf            Upper limit on net count rate
#   43   SRC_SIGNIFICANCE                  Real8          -Inf:+Inf            Source significance
#   44   FLUX_APER            ergs/cm**2/s Real8          -Inf:+Inf            Sum eff2evt flux in src region
#   45   BG_FLUX_APER         ergs/cm**2/s Real8          -Inf:+Inf            Sum eff2evt flux in bkg region
#   46   SRC_PHOTFLUX         photon/cm**2/s Real8          -Inf:+Inf            Sum of flux image in src region
#   47   BG_PHOTFLUX          photon/cm**2/s Real8          -Inf:+Inf            Sum of the flux image in background region
#   48   MEAN_SRC_EXP         cm**2        Real8          -Inf:+Inf            Mean source expmap value
#   49   MEAN_BG_EXP          cm**2        Real8          -Inf:+Inf            Mean background expmap value
#   50   NET_FLUX_APER        ergs/cm**2/s Real8          -Inf:+Inf            Model independent flux
#   51   NET_FLUX_APER_LO     ergs/cm**2/s Real8          -Inf:+Inf            Model independent flux lower limit
#   52   NET_FLUX_APER_HI     ergs/cm**2/s Real8          -Inf:+Inf            Model independent flux upper limit
#   53   UPPER_LIMIT                       Logical                             Was upper limit used?
#   54   NET_PHOTFLUX_APER    photon/cm**2/s Real8          -Inf:+Inf            Photon flux counts/expmap
#   55   NET_PHOTFLUX_APER_LO photon/cm**2/s Real8          -Inf:+Inf            Photon flux lower limit
#   56   NET_PHOTFLUX_APER_HI photon/cm**2/s Real8          -Inf:+Inf            Photon flux upper limit
#   57   MFLUX_CNV                         Real8          -Inf:+Inf            model flux rate conversion
#   58   UMFLUX_CNV                        Real8          -Inf:+Inf            unabsorbed model flux rate conversion
#   59   NET_MFLUX_APER       ergs/cm**2/s Real8          -Inf:+Inf            Model scaled flux
#   60   NET_MFLUX_APER_LO    ergs/cm**2/s Real8          -Inf:+Inf            Model scaled flux lower limit
#   61   NET_MFLUX_APER_HI    ergs/cm**2/s Real8          -Inf:+Inf            Model scaled flux upper limit
#   62   NET_UMFLUX_APER      ergs/cm**2/s Real8          -Inf:+Inf            Unabs. model scaled flux
#   63   NET_UMFLUX_APER_LO   ergs/cm**2/s Real8          -Inf:+Inf            Unabs. model scaled flux lower limit
#   64   NET_UMFLUX_APER_HI   ergs/cm**2/s Real8          -Inf:+Inf            Unabs. model scaled flux upper limit
#   65   SRC_VAR_ODDS                      Real8          -Inf:+Inf            Odds for variable signal 10Log
#   66   SRC_VAR_PROB                      Real8          -Inf:+Inf            Probability of variable signal
#   67   SRC_VAR_INDEX                     Int4           -                    Variability index
#   68   fitted_Nh            cm**22       Real8          -Inf:+Inf            Fitted Absorption value
#   69   kT                   keV          Real8          -Inf:+Inf            Plasma Temperature
#   70   normalization                     Real8          -Inf:+Inf            Spectrum Normalization
#   71   reduced_statistic                 Real8          -Inf:+Inf            Reduced Fit Statistic
#   72   fit_statistic                     Real8          -Inf:+Inf            Fit Statistic
#   73   dof                               Real8          -Inf:+Inf            Degrees of Freedom
#   74   sample_flux                       Real8          -Inf:+Inf            2-10 keV Sample Flux
#   75   sample_flux_lo                    Real8          -Inf:+Inf            2-10 Sample Flux Uncertainty Low
#   76   sample_flux_hi                    Real8          -Inf:+Inf            2-10 Sample Flux Uncertainty Low
#
#
# ⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼
#
# World Coord Transforms for Columns in Table Block HISTOGRAM
#
# ⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼
#
#
# ColNo    Name
#
# 4:    CEL_R                = +0.2460 [arcsec] +0.4920 * (R  -0.50)
#
# 5:    CEL_RMID             = +0.2460 [arcsec] +0.4920 * (RMID  -0.50)
#
# 10:   CEL_AREA             = +0.1210 [arcsec**2] +0.2421 * (AREA  -0.50)
#
# 19:   BG_CEL_BRI           = +2.0656 [count/arcsec**2] +4.1311 * (BG_SUR_BRI  -0.50)
#
# 20:   BG_CEL_BRI_ERR       = +2.0656 [count/arcsec**2] +4.1311 * (BG_SUR_BRI_ERR  -0.50)
#
# 25:   CEL_BRI              = +2.0656 [count/arcsec**2] +4.1311 * (SUR_BRI  -0.50)
#
# 26:   CEL_BRI_ERR          = +2.0656 [count/arcsec**2] +4.1311 * (SUR_BRI_ERR  -0.50)
