# %% [markdown]
# # spectra grouping

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
download_chandra_obsid 459,460 pha2
mv -fv */primary/*pha2.fits.gz .
gunzip -f *pha2.fits.gz 
rmdir -p */primary
# Out:
# Downloading files for ObsId 459, total size is 1 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   pha2     fits        1 Mb  ####################          < 1 s  23213.4 kb/s
#
# Downloading files for ObsId 460, total size is 432 Kb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   pha2     fits      432 Kb  ####################          < 1 s  10123.3 kb/s
#
# `459/primary/acisf00459N004_pha2.fits.gz' -> `./acisf00459N004_pha2.fits.gz'
# `460/primary/hrcf00460N005_pha2.fits.gz' -> `./hrcf00460N005_pha2.fits.gz'

# %% [markdown]
# ## dmtype2split

# %%
dmtype2split "acisf00459N004_pha2.fits[tg_part=1,tg_m=-3]" \
  "459_heg_m1.fits[SPECTRUM]" clob+

# %%
dmkeypar 459_heg_m1.fits TG_M echo-
pget dmkeypar value
# Out:
# -3

# %%
dmkeypar 459_heg_m1.fits TG_PART echo+
# Out:
# 1

# %% [markdown]
# ## Multiple spectra

# %%
dmtype2split hrcf00460N005_pha2.fits "leg_m1.fits[SPECTRUM], leg_p1.fits[SPECTRUM]" clob+

# %%
cat << EOM > output.lis 
leg_m1_b.fits[SPECTRUM]
leg_p1_b.fits[SPECTRUM]
EOM

# %%
dmtype2split hrcf00460N005_pha2.fits @output.lis clob+

# %% [markdown]
# ## Group spectra

# %%
dmgroup infile="leg_p1.fits[SPECTRUM]" \
      outfile=leg_p1_bin10.pha \
      binspec="1:16384:10" grouptypeval="" grouptype=BIN ycolumn="counts" \
      xcolumn="channel" clob+

# %%
dmlist leg_p1_bin10.pha cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block SPECTRUM
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   CHANNEL                           Int2           -
#    2   COUNTS               count        Int2           -
#    3   STAT_ERR             count        Real4          -Inf:+Inf
#    4   BACKGROUND_UP        count        Int2           -
#    5   BACKGROUND_DOWN      count        Int2           -
#    6   BIN_LO               angstrom     Real8          -Inf:+Inf
#    7   BIN_HI               angstrom     Real8          -Inf:+Inf
#    8   GROUPING                          Int2           -
#    9   QUALITY                           Int2           -
#   10   GRP_NUM                           Int4           -
#   11   CHANS_PER_GRP                     Int4           -
#   12   GRP_DATA                          Real8          -Inf:+Inf
#   13   GRP_STAT_ERR                      Real8          -Inf:+Inf
