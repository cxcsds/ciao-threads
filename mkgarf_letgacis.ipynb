# %% [markdown]
# # mkgarf letg acis
#
# (same as hetg, same as hrc, same as cc)

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 1198
download_chandra_obsid 1198
# Out:
# Downloading files for ObsId 1198, total size is 208 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      10 Kb  ####################          < 1 s  191.4 kb/s
#   oif      fits       25 Kb  ####################          < 1 s  442.7 kb/s
#   vv       pdf        29 Kb  ####################          < 1 s  504.5 kb/s
#   cntr_img jpg       139 Kb  ####################          < 1 s  2433.9 kb/s
#   evt2     fits       16 Mb  ####################          < 1 s  19984.1 kb/s
#   full_img jpg        38 Kb  ####################          < 1 s  756.8 kb/s
#   pha2     fits      559 Kb  ####################          < 1 s  6042.7 kb/s
#   bpix     fits        8 Kb  ####################          < 1 s  294.2 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  46.6 kb/s
#   eph1     fits      301 Kb  ####################          < 1 s  1661.5 kb/s
#   asol     fits       10 Mb  ####################          < 1 s  18286.5 kb/s
#   aoff     fits        4 Mb  ####################          < 1 s  10527.1 kb/s
#   evt1     fits       42 Mb  ####################            2 s  21194.6 kb/s
#   evt1a    fits       43 Mb  ####################            3 s  12759.3 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  143.4 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  693.8 kb/s
#   mtl      fits        4 Mb  ####################          < 1 s  26848.4 kb/s
#   soff     fits        5 Kb  ####################          < 1 s  320.4 kb/s
#   stat     fits        3 Mb  ####################          < 1 s  15020.2 kb/s
#   bias     fits      132 Kb  ####################          < 1 s  2949.9 kb/s
#   bias     fits      119 Kb  ####################          < 1 s  3003.0 kb/s
#   bias     fits      114 Kb  ####################          < 1 s  2562.4 kb/s
#   bias     fits      112 Kb  ####################          < 1 s  2704.9 kb/s
#   bias     fits      110 Kb  ####################          < 1 s  5537.6 kb/s
#   bias     fits      111 Kb  ####################          < 1 s  3618.0 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  120.1 kb/s
#   vv       pdf        79 Mb  ####################            3 s  27620.3 kb/s
#   eph1     fits       16 Kb  ####################          < 1 s  155.7 kb/s
#   eph1     fits      293 Kb  ####################          < 1 s  2004.2 kb/s
#   eph1     fits      271 Kb  ####################          < 1 s  3175.4 kb/s
#   osol     fits      361 Kb  ####################          < 1 s  2850.5 kb/s
#   aqual    fits      612 Kb  ####################          < 1 s  11262.4 kb/s
#   osol     fits      186 Kb  ####################          < 1 s  2712.9 kb/s
#   osol     fits      355 Kb  ####################          < 1 s  3755.0 kb/s
#   osol     fits      250 Kb  ####################          < 1 s  1351.0 kb/s
#   osol     fits      357 Kb  ####################          < 1 s  3121.3 kb/s
#   osol     fits      357 Kb  ####################          < 1 s  8953.0 kb/s
#   osol     fits      356 Kb  ####################          < 1 s  9609.7 kb/s
#   osol     fits      115 Kb  ####################          < 1 s  3769.7 kb/s
#
#       Total download size for ObsId 1198 = 208 Mb
#       Total download time for ObsId 1198 = 13 s

# %%
/bin/rm -rf acisf01198* tg/* 
chandra_repro 1198 out=./
# Out:
# Processing input directory '/data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/1198'
#
# Resetting afterglow status bits in evt1.fits file...
#
# Running the destreak tool on the evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Output from acis_process_events:
# # acis_process_events (CIAO 4.9): WARNING: problem reading ctifile, cti adjustment will not be applied. Changing apply_cti=yes to apply_cti=no.
# Copy existing [REGION] block from evt2 file to use with tg_resolve_events
# Assign grating events to spectral orders with tg_resolve_events...
# The new evt1a file is: /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_evt1a.fits
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_evt2.fits
# Extracting a grating spectrum with tgextract...
# The new level=2 PHA file is: /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_pha2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
# Setting observation-specific bad pixel file in local ardlib.par.
#
# Cleaning up intermediate files
#
# WARNING: Observation-specific bad pixel file set for session use:
#          /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits
#          Run 'punlearn ardlib' when analysis of this dataset completed.
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis

# %% [markdown]
# ## Determine orders

# %%
prism acisf01198_repro_pha2.fits &
sleep 3
import -window prism prism.png
xpaset -p prism quit

display < prism.png
# Out:
# [1] 23566
# [1]+  Done                    prism acisf01198_repro_pha2.fits

# %% [markdown]
# ## Run fullgarf

# %%
cat acisf01198_asol1.lis
# Out:
# /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/1198/primary/pcadf063832996N003_asol1.fits

# %%
punlearn ardlib
acis_set_ardlib acisf01198_repro_bpix1.fits
# Out:
# Updated ardlib parameter file: /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/param/ardlib.par
#   AXAF_ACIS0_BADPIX_FILE -> CALDB
#   AXAF_ACIS1_BADPIX_FILE -> CALDB
#   AXAF_ACIS2_BADPIX_FILE -> CALDB
#   AXAF_ACIS3_BADPIX_FILE -> CALDB
#   AXAF_ACIS4_BADPIX_FILE -> /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits[BADPIX4]
#   AXAF_ACIS5_BADPIX_FILE -> /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits[BADPIX5]
#   AXAF_ACIS6_BADPIX_FILE -> /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits[BADPIX6]
#   AXAF_ACIS7_BADPIX_FILE -> /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits[BADPIX7]
#   AXAF_ACIS8_BADPIX_FILE -> /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits[BADPIX8]
#   AXAF_ACIS9_BADPIX_FILE -> /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/acisf01198_repro_bpix1.fits[BADPIX9]

# %%
pset fullgarf phafile=acisf01198_repro_pha2.fits
pset fullgarf pharow=2
pset fullgarf evtfile=acisf01198_repro_evt2.fits
pset fullgarf asol=@acisf01198_asol1.lis
pset fullgarf engrid=compute # "grid(rmf.fits[cols ENERG_LO,ENERG_HI])"
pset fullgarf badpix=acisf01198_repro_bpix1.fits
pset fullgarf maskfile=acisf01198_000N003_msk1.fits
pset fullgarf dafile=CALDB
pset fullgarf mode=h clobber=yes
fullgarf
# Out:
# Will use /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/param/fullgarf.par for the parameter file.
#
# /data/sdsreg/thread_output/CIAO4.9/mkgarf_letgacis/param/fullgarf.par contains 14 parameters . . .
#
# Getting the pha file type . . .
# Grating arm is LEG, order=-2
# Source location is X=4159.1591796875, Y=4086.5712890625
#
# Detector is ACIS
# Will run asphist for ccd_id= 4 5 6 7
#
#
# _ah4.fits exists . . . will clobber
# asphist infile=@acisf01198_asol1.lis outfile=_ah4.fits evtfile=acisf01198_repro_evt2.fits[ccd_id=4] dtffile=acisf01198_repro_evt2.fits clobber=yes mode=hl
#
# _ah5.fits exists . . . will clobber
# asphist infile=@acisf01198_asol1.lis outfile=_ah5.fits evtfile=acisf01198_repro_evt2.fits[ccd_id=5] dtffile=acisf01198_repro_evt2.fits clobber=yes mode=hl
#
# _ah6.fits exists . . . will clobber
# asphist infile=@acisf01198_asol1.lis outfile=_ah6.fits evtfile=acisf01198_repro_evt2.fits[ccd_id=6] dtffile=acisf01198_repro_evt2.fits clobber=yes mode=hl
#
# _ah7.fits exists . . . will clobber
# asphist infile=@acisf01198_asol1.lis outfile=_ah7.fits evtfile=acisf01198_repro_evt2.fits[ccd_id=7] dtffile=acisf01198_repro_evt2.fits clobber=yes mode=hl
#
# Finished processing aspect histograms for ccd_id= 4 5 6 7
# Will run mkgarf for the same ccd_id list
#
# _S0_LEG_-2.fits exists . . . will clobber
# mkgarf detsubsys=ACIS-S0 order=-2 grating_arm=LEG outfile=_S0_LEG_-2.fits asphistfile=_ah4.fits[ASPHIST] obsfile=acisf01198_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf01198_000N003_msk1.fits mirror=HRMA sourcepixelx=4159.1591796875 sourcepixely=4086.5712890625 mode=hl verb=0 clobber=yes
#
# _S1_LEG_-2.fits exists . . . will clobber
# mkgarf detsubsys=ACIS-S1 order=-2 grating_arm=LEG outfile=_S1_LEG_-2.fits asphistfile=_ah5.fits[ASPHIST] obsfile=acisf01198_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf01198_000N003_msk1.fits mirror=HRMA sourcepixelx=4159.1591796875 sourcepixely=4086.5712890625 mode=hl verb=0 clobber=yes
#
# _S2_LEG_-2.fits exists . . . will clobber
# mkgarf detsubsys=ACIS-S2 order=-2 grating_arm=LEG outfile=_S2_LEG_-2.fits asphistfile=_ah6.fits[ASPHIST] obsfile=acisf01198_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf01198_000N003_msk1.fits mirror=HRMA sourcepixelx=4159.1591796875 sourcepixely=4086.5712890625 mode=hl verb=0 clobber=yes
#
# _S3_LEG_-2.fits exists . . . will clobber
# mkgarf detsubsys=ACIS-S3 order=-2 grating_arm=LEG outfile=_S3_LEG_-2.fits asphistfile=_ah7.fits[ASPHIST] obsfile=acisf01198_repro_evt2.fits engrid=compute osipfile=CALDB dafile=CALDB pbkfile= maskfile=acisf01198_000N003_msk1.fits mirror=HRMA sourcepixelx=4159.1591796875 sourcepixely=4086.5712890625 mode=hl verb=0 clobber=yes
#
#
# Finished processing grating arfs for ccd_id= 4 5 6 7
#
# dmarfadd @thisfile.istemporary LEG_-2_garf.fits
# LEG_-2_garf.fits already exists . . . will clobber
#
# /export/ciao-4.9/contrib/bin/fullgarf finished.
