# %% [markdown]
# # Analysing the ACIS Background with the "Blank-Sky" Files

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 1838
download_chandra_obsid 1838
# Out:
# Downloading files for ObsId 1838, total size is 45 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb  ####################          < 1 s  1743.9 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  3516.1 kb/s
#   vv       pdf        33 Kb  ####################          < 1 s  4862.6 kb/s
#   cntr_img fits       75 Kb  ####################          < 1 s  9187.0 kb/s
#   cntr_img jpg       446 Kb  ####################          < 1 s  31445.5 kb/s
#   evt2     fits        3 Mb  ####################          < 1 s  69269.1 kb/s
#   full_img fits       48 Kb  ####################          < 1 s  6214.5 kb/s
#   full_img jpg        47 Kb  ####################          < 1 s  5588.0 kb/s
#   bpix     fits       12 Kb  ####################          < 1 s  1992.3 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  1034.8 kb/s
#   eph1     fits      281 Kb  ####################          < 1 s  20550.2 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  58118.2 kb/s
#   evt1     fits       15 Mb  ####################          < 1 s  68858.4 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  1128.8 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  897.1 kb/s
#   mtl      fits      341 Kb  ####################          < 1 s  25656.7 kb/s
#   stat     fits      288 Kb  ####################          < 1 s  24932.9 kb/s
#   bias     fits      420 Kb  ####################          < 1 s  24349.0 kb/s
#   bias     fits      493 Kb  ####################          < 1 s  31499.0 kb/s
#   bias     fits      426 Kb  ####################          < 1 s  29027.6 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  28745.3 kb/s
#   bias     fits      424 Kb  ####################          < 1 s  29325.8 kb/s
#   bias     fits      433 Kb  ####################          < 1 s  30609.4 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  700.1 kb/s
#   vv       pdf        19 Mb  ####################          < 1 s  77371.2 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  1015.2 kb/s
#   eph1     fits      274 Kb  ####################          < 1 s  21563.4 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  19303.6 kb/s
#   osol     fits      354 Kb  ####################          < 1 s  24605.3 kb/s
#   aqual    fits      152 Kb  ####################          < 1 s  14201.9 kb/s
#   osol     fits      355 Kb  ####################          < 1 s  26711.3 kb/s
#   osol     fits      356 Kb  ####################          < 1 s  25949.4 kb/s
#
#       Total download size for ObsId 1838 = 45 Mb
#       Total download time for ObsId 1838 = < 1 s

# %%
chandra_repro 1838 out=
# Out:
# Processing input directory '/lenin1.real/Junk/foo/1838'
#
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /lenin1.real/Junk/foo/1838/repro/acisf01838_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
# Setting observation-specific bad pixel file in local ardlib.par.
#
# Cleaning up intermediate files
#
# WARNING: Observation-specific bad pixel file set for session use:
#          /lenin1.real/Junk/foo/1838/repro/acisf01838_repro_bpix1.fits
#          Run 'punlearn ardlib' when analysis of this dataset completed.
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /lenin1.real/Junk/foo/1838/repro

# %%
mv 1838/repro/* .

# %% [markdown]
# ## Single Chip

# %%
dmcopy "acisf01838_repro_evt2.fits[energy=500:7000,ccd_id=7]" 1838_c7.fits cl+

# %% [markdown]
# ## Remove background flare

# %%
cat << EOM > sources.reg
# Region file format: CIAO version 1.0
circle(4072.5,4252.5,400)
circle(4604.5,4804.5,48)
EOM

dmcopy "1838_c7.fits[exclude sky=region(sources.reg)]" 1838_c7_bg.fits cl+

# %%
dmextract infile="1838_c7_bg.fits[bin time=84245789.155:84253741.155:259.28]" \
  outfile=1838_c7_bg.lc op=ltc1 clob+

# %%
deflare 1838_c7_bg.lc 1838_c7_bg_deflare.gti method=clean
# Out:
# Parameters used to clean the lightcurve are:
#   script version = October 2016
#   mean           = None
#   clip           = 3
#   scale          = 1.2
#   minfrac        = 0.1
#   outfile        = 1838_c7_bg_deflare.gti
#   plot           = False
#
# Total number of bins in lightcurve   = 31
# Max length of one bin                = 255.997 s
# Num. bins with a smaller exp. time   = 1
# Num. bins with exp. time = 0         = 0
# Calculated an initial mean (sigma-clipped) rate of 0.269603 ct/s
# Lightcurve limits use a scale factor of 1.2 about this mean
# Filtering lightcurve between rates of 0.224669 and 0.323524 ct/s
# Number of good time bins = 24
# Rate filter:  0.22466912825964613 <= count_rate < 0.32352354469389039
# Mean level of filtered lightcurve = 0.26441449970405073 ct/s
#
# GTI limits calculated using a count-rate filter:
#   (count_rate>0.22466912825964613 && count_rate<0.32352354469389039)
#
# The corresponding times are:
#   ((time >= 84246048.435000002) && (time < 84247604.11500001)) ; 1.54 ksec, bin 1
#   ((time >= 84248641.234999999) && (time < 84249159.795000002)) ; 0.51 ksec, bin 2
#   ((time >= 84249419.075000003) && (time < 84252011.875)) ; 2.56 ksec, bin 3
#   ((time >= 84252271.155000001) && (time < 84253826.835000008)) ; 1.45 ksec, bin 4
#
#   Exposure time of lightcurve = 7.86 ks
#   Filtered exposure time      = 6.06 ks
#   DTCOR value                 = 0.987337
#
# Creating GTI file
# Created: 1838_c7_bg_deflare.gti
# Light curve cleaned using the lc_clean routine.

# %%
dmcopy "1838_c7.fits[@1838_c7_bg_deflare.gti]" 1838_c7_clean.fits cl+

# %% [markdown]
# ## Now back to thread

# %%
ls -1 $CALDB/data/chandra/acis/bkgrnd/
# Out:
# acis0D2000-12-01bgstow_ctiN0004.fits
# acis0D2005-09-01bgstow_ctiN0001.fits
# acis0D2009-09-21bgstow_ctiN0001.fits
# acis0iD1999-09-16bkgrndN0002.fits
# acis0iD2000-01-29bkgrndN0003.fits
# acis0iD2000-01-29bkgrnd_ctiN0005.fits
# acis0iD2000-12-01bkgrndN0002.fits
# acis0iD2000-12-01bkgrnd_ctiN0004.fits
# acis0iD2005-09-01bkgrnd_ctiN0004.fits
# acis0iD2009-09-21bkgrnd_ctiN0002.fits
# acis1D2000-12-01bgstow_ctiN0004.fits
# acis1D2005-09-01bgstow_ctiN0001.fits
# acis1D2009-09-21bgstow_ctiN0001.fits
# acis1iD1999-09-16bkgrndN0002.fits
# acis1iD2000-01-29bkgrndN0003.fits
# acis1iD2000-01-29bkgrnd_ctiN0005.fits
# acis1iD2000-12-01bkgrndN0002.fits
# acis1iD2000-12-01bkgrnd_ctiN0004.fits
# acis1iD2005-09-01bkgrnd_ctiN0004.fits
# acis1iD2009-09-21bkgrnd_ctiN0002.fits
# acis1sD2000-01-29bkgrndN0005.fits
# acis1sD2000-01-29bkgrnd_ctiN0005.fits
# acis1sD2000-12-01bkgrndN0001.fits
# acis1sD2000-12-01bkgrnd_ctiN0005.fits
# acis2D2000-12-01bgstow_ctiN0002.fits
# acis2D2005-09-01bgstow_ctiN0001.fits
# acis2D2009-09-21bgstow_ctiN0001.fits
# acis2iD1999-09-16bkgrndN0002.fits
# acis2iD2000-01-29bkgrndN0003.fits
# acis2iD2000-01-29bkgrnd_ctiN0005.fits
# acis2iD2000-12-01bkgrndN0002.fits
# acis2iD2000-12-01bkgrnd_ctiN0004.fits
# acis2iD2005-09-01bkgrnd_ctiN0004.fits
# acis2iD2009-09-21bkgrnd_ctiN0002.fits
# acis2sD1999-09-16bkgrndN0002.fits
# acis2sD2000-01-29bkgrndN0005.fits
# acis2sD2000-01-29bkgrnd_ctiN0005.fits
# acis2sD2000-12-01bkgrndN0005.fits
# acis2sD2000-12-01bkgrnd_ctiN0005.fits
# acis2sD2005-09-01bkgrndN0004.fits
# acis2sD2005-09-01bkgrnd_ctiN0004.fits
# acis2sD2009-09-21bkgrnd_ctiN0002.fits
# acis3D2000-12-01bgstow_ctiN0004.fits
# acis3D2005-09-01bgstow_ctiN0001.fits
# acis3D2009-09-21bgstow_ctiN0001.fits
# acis3iD1999-09-16bkgrndN0002.fits
# acis3iD2000-01-29bkgrndN0003.fits
# acis3iD2000-01-29bkgrnd_ctiN0005.fits
# acis3iD2000-12-01bkgrndN0002.fits
# acis3iD2000-12-01bkgrnd_ctiN0004.fits
# acis3iD2005-09-01bkgrnd_ctiN0004.fits
# acis3iD2009-09-21bkgrnd_ctiN0002.fits
# acis3sD1999-09-16bkgrndN0002.fits
# acis3sD2000-01-29bkgrndN0005.fits
# acis3sD2000-01-29bkgrnd_ctiN0005.fits
# acis3sD2000-12-01bkgrndN0005.fits
# acis3sD2000-12-01bkgrnd_ctiN0005.fits
# acis3sD2005-09-01bkgrndN0004.fits
# acis3sD2005-09-01bkgrnd_ctiN0004.fits
# acis3sD2009-09-21bkgrnd_ctiN0002.fits
# acis5D2000-12-01bgstowN0003.fits
# acis5D2000-12-01bgstow_ctiN0001.fits
# acis5D2005-09-01bgstow_ctiN0001.fits
# acis5D2009-09-21bgstow_ctiN0001.fits
# acis5sD1999-09-16bkgrndN0002.fits
# acis5sD2000-01-29bkgrndN0005.fits
# acis5sD2000-01-29bkgrnd_ctiN0001.fits
# acis5sD2000-12-01bkgrndN0005.fits
# acis5sD2000-12-01bkgrnd_ctiN0001.fits
# acis5sD2005-09-01bkgrndN0004.fits
# acis5sD2005-09-01bkgrnd_ctiN0004.fits
# acis5sD2009-09-21bkgrndN0001.fits
# acis5sD2009-09-21bkgrnd_ctiN0002.fits
# acis6D2000-12-01bgstow_ctiN0004.fits
# acis6D2005-09-01bgstow_ctiN0001.fits
# acis6D2009-09-21bgstow_ctiN0001.fits
# acis6iD1999-09-16bkgrndN0002.fits
# acis6iD2000-01-29bkgrnd_ctiN0005.fits
# acis6iD2000-12-01bkgrndN0002.fits
# acis6iD2000-12-01bkgrnd_ctiN0004.fits
# acis6iD2005-09-01bkgrnd_ctiN0004.fits
# acis6iD2009-09-21bkgrnd_ctiN0002.fits
# acis6sD1999-08-12bkgrndN0002.fits
# acis6sD1999-09-16bkgrndN0002.fits
# acis6sD2000-01-29bkgrndN0005.fits
# acis6sD2000-01-29bkgrnd_ctiN0005.fits
# acis6sD2000-12-01bkgrndN0005.fits
# acis6sD2000-12-01bkgrnd_ctiN0005.fits
# acis6sD2005-09-01bkgrndN0004.fits
# acis6sD2005-09-01bkgrnd_ctiN0004.fits
# acis6sD2009-09-21bkgrnd_ctiN0002.fits
# acis7D2000-12-01bgstowN0003.fits
# acis7D2000-12-01bgstow_ctiN0001.fits
# acis7D2005-09-01bgstow_ctiN0001.fits
# acis7D2009-09-21bgstow_ctiN0001.fits
# acis7iD1999-08-12bkgrndN0003.fits
# acis7iD1999-09-16bkgrndN0002.fits
# acis7iD2000-01-29bkgrndN0004.fits
# acis7iD2000-01-29bkgrnd_ctiN0001.fits
# acis7iD2000-12-01bkgrndN0003.fits
# acis7iD2000-12-01bkgrnd_ctiN0001.fits
# acis7iD2005-09-01bkgrnd_ctiN0004.fits
# acis7sD1999-08-12bkgrndN0002.fits
# acis7sD1999-09-16bkgrndN0002.fits
# acis7sD2000-01-29bkgrndN0005.fits
# acis7sD2000-01-29bkgrnd_ctiN0001.fits
# acis7sD2000-12-01bkgrndN0005.fits
# acis7sD2000-12-01bkgrnd_ctiN0001.fits
# acis7sD2005-09-01bkgrndN0004.fits
# acis7sD2005-09-01bkgrnd_ctiN0004.fits
# acis7sD2009-09-21bkgrndN0001.fits
# acis7sD2009-09-21bkgrnd_ctiN0002.fits
# acis8iD2000-12-01bkgrndN0003.fits
# acis8iD2000-12-01bkgrnd_ctiN0001.fits
# acis8sD1999-09-16bkgrndN0002.fits
# acis8sD2000-01-29bkgrndN0005.fits
# acis8sD2000-01-29bkgrnd_ctiN0001.fits
# acis8sD2000-12-01bkgrndN0006.fits
# acis8sD2000-12-01bkgrnd_ctiN0002.fits
# acis8sD2005-09-01bkgrndN0004.fits
# acis8sD2005-09-01bkgrnd_ctiN0004.fits
# acis8sD2009-09-21bkgrnd_ctiN0002.fits
# acis9sD1999-09-16bkgrndN0002.fits
# acis_bkgrnd_manifest.txt

# %%
acis_bkgrnd_lookup 1838_c7_clean.fits
# Out:
# /export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis7sD2000-01-29bkgrnd_ctiN0001.fits

# %%
 pget acis_bkgrnd_lookup outfile
# Out:
# /export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis7sD2000-01-29bkgrnd_ctiN0001.fits

# %%
acis_bkgrnd_lookup "acisf01838_repro_evt2.fits[sky=circle(6072.5,4632.5,320)]"
# Out:
# /export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis1sD2000-01-29bkgrnd_ctiN0005.fits
# /export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis3sD2000-01-29bkgrnd_ctiN0005.fits

# %%
pget acis_bkgrnd_lookup outfile
# Out:
# /export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis1sD2000-01-29bkgrnd_ctiN0005.fits,/export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis3sD2000-01-29bkgrnd_ctiN0005.fits

# %% [markdown]
# ## Make a local copy

# %%
cp -fv $CALDB/data/chandra/acis/bkgrnd/acis7sD2000-01-29bkgrnd_ctiN0001.fits \
      bgevt2_c7.fits
# Out:
# `/export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis7sD2000-01-29bkgrnd_ctiN0001.fits' -> `bgevt2_c7.fits'

# %% [markdown]
# ## Tailor background

# %%
dmkeypar 1838_c7_clean.fits DATAMODE echo+
# Out:
# FAINT

# %%
dmkeypar 1838_c7_clean.fits GAINFILE echo+
# Out:
# acisD2000-01-29gain_ctiN0007.fits

# %%
dmkeypar bgevt2_c7.fits GAINFILE echo+
# Out:
# acisD2000-01-29gain_ctiN0006.fits

# %% [markdown]
# ## Adding PNT header keywords

# %%
 dmlist bgevt2_c7.fits header |grep PNT
# Out:
# 0058 RA_PNT                                  0           Real8        Pointing RA
# 0059 DEC_PNT                                 0           Real8        Pointing Dec
# 0060 ROLL_PNT                                0 [deg]     Real8        Roll (fake)

# %%
dmmakepar 1838_c7_clean.fits event_header.par cl+

# %%
grep _pnt event_header.par > event_pnt.par
grep _avg event_header.par >> event_pnt.par
cat event_pnt.par
# Out:
# ra_pnt,r,h,278.38657206626,,,"Pointing RA [deg]"
# dec_pnt,r,h,-10.589269915683,,,"Pointing Dec [deg]"
# roll_pnt,r,h,266.80752046013,,,"Pointing Roll [deg]"
# dy_avg,r,h,0.094093196106,,,"Mean DY during observation [mm]"
# dz_avg,r,h,0.23995890484,,,"Mean DZ during observation [mm]"
# dth_avg,r,h,-0.0047718649694,,,"Mean DTHETA during observation [deg]"

# %%
chmod +w bgevt2_c7.fits
dmreadpar event_pnt.par "bgevt2_c7.fits[events]" clobber+
dmlist bgevt2_c7.fits header |grep PNT
# Out:
# 0058 RA_PNT                     278.3865720663           Real8        Pointing RA [deg]
# 0059 DEC_PNT                    -10.5892699157           Real8        Pointing Dec [deg]
# 0060 ROLL_PNT                   266.8075204601 [deg]     Real8        Pointing Roll [deg]

# %% [markdown]
# ## Reproject background data

# %%
punlearn reproject_events
pset reproject_events infile=bgevt2_c7.fits
pset reproject_events outfile=bgevt2_c7_reproj.fits
pset reproject_events aspect=pcadf084244404N003_asol1.fits
pset reproject_events match=1838_c7_clean.fits
pset reproject_events random=0
reproject_events mode=h cl+

# %% [markdown]
# ## Imaging Analysis

# %%
fluximage 1838_c7_clean.fits out=1838_c7 bin=8 band=broad clob+
# Out:
# Running fluximage
# Version: 12 September 2016
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf084244404N003_asol1.fits found.
# Bad-pixel file acisf01838_repro_bpix1.fits found.
# Mask file acisf01838_000N003_msk1.fits found.
#
# The output images will have 140 by 140 pixels, pixel size of 3.936 arcsec,
#     and cover x=3632.5:4752.5:8,y=3840.5:4960.5:8.
#
# Running tasks in parallel with 4 processors.
# Creating aspect histogram for obsid 1838
# Creating instrument map for obsid 1838
# Creating exposure map for obsid 1838
# Thresholding data for obsid 1838
# Exposure-correcting image for obsid 1838
#
# The following files were created:
#
#  The clipped counts image is:
#      1838_c7_broad_thresh.img
#
#  The clipped exposure map is:
#      1838_c7_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      1838_c7_broad_flux.img

# %%
get_sky_limits 1838_c7_broad_thresh.img
dmf=`pget get_sky_limits dmfilter`
# Out:
# Running: get_sky_limits
#   version: 07 October 2016
# Checking binning of image: 1838_c7_broad_thresh.img
#   Image has 140 x 140 pixels
#   Pixel size is 8.0 by 8.0
#   Lower left (0.5,0.5) corner is x,y= 3632.5, 3840.5
#   Upper right (140.5,140.5) corner is x,y= 4752.5, 4960.5
#   DM filter is:
#     x=3632.5:4752.5:#140,y=3840.5:4960.5:#140
#   mkexpmap xygrid value is:
#     3632.5:4752.5:#140,3840.5:4960.5:#140

# %%
dmcopy "bgevt2_c7_reproj.fits[energy=500:7000][bin $dmf]" 1838_c7_broad.bgimg cl+

# %% [markdown]
# ### Compute scaling factor

# %%
bkg_cts=`dmlist bgevt2_c7_reproj.fits"[energy=9000:12000]" counts`
bkg_exp=`dmkeypar bgevt2_c7_reproj.fits LIVETIME echo+`

bkg_rate=`echo $bkg_cts/$bkg_exp | bc -l`
echo $bkg_cts
echo $bkg_exp
echo $bkg_rate
# Out:
# 85817
# 110000.0
# .78015454545454545454

# %%
obs_cts=`dmcopy "acisf01838_repro_evt2.fits[ccd_id=7][@1838_c7_bg_deflare.gti]" - | \
  dmlist "-[energy=9000:12000]" counts `
obs_exp=`dmkeypar "acisf01838_repro_evt2.fits[ccd_id=7][@1838_c7_bg_deflare.gti]" \
  LIVETIME echo+`

obs_rate=`echo $obs_cts/$obs_exp | bc -l`
echo $obs_cts
echo $obs_exp
echo $obs_rate
# Out:
# 4788
# 6060.75475111337
# .79000061817720590191

# %%
dmimgcalc 1838_c7_broad_thresh.img,1838_c7_broad_thresh.expmap,1838_c7_broad.bgimg \
  none 1838_c7_broad.netimg \
  op="imgout=((img1-(((0.0+${obs_cts})/${bkg_cts})*img3))/img2)" cl+
# Out:
# BTIMCORR not present in all input files...FAIL...
# BTIMDRFT not present in all input files...FAIL...
# BTIMNULL not present in all input files...FAIL...
# BTIMRATE not present in all input files...FAIL...
# warning: CONTENT has 1 different values.
# warning: DETNAM has different value...Merged...
# warning: DS_IDENT has different value...Merged...
# omit - FOC_LEN values different more than 1.000000
# OBI_NUM not present in all input files...FAIL...
# warning: OBJECT has different value...Merged...
# warning: OBSERVER has different value...Merged...
# warning: OBS_ID has different value...Merged...
# omit - RAND_SKY values different more than 0.050000
# omit - ROLL_NOM values different more than 1.000000
# warning: SEQ_NUM has different value...Merged...
# warning: TITLE has different value...Merged...

# %% [markdown]
# # Using `blanksky` and `blansky_image`

# %%
pset blanksky evt="acisf01838_repro_evt2.fits[ccd_id=7][@1838_c7_bg_deflare.gti]"
pset blanksky out=1838_blank.evt
pset blanksky tmpdir=./
blanksky mode=h clob+
# Out:
# Running blanksky
# Version: 05 October 2016
#
# Aspect solution file pcadf084244404N003_asol1.fits found.
#
# ACIS background file /export/ciao-4.9/CALDB/data/chandra/acis/bkgrnd/acis7sD2000-01-29bkgrnd_ctiN0001.fits found.
#
# Calculated scale factor for 'weight_method=particle':
#     ACIS-7: 0.05579314 written to the 'BKGSCAL7' header keyword.

# %%
pset blanksky_image bkg=1838_blank.evt
pset blanksky_image out=1838_blank
pset blanksky_image img=1838_c7_broad_thresh.img
pset blanksky_image tmp=./
blanksky_image mode=h clob+ verb=1
# Out:
# Running blanksky_image
# Version: 30 September 2016
