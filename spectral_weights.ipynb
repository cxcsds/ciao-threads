# %% [markdown]
# # spectral weights

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %%
/bin/rm -rf 1838 repro
download_chandra_obsid 1838 --exclude vvref,evt2,osol,eph1
chandra_repro 1838 out=`pwd`/repro clob+
# Out:
# ...
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt1     fits       15 Mb  ####################          < 1 s  30990.8 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  29467.1 kb/s
#   bias     fits      494 Kb  ####################          < 1 s  21219.9 kb/s
#   bias     fits      434 Kb  ####################          < 1 s  18726.6 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  18128.5 kb/s
#   bias     fits      426 Kb  ####################          < 1 s  22095.4 kb/s
#   bias     fits      425 Kb  ####################          < 1 s  22675.8 kb/s
#   bias     fits      420 Kb  ####################          < 1 s  15673.2 kb/s
#   mtl      fits      338 Kb  ####################          < 1 s  19560.0 kb/s
#   stat     fits      289 Kb  ####################          < 1 s  15889.3 kb/s
# ...

# %% [markdown]
# ## Using make_instmap_weights script

# %%
make_instmap_weights weights.txt "xsphabs.gal*powlaw1d.p1" \
      paramvals="gal.nh=1.3;p1.gamma=1.7" emin=0.5 emax=8 ewidth=0.25 clob+
# Out:
#  Solar Abundance Vector set to angr:  Anders E. & Grevesse N. Geochimica et Cosmochimica Acta 53, 197 (1989)
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
# Model used:
# (xsphabs.gal * powlaw1d.p1)
#    Param        Type          Value          Min          Max      Units
#    -----        ----          -----          ---          ---      -----
#    gal.nH       thawed          1.3            0        1e+06 10^22 atoms / cm^2
#    p1.gamma     thawed          1.7          -10           10
#    p1.ref       frozen            1 -3.40282e+38  3.40282e+38
#    p1.ampl      thawed            1            0  3.40282e+38
# Created: weights.txt

# %%
cat weights.txt
# Out:
# #TEXT/SIMPLE
# # X WEIGHT
# #
# # DATE = 2021-11-09T14:11:11 / Date and time of file creation
# # MODELEXPR = (xsphabs.gal * powlaw1d.p1)
# # ENERG_LO = 0.5 / [keV] Minimum energy
# # ENERG_HI = 8.0 / [keV] Maximum energy
# #
# 0.625 0.0005505499378475431
# 0.875 0.005133913053133582
# 1.125 0.02779381690871387
# 1.375 0.056084831800127403
# 1.625 0.07066623980281715
# 1.875 0.07413742820878573
# 2.125 0.0712275747324698
# 2.375 0.06669921234265919
# 2.625 0.06102870878761724
# 2.875 0.05580786480786807
# 3.125 0.05067728967895906
# 3.375 0.04597129491973783
# 3.625 0.04181074649300642
# 3.875 0.03810108003743937
# 4.125 0.03478392863101238
# 4.375 0.031852303498792825
# 4.625 0.02928280475960336
# 4.875 0.02700223451672559
# 5.125 0.024973234527294007
# 5.375 0.023162919654288874
# 5.625 0.021542753530535842
# 5.875 0.020085760678698657
# 6.125 0.018773803619361276
# 6.375 0.017590825350819506
# 6.625 0.016518718543815914
# 6.875 0.01554423141902547
# 7.125 0.014513042710459261
# ...

# %% [markdown]
# ## Step-by-step

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 1838 repro
