# %% [markdown]
# # spectral weights

# %%
source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./
# Out:
# CIAO configuration is complete...
# CIAO 4.9 Friday, December  2, 2016
#   bindir      : /export/ciao-4.9/bin
#   CALDB       : 4.7.3

# %%
/bin/rm -rf 1838 repro
download_chandra_obsid 1838
chandra_repro 1838 out=`pwd`/repro clob+
# Out:
# Downloading files for ObsId 1838, total size is 45 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   readme   ascii      11 Kb  ####################          < 1 s  244.5 kb/s
#   oif      fits       23 Kb  ####################          < 1 s  680.1 kb/s
#   vv       pdf        33 Kb  ####################          < 1 s  1442.7 kb/s
#   cntr_img fits       75 Kb  ####################          < 1 s  6171.0 kb/s
#   cntr_img jpg       446 Kb  ####################          < 1 s  7235.0 kb/s
#   evt2     fits        3 Mb  ####################          < 1 s  37233.4 kb/s
#   full_img fits       48 Kb  ####################          < 1 s  5299.2 kb/s
#   full_img jpg        47 Kb  ####################          < 1 s  5264.1 kb/s
#   bpix     fits       12 Kb  ####################          < 1 s  294.6 kb/s
#   fov      fits        6 Kb  ####################          < 1 s  927.8 kb/s
#   eph1     fits      281 Kb  ####################          < 1 s  8574.7 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  18727.9 kb/s
#   evt1     fits       15 Mb  ####################          < 1 s  31105.7 kb/s
#   flt      fits        7 Kb  ####################          < 1 s  1009.6 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  567.5 kb/s
#   mtl      fits      341 Kb  ####################          < 1 s  6836.5 kb/s
#   stat     fits      288 Kb  ####################          < 1 s  6452.8 kb/s
#   bias     fits      420 Kb  ####################          < 1 s  9879.1 kb/s
#   bias     fits      493 Kb  ####################          < 1 s  14751.0 kb/s
#   bias     fits      426 Kb  ####################          < 1 s  11691.4 kb/s
#   bias     fits      427 Kb  ####################          < 1 s  13607.3 kb/s
#   bias     fits      424 Kb  ####################          < 1 s  12225.3 kb/s
#   bias     fits      433 Kb  ####################          < 1 s  13379.8 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  595.4 kb/s
#   vv       pdf        19 Mb  ####################          < 1 s  56991.1 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  279.9 kb/s
#   eph1     fits      274 Kb  ####################          < 1 s  4001.1 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  5283.7 kb/s
#   osol     fits      354 Kb  ####################          < 1 s  7757.0 kb/s
#   aqual    fits      152 Kb  ####################          < 1 s  6312.9 kb/s
#   osol     fits      355 Kb  ####################          < 1 s  12591.9 kb/s
#   osol     fits      356 Kb  ####################          < 1 s  8957.0 kb/s
#
#       Total download size for ObsId 1838 = 45 Mb
#       Total download time for ObsId 1838 = 2 s
#
#
# Processing input directory '/data/sdsreg/thread_output/CIAO4.9/spectral_weights/1838'
#
# Resetting afterglow status bits in evt1.fits file...
#
# Running acis_build_badpix and acis_find_afterglow to create a new bad pixel file...
#
# Running acis_process_events to reprocess the evt1.fits file...
# Filtering the evt1.fits file by grade and status and time...
# Applying the good time intervals from the flt1.fits file...
# The new evt2.fits file is: /data/sdsreg/thread_output/CIAO4.9/spectral_weights/repro/acisf01838_repro_evt2.fits
#
# Updating the event file header with chandra_repro HISTORY record
# Creating FOV file...
# Setting observation-specific bad pixel file in local ardlib.par.
#
# Cleaning up intermediate files
#
# WARNING: Observation-specific bad pixel file set for session use:
#          /data/sdsreg/thread_output/CIAO4.9/spectral_weights/repro/acisf01838_repro_bpix1.fits
#          Run 'punlearn ardlib' when analysis of this dataset completed.
#
# The data have been reprocessed.
# Start your analysis with the new products in
# /data/sdsreg/thread_output/CIAO4.9/spectral_weights/repro

# %% [markdown]
# ## Using make_instmap_weights script

# %%
make_instmap_weights weights.txt "xsphabs.gal*powlaw1d.p1" \
      paramvals="gal.nh=1.3;p1.gamma=1.7" emin=0.5 emax=8 ewidth=0.25 clob+
# Out:
# Model used:
# (xsphabs.gal * powlaw1d.p1)
#    Param        Type          Value          Min          Max      Units
#    -----        ----          -----          ---          ---      -----
#    gal.nH       thawed          1.3            0       100000 10^22 atoms / cm^2
#    p1.gamma     thawed          1.7          -10           10
#    p1.ref       frozen            1 -3.40282e+38  3.40282e+38
#    p1.ampl      thawed            1            0  3.40282e+38
# Created: weights.txt

# %%
cat weights.txt
# Out:
# #TEXT/SIMPLE
# # X WEIGHT
# #
# # DATE = 2017-01-11T13:35:57 / Date and time of file creation
# # MODELEXPR = (xsphabs.gal * powlaw1d.p1)
# # ENERG_LO = 0.5 / [keV] Minimum energy
# # ENERG_HI = 8.0 / [keV] Maximum energy
# #
# 0.625 0.000262206958899
# 0.875 0.00680336709152
# 1.125 0.0296492945584
# 1.375 0.0562062174781
# 1.625 0.0705678030635
# 1.875 0.0740071023859
# 2.125 0.0706968736338
# 2.375 0.06683637039
# 2.625 0.0605703912684
# 2.875 0.0554519470171
# 3.125 0.0504631354041
# 3.375 0.0457218204413
# 3.625 0.0416093446645
# 3.875 0.0379342170434
# 4.125 0.0346277236647
# 4.375 0.0317287277273
# 4.625 0.029175094479
# 4.875 0.0269070452828
# 5.125 0.0248881325335
# 5.375 0.0230860958395
# 5.625 0.0214728313009
# 5.875 0.0200240167049
# 6.125 0.0187147444077
# 6.375 0.0175361040711
# 6.625 0.0164677939141
# 6.875 0.0154966568871
# 7.125 0.0145206381483
# 7.375 0.0135493374534
# 7.625 0.0128396753267
# 7.875 0.0121852908602

# %% [markdown]
# ## Step-by-step
