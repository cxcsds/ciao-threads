# %% [markdown]
# # Combine spectra

# %%
#source /export/ciao/bin/ciao.bash -o
PFILES="./param;$ASCDS_INSTALL/param:$ASCDS_INSTALL/contrib/param"
mkdir -p ./param
ASCDS_WORK_PATH=./

# %% [markdown]
# ## Get Started

# %%
/bin/rm -rf 10289 10290 10291 10292 10293
download_chandra_obsid 10289,10290,10291,10292,10293
# Out:
# Downloading files for ObsId 10289, total size is 37 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   vvref    pdf        19 Mb  ####################          < 1 s  76246.3 kb/s
#   evt1     fits        9 Mb  ####################          < 1 s  69852.8 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  36464.5 kb/s
#   evt2     fits        2 Mb  ####################          < 1 s  30701.0 kb/s
#   mtl      fits        1 Mb  ####################          < 1 s  35688.4 kb/s
#   stat     fits      693 Kb  ####################          < 1 s  17348.2 kb/s
#   osol     fits      368 Kb  ####################          < 1 s  14637.0 kb/s
#   osol     fits      359 Kb  ####################          < 1 s  14499.2 kb/s
#   osol     fits      321 Kb  ####################          < 1 s  9679.4 kb/s
#   eph1     fits      282 Kb  ####################          < 1 s  13523.2 kb/s
#   eph1     fits      277 Kb  ####################          < 1 s  13274.9 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  13066.8 kb/s
#   aqual    fits      162 Kb  ####################          < 1 s  6348.5 kb/s
#   bias     fits      128 Kb  ####################          < 1 s  7578.6 kb/s
#   bias     fits      117 Kb  ####################          < 1 s  6546.4 kb/s
#   bias     fits      108 Kb  ####################          < 1 s  6446.9 kb/s
#   bias     fits      107 Kb  ####################          < 1 s  7251.8 kb/s
#   cntr_img jpg        78 Kb  ####################          < 1 s  5369.9 kb/s
#   vv       pdf        42 Kb  ####################          < 1 s  3075.1 kb/s
#   cntr_img fits       22 Kb  ####################          < 1 s  1394.7 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1538.8 kb/s
#   full_img fits       19 Kb  ####################          < 1 s  1457.7 kb/s
#   full_img jpg        11 Kb  ####################          < 1 s  857.0 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  838.2 kb/s
#   bpix     fits        9 Kb  ####################          < 1 s  499.3 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  476.1 kb/s
#   eph1     fits        7 Kb  ####################          < 1 s  642.8 kb/s
#   flt      fits        5 Kb  ####################          < 1 s  519.7 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  464.4 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  317.8 kb/s
#
#       Total download size for ObsId 10289 = 37 Mb
#       Total download time for ObsId 10289 = < 1 s
#
# Downloading files for ObsId 10290, total size is 35 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   vvref    pdf        19 Mb  ####################          < 1 s  57388.0 kb/s
#   evt1     fits        8 Mb  ####################          < 1 s  86965.4 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  22352.0 kb/s
#   evt2     fits        2 Mb  ####################          < 1 s  46000.1 kb/s
#   mtl      fits      995 Kb  ####################          < 1 s  29363.7 kb/s
#   stat     fits      598 Kb  ####################          < 1 s  18355.6 kb/s
#   osol     fits      364 Kb  ####################          < 1 s  17086.1 kb/s
#   osol     fits      358 Kb  ####################          < 1 s  12554.8 kb/s
#   osol     fits      354 Kb  ####################          < 1 s  13309.2 kb/s
#   eph1     fits      283 Kb  ####################          < 1 s  16310.4 kb/s
#   eph1     fits      276 Kb  ####################          < 1 s  13465.8 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  12794.0 kb/s
#   aqual    fits      159 Kb  ####################          < 1 s  7143.0 kb/s
#   bias     fits      128 Kb  ####################          < 1 s  8201.8 kb/s
#   bias     fits      117 Kb  ####################          < 1 s  7683.9 kb/s
#   bias     fits      109 Kb  ####################          < 1 s  5864.2 kb/s
#   bias     fits      106 Kb  ####################          < 1 s  6466.3 kb/s
#   cntr_img jpg        80 Kb  ####################          < 1 s  5407.9 kb/s
#   vv       pdf        39 Kb  ####################          < 1 s  2842.7 kb/s
#   cntr_img fits       22 Kb  ####################          < 1 s  1980.7 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1735.0 kb/s
#   full_img fits       19 Kb  ####################          < 1 s  1323.4 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  52.3 kb/s
#   bpix     fits        9 Kb  ####################          < 1 s  705.6 kb/s
#   full_img jpg         7 Kb  ####################          < 1 s  631.4 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  532.0 kb/s
#   eph1     fits        6 Kb  ####################          < 1 s  523.3 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  455.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  417.2 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  340.4 kb/s
#
#       Total download size for ObsId 10290 = 35 Mb
#       Total download time for ObsId 10290 = 1 s
#
# Downloading files for ObsId 10291, total size is 37 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   vvref    pdf        20 Mb  ####################          < 1 s  54383.5 kb/s
#   evt1     fits        9 Mb  ####################          < 1 s  49384.6 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  52796.6 kb/s
#   evt2     fits        2 Mb  ####################          < 1 s  39087.7 kb/s
#   mtl      fits        1 Mb  ####################          < 1 s  25125.8 kb/s
#   stat     fits      702 Kb  ####################          < 1 s  26004.1 kb/s
#   osol     fits      369 Kb  ####################          < 1 s  19999.2 kb/s
#   osol     fits      367 Kb  ####################          < 1 s  15166.2 kb/s
#   osol     fits      359 Kb  ####################          < 1 s  16470.3 kb/s
#   eph1     fits      283 Kb  ####################          < 1 s  14132.6 kb/s
#   eph1     fits      276 Kb  ####################          < 1 s  13839.7 kb/s
#   eph1     fits      258 Kb  ####################          < 1 s  13825.5 kb/s
#   aqual    fits      163 Kb  ####################          < 1 s  8987.2 kb/s
#   bias     fits      128 Kb  ####################          < 1 s  7643.6 kb/s
#   osol     fits      128 Kb  ####################          < 1 s  8266.6 kb/s
#   bias     fits      117 Kb  ####################          < 1 s  7433.0 kb/s
#   bias     fits      109 Kb  ####################          < 1 s  6399.9 kb/s
#   bias     fits      107 Kb  ####################          < 1 s  4314.7 kb/s
#   cntr_img jpg        81 Kb  ####################          < 1 s  4751.8 kb/s
#   vv       pdf        38 Kb  ####################          < 1 s  2845.9 kb/s
#   cntr_img fits       21 Kb  ####################          < 1 s  1786.2 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1476.1 kb/s
#   full_img fits       19 Kb  ####################          < 1 s  1434.1 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  888.1 kb/s
#   full_img jpg         9 Kb  ####################          < 1 s  743.9 kb/s
#   bpix     fits        9 Kb  ####################          < 1 s  735.6 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  622.0 kb/s
#   eph1     fits        7 Kb  ####################          < 1 s  567.9 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  446.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  424.8 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  353.4 kb/s
#
#       Total download size for ObsId 10291 = 37 Mb
#       Total download time for ObsId 10291 = 1 s
#
# Downloading files for ObsId 10292, total size is 37 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   vvref    pdf        20 Mb  ####################          < 1 s  59542.7 kb/s
#   evt1     fits        8 Mb  ####################          < 1 s  57123.2 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  31530.0 kb/s
#   evt2     fits        2 Mb  ####################          < 1 s  44670.6 kb/s
#   mtl      fits        1 Mb  ####################          < 1 s  31700.6 kb/s
#   stat     fits      642 Kb  ####################          < 1 s  24258.5 kb/s
#   osol     fits      367 Kb  ####################          < 1 s  13914.0 kb/s
#   osol     fits      364 Kb  ####################          < 1 s  16930.7 kb/s
#   osol     fits      364 Kb  ####################          < 1 s  17353.1 kb/s
#   eph1     fits      283 Kb  ####################          < 1 s  15197.0 kb/s
#   eph1     fits      277 Kb  ####################          < 1 s  13035.3 kb/s
#   eph1     fits      259 Kb  ####################          < 1 s  15324.6 kb/s
#   aqual    fits      163 Kb  ####################          < 1 s  9814.7 kb/s
#   bias     fits      128 Kb  ####################          < 1 s  8651.3 kb/s
#   bias     fits      117 Kb  ####################          < 1 s  7408.3 kb/s
#   bias     fits      109 Kb  ####################          < 1 s  7746.6 kb/s
#   bias     fits      107 Kb  ####################          < 1 s  6714.9 kb/s
#   cntr_img jpg        80 Kb  ####################          < 1 s  5706.2 kb/s
#   vv       pdf        39 Kb  ####################          < 1 s  2518.6 kb/s
#   cntr_img fits       22 Kb  ####################          < 1 s  1717.8 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1557.0 kb/s
#   full_img fits       18 Kb  ####################          < 1 s  692.4 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  736.0 kb/s
#   bpix     fits        9 Kb  ####################          < 1 s  614.5 kb/s
#   full_img jpg         8 Kb  ####################          < 1 s  631.9 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  546.0 kb/s
#   eph1     fits        7 Kb  ####################          < 1 s  514.3 kb/s
#   flt      fits        6 Kb  ####################          < 1 s  344.6 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  411.3 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  338.1 kb/s
#
#       Total download size for ObsId 10292 = 37 Mb
#       Total download time for ObsId 10292 = 1 s
#
# Downloading files for ObsId 10293, total size is 37 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   vvref    pdf        20 Mb  ####################          < 1 s  76041.0 kb/s
#   evt1     fits        9 Mb  ####################          < 1 s  47058.4 kb/s
#   asol     fits        2 Mb  ####################          < 1 s  53502.8 kb/s
#   evt2     fits        2 Mb  ####################          < 1 s  36025.5 kb/s
#   mtl      fits        1 Mb  ####################          < 1 s  34182.3 kb/s
#   stat     fits      676 Kb  ####################          < 1 s  28531.0 kb/s
#   osol     fits      361 Kb  ####################          < 1 s  15918.5 kb/s
#   osol     fits      350 Kb  ####################          < 1 s  15943.5 kb/s
#   eph1     fits      283 Kb  ####################          < 1 s  16310.5 kb/s
#   eph1     fits      276 Kb  ####################          < 1 s  12992.3 kb/s
#   eph1     fits      259 Kb  ####################          < 1 s  14444.0 kb/s
#   aqual    fits      163 Kb  ####################          < 1 s  9827.1 kb/s
#   bias     fits      129 Kb  ####################          < 1 s  7921.8 kb/s
#   bias     fits      117 Kb  ####################          < 1 s  7891.0 kb/s
#   bias     fits      109 Kb  ####################          < 1 s  7106.8 kb/s
#   bias     fits      108 Kb  ####################          < 1 s  7301.7 kb/s
#   cntr_img jpg        78 Kb  ####################          < 1 s  5453.2 kb/s
#   vv       pdf        42 Kb  ####################          < 1 s  2931.9 kb/s
#   cntr_img fits       21 Kb  ####################          < 1 s  1720.8 kb/s
#   oif      fits       20 Kb  ####################          < 1 s  1520.1 kb/s
#   full_img fits       19 Kb  ####################          < 1 s  1398.1 kb/s
#   readme   ascii      10 Kb  ####################          < 1 s  841.8 kb/s
#   bpix     fits        9 Kb  ####################          < 1 s  753.5 kb/s
#   full_img jpg         9 Kb  ####################          < 1 s  729.8 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  626.9 kb/s
#   eph1     fits        7 Kb  ####################          < 1 s  527.9 kb/s
#   flt      fits        5 Kb  ####################          < 1 s  432.4 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  417.0 kb/s
#   pbk      fits        4 Kb  ####################          < 1 s  311.7 kb/s
#
#       Total download size for ObsId 10293 = 37 Mb
#       Total download time for ObsId 10293 = < 1 s

# %%
cat << EOM > ds9.reg
# Region file format: DS9 version 4.1
global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1
fk5
circle(17:16:59.592,-62:49:13.868,4.976")
EOM


cat << EOM > bkg.reg
# Region file format: DS9 version 4.1
global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1
fk5
annulus(17:16:59.592,-62:49:13.868,5",9")
EOM

# %%
for d in 10289 10290 10291 10292 10293
do
  specextract ${d}/primary/*evt2.fits.gz"[sky=region(ds9.reg)]" \
  outroot=${d} bkgfile=${d}/primary/*evt2.fits.gz"[sky=region(bkg.reg)]" \
  mode=h clob+
done
# Out:
# Running specextract
# Version: 09 Mar 2021
#
# Checking for blank sky background files...
# Using event file 10289/primary/acisf10289N004_evt2.fits.gz[sky=region(ds9.reg)]
#
# Aspect solution file 10289/primary/pcadf10289_000N001_asol1.fits found.
#
# Bad-pixel file 10289/primary/acisf10289_000N004_bpix1.fits.gz found.
#
# Mask file 10289/secondary/acisf10289_000N004_msk1.fits found.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting src spectra
#
# Creating src ARF
#
# Creating src RMF
#
# Using mkacisrmf...
#
# Grouping src spectrum
#
# Updating header of 10289.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10289_grp.pi with RESPFILE and ANCRFILE keywords.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting bkg spectra
#
# Creating bkg ARF
#
# Creating bkg RMF
#
# Using mkacisrmf...
#
# Updating header of 10289_bkg.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10289.pi with BACKFILE keyword.
#
# Updating header of 10289_grp.pi with BACKFILE keyword.
#
# Running specextract
# Version: 09 Mar 2021
#
# Checking for blank sky background files...
# Using event file 10290/primary/acisf10290N003_evt2.fits.gz[sky=region(ds9.reg)]
#
# Aspect solution file 10290/primary/pcadf10290_000N001_asol1.fits found.
#
# Bad-pixel file 10290/primary/acisf10290_000N003_bpix1.fits.gz found.
#
# Mask file 10290/secondary/acisf10290_000N003_msk1.fits found.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting src spectra
#
# Creating src ARF
#
# Creating src RMF
#
# Using mkacisrmf...
#
# Grouping src spectrum
#
# Updating header of 10290.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10290_grp.pi with RESPFILE and ANCRFILE keywords.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting bkg spectra
#
# Creating bkg ARF
#
# Creating bkg RMF
#
# Using mkacisrmf...
#
# Updating header of 10290_bkg.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10290.pi with BACKFILE keyword.
#
# Updating header of 10290_grp.pi with BACKFILE keyword.
#
# Running specextract
# Version: 09 Mar 2021
#
# Checking for blank sky background files...
# Using event file 10291/primary/acisf10291N003_evt2.fits.gz[sky=region(ds9.reg)]
#
# Aspect solution file 10291/primary/pcadf10291_000N001_asol1.fits found.
#
# Bad-pixel file 10291/primary/acisf10291_000N003_bpix1.fits.gz found.
#
# Mask file 10291/secondary/acisf10291_000N003_msk1.fits found.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting src spectra
#
# Creating src ARF
#
# Creating src RMF
#
# Using mkacisrmf...
#
# Grouping src spectrum
#
# Updating header of 10291.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10291_grp.pi with RESPFILE and ANCRFILE keywords.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting bkg spectra
#
# Creating bkg ARF
#
# Creating bkg RMF
#
# Using mkacisrmf...
#
# Updating header of 10291_bkg.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10291.pi with BACKFILE keyword.
#
# Updating header of 10291_grp.pi with BACKFILE keyword.
#
# Running specextract
# Version: 09 Mar 2021
#
# Checking for blank sky background files...
# Using event file 10292/primary/acisf10292N003_evt2.fits.gz[sky=region(ds9.reg)]
#
# Aspect solution file 10292/primary/pcadf10292_000N001_asol1.fits found.
#
# Bad-pixel file 10292/primary/acisf10292_000N003_bpix1.fits.gz found.
#
# Mask file 10292/secondary/acisf10292_000N003_msk1.fits found.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting src spectra
#
# Creating src ARF
#
# Creating src RMF
#
# Using mkacisrmf...
#
# Grouping src spectrum
#
# Updating header of 10292.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10292_grp.pi with RESPFILE and ANCRFILE keywords.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting bkg spectra
#
# Creating bkg ARF
#
# Creating bkg RMF
#
# Using mkacisrmf...
#
# Updating header of 10292_bkg.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10292.pi with BACKFILE keyword.
#
# Updating header of 10292_grp.pi with BACKFILE keyword.
#
# Running specextract
# Version: 09 Mar 2021
#
# Checking for blank sky background files...
# Using event file 10293/primary/acisf10293N003_evt2.fits.gz[sky=region(ds9.reg)]
#
# Aspect solution file 10293/primary/pcadf10293_000N001_asol1.fits found.
#
# Bad-pixel file 10293/primary/acisf10293_000N003_bpix1.fits.gz found.
#
# Mask file 10293/secondary/acisf10293_000N003_msk1.fits found.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting src spectra
#
# Creating src ARF
#
# Creating src RMF
#
# Using mkacisrmf...
#
# Grouping src spectrum
#
# Updating header of 10293.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10293_grp.pi with RESPFILE and ANCRFILE keywords.
#
# Warning: Skip adding 'bell_nh' header keyword.  No valid data at the source location in the Bell Labs HI Survey (the survey covers RA > -40 deg).
#
# Setting bad pixel file
#
# Extracting bkg spectra
#
# Creating bkg ARF
#
# Creating bkg RMF
#
# Using mkacisrmf...
#
# Updating header of 10293_bkg.pi with RESPFILE and ANCRFILE keywords.
#
# Updating header of 10293.pi with BACKFILE keyword.
#
# Updating header of 10293_grp.pi with BACKFILE keyword.

# %%
/bin/ls -1 *.pi
# Out:
# 10289.pi
# 10289_bkg.pi
# 10289_grp.pi
# 10290.pi
# 10290_bkg.pi
# 10290_grp.pi
# 10291.pi
# 10291_bkg.pi
# 10291_grp.pi
# 10292.pi
# 10292_bkg.pi
# 10292_grp.pi
# 10293.pi
# 10293_bkg.pi
# 10293_grp.pi
# ngc6300_bkg.pi
# ngc6300_src.pi
# ngc6300_stacks_bkg.pi
# ngc6300_stacks_src.pi

# %%
/bin/ls -1 *.arf
# Out:
# 10289.arf
# 10289_bkg.arf
# 10290.arf
# 10290_bkg.arf
# 10291.arf
# 10291_bkg.arf
# 10292.arf
# 10292_bkg.arf
# 10293.arf
# 10293_bkg.arf
# ngc6300_bkg.arf
# ngc6300_src.arf
# ngc6300_stacks_bkg.arf
# ngc6300_stacks_src.arf

# %%
/bin/ls -1 *.rmf
# Out:
# 10289.rmf
# 10289_bkg.rmf
# 10290.rmf
# 10290_bkg.rmf
# 10291.rmf
# 10291_bkg.rmf
# 10292.rmf
# 10292_bkg.rmf
# 10293.rmf
# 10293_bkg.rmf
# ngc6300_bkg.rmf
# ngc6300_src.rmf
# ngc6300_stacks_bkg.rmf
# ngc6300_stacks_src.rmf

# %% [markdown]
# ## Running combine_spectra

# %%
punlearn combine_spectra
pset combine_spectra src_spectra="10289.pi,10290.pi,10291.pi,10292.pi,10293.pi"
pset combine_spectra outroot=ngc6300
combine_spectra mode=h clob+
# Out:
# Prepared to combine 5 spectra
#
# source PHA: 10289.pi
#        ARF: 10289.arf
#        RMF: 10289.rmf
#     background PHA: 10289_bkg.pi
#                ARF: 10289_bkg.arf
#                RMF: 10289_bkg.rmf
# source PHA: 10290.pi
#        ARF: 10290.arf
#        RMF: 10290.rmf
#     background PHA: 10290_bkg.pi
#                ARF: 10290_bkg.arf
#                RMF: 10290_bkg.rmf
# source PHA: 10291.pi
#        ARF: 10291.arf
#        RMF: 10291.rmf
#     background PHA: 10291_bkg.pi
#                ARF: 10291_bkg.arf
#                RMF: 10291_bkg.rmf
# source PHA: 10292.pi
#        ARF: 10292.arf
#        RMF: 10292.rmf
#     background PHA: 10292_bkg.pi
#                ARF: 10292_bkg.arf
#                RMF: 10292_bkg.rmf
# source PHA: 10293.pi
#        ARF: 10293.arf
#        RMF: 10293.rmf
#     background PHA: 10293_bkg.pi
#                ARF: 10293_bkg.arf
#                RMF: 10293_bkg.rmf
#
# The following files were created:
#   ngc6300_src.pi
#   ngc6300_bkg.pi
#   ngc6300_src.arf
#   ngc6300_bkg.arf
#   ngc6300_src.rmf
#   ngc6300_bkg.rmf

# %% [markdown]
# ## Manually input stacks

# %%
/bin/ls ?????.pi > src.lis
/bin/ls ?????.arf > arf.lis
/bin/ls ?????.rmf > rmf.lis

# Repeat for background files
/bin/ls ?????_bkg.pi > bg.lis
/bin/ls ?????_bkg.arf > bg_arf.lis
/bin/ls ?????_bkg.rmf > bg_rmf.lis

# %%
cat src.lis
# Out:
# 10289.pi
# 10290.pi
# 10291.pi
# 10292.pi
# 10293.pi

# %%
cat bg_arf.lis
# Out:
# 10289_bkg.arf
# 10290_bkg.arf
# 10291_bkg.arf
# 10292_bkg.arf
# 10293_bkg.arf

# %%
punlearn combine_spectra
pset combine_spectra src_spectra=@src.lis
pset combine_spectra src_arfs=@arf.lis
pset combine_spectra src_rmfs=@rmf.lis
pset combine_spectra bkg_spectra=@bg.lis
pset combine_spectra bkg_arfs=@bg_arf.lis
pset combine_spectra bkg_rmfs=@bg_rmf.lis
pset combine_spectra outroot=ngc6300_stacks
combine_spectra mode=h clob+
# Out:
# Prepared to combine 5 spectra
#
# source PHA: 10289.pi
#        ARF: 10289.arf
#        RMF: 10289.rmf
#     background PHA: 10289_bkg.pi
#                ARF: 10289_bkg.arf
#                RMF: 10289_bkg.rmf
# source PHA: 10290.pi
#        ARF: 10290.arf
#        RMF: 10290.rmf
#     background PHA: 10290_bkg.pi
#                ARF: 10290_bkg.arf
#                RMF: 10290_bkg.rmf
# source PHA: 10291.pi
#        ARF: 10291.arf
#        RMF: 10291.rmf
#     background PHA: 10291_bkg.pi
#                ARF: 10291_bkg.arf
#                RMF: 10291_bkg.rmf
# source PHA: 10292.pi
#        ARF: 10292.arf
#        RMF: 10292.rmf
#     background PHA: 10292_bkg.pi
#                ARF: 10292_bkg.arf
#                RMF: 10292_bkg.rmf
# source PHA: 10293.pi
#        ARF: 10293.arf
#        RMF: 10293.rmf
#     background PHA: 10293_bkg.pi
#                ARF: 10293_bkg.arf
#                RMF: 10293_bkg.rmf
#
# The following files were created:
#   ngc6300_stacks_src.pi
#   ngc6300_stacks_bkg.pi
#   ngc6300_stacks_src.arf
#   ngc6300_stacks_bkg.arf
#   ngc6300_stacks_src.rmf
#   ngc6300_stacks_bkg.rmf

# %% [markdown]
# ## Fitting

# %%
dmlist ngc6300_src.pi keys | grep FILE
# Out:
# 0097 BACKFILE             ngc6300_bkg.pi                 String
# 0098 CORRFILE             none                           String
# 0099 RESPFILE             ngc6300_src.rmf                String
# 0100 ANCRFILE             ngc6300_src.arf                String

# %%
dmlist ngc6300_stacks_src.pi keys | grep FILE
# Out:
# 0097 BACKFILE             ngc6300_stacks_bkg.pi          String
# 0098 CORRFILE             none                           String
# 0099 RESPFILE             ngc6300_stacks_src.rmf         String
# 0100 ANCRFILE             ngc6300_stacks_src.arf         String

# %%
dmlist ngc6300_stacks_bkg.pi keys | grep FILE
# Out:
# 0097 BACKFILE             none                           String
# 0098 CORRFILE             none                           String
# 0099 RESPFILE             ngc6300_stacks_bkg.rmf         String
# 0100 ANCRFILE             ngc6300_stacks_bkg.arf         String

# %% [markdown]
# # Cleanup

# %%
/bin/rm -rf 10289 10290 10291 10292 10293
